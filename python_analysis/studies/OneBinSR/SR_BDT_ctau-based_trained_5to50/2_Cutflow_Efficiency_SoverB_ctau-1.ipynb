# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os, sys
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import utils
from pathlib import Path

sys.path.append("../../../analysisTools/")
import plotTools as ptools

# %%
def add_signal_info_to_df(df):
    m1_list = []
    delta_list = []
    ctau_list = []
    
    for point in df.index.values:
        sig_dict = ptools.signalPoint(point)
        m1_list.append(sig_dict['m1'])
        delta_list.append(sig_dict['delta'])
        ctau_list.append(sig_dict['ctau'])
    
    df['m1'] = m1_list
    df['delta'] = delta_list
    df['ctau'] = ctau_list
    
    df = df.sort_values(by=['m1']) # sort by m1

    return df

# %%
def save_df_to_csv(df, outdir, outname, isSignal = False):
    Path(outdir).mkdir(parents=True, exist_ok=True)

    if isSignal:
        df = add_signal_info_to_df(df)
    
    df.to_csv(f'{outdir}/{outname}.csv')

    print(f'Saved: {outdir}/{outname}.csv')

# %% [markdown]
# # SR ctau-BDT-based (trained on [5,50]GeV): run on all signal mass points [5, 100] GeV

# %%
ct = 1

# %% [markdown]
# ## Background

# %%
prefix = './coffea/skimmed/'
suffix = f'_SR_BDT-based_ctau-{ct}_trained_5to50'

# %%
# Background
bkg_files = {
    "QCD": "bkg_2018_QCD_TuneCP5_PSWeights", # No entry for QCD
    "Top": "bkg_2018_Top",
    "DY": "bkg_2018_DY",
    "Diboson": "bkg_2018_Diboson",
    "Triboson": "bkg_2018_Triboson",
    "W+jets": "bkg_2018_WJets",
    "Z+jets": "bkg_2018_ZJets",
}

bkg_histos = {}

for b in bkg_files.keys():
    bkg_histos[b] = util.load(f'{prefix}/{bkg_files[b]}{suffix}.coffea')[0]

# %%
# efficiency
pd.options.display.float_format = '{:,.6f}'.format
bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histos, 'cutflow')

bkg_eff_df
# Out:
#           Preselections  0 < n(jet) < 3 & n(good vertex) > 0  \
# QCD            0.000002                             0.000000
# Top            0.000129                             0.000013
# DY             0.000011                             0.000001
# Diboson        0.000637                             0.000044
# Triboson       0.001933                             0.000158
# W+jets         0.002310                             0.000173
# Z+jets         0.006645                             0.000398
# Total          0.000019                             0.000001
#
#           computing BDT score  No b-tagged jets  Leading jet |eta| < 2.4  \
# QCD                  0.000000          0.000000                 0.000000
# Top                  0.000013          0.000008                 0.000007
# DY                   0.000001          0.000000                 0.000000
# Diboson              0.000044          0.000033                 0.000031
# Triboson             0.000158          0.000104                 0.000092
# W+jets               0.000173          0.000139                 0.000132
# Z+jets               0.000398          0.000325                 0.000310
# Total                0.000000          0.000000                 0.000000
#
#           Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# QCD                      0.000000                     0.000000
# Top                      0.000007                     0.000007
# DY                       0.000000                     0.000000
# Diboson                  0.000030                     0.000030
# Triboson                 0.000091                     0.000091
# W+jets                   0.000131                     0.000131
# Z+jets                   0.000309                     0.000309
# Total                    0.000000                     0.000000
#
#           dPhi(MET,all jets) > 0.75  BDT v2 Loose WP
# QCD                        0.000000         0.000000
# Top                        0.000007         0.000000
# DY                         0.000000         0.000000
# Diboson                    0.000027         0.000000
# Triboson                   0.000076         0.000000
# W+jets                     0.000114         0.000000
# Z+jets                     0.000292         0.000000
# Total                      0.000000         0.000000

# %%
outdir = './csv/Cutflow/Efficiency/'
outname = f'SR_BDT_ctau-{int(ct)}-based_trained_5to50_Background_Efficiency'

df_to_save = bkg_eff_df

save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_BDT_ctau-1-based_trained_5to50_Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histos, 'cutflow_cts')

bkg_cts_df
# Out:
#           Preselections  0 < n(jet) < 3 & n(good vertex) > 0  \
# QCD           38,039.83                             1,882.67
# Top            5,667.49                               559.22
# DY            14,495.72                               671.44
# Diboson        4,424.20                               307.91
# Triboson          53.00                                 4.32
# W+jets       227,212.60                            17,009.81
# Z+jets       142,220.15                             8,524.55
# Total        432,113.00                            28,959.92
#
#           computing BDT score  No b-tagged jets  Leading jet |eta| < 2.4  \
# QCD                  1,882.67          1,326.86                 1,319.01
# Top                    559.22            349.76                   314.03
# DY                     671.44            623.25                   623.25
# Diboson                307.91            227.24                   213.36
# Triboson                 4.32              2.85                     2.51
# W+jets              17,009.81         13,645.63                12,937.21
# Z+jets               8,524.55          6,957.67                 6,625.48
# Total               28,959.92         23,133.27                22,034.86
#
#           Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# QCD                      1,319.01                     1,318.41
# Top                        312.99                       312.95
# DY                         623.25                       623.25
# Diboson                    211.27                       210.33
# Triboson                     2.51                         2.50
# W+jets                  12,911.49                    12,907.15
# Z+jets                   6,613.11                     6,612.30
# Total                   21,993.63                    21,986.91
#
#           dPhi(MET,all jets) > 0.75  BDT v2 Loose WP
# QCD                          632.25             0.00
# Top                          294.00             0.33
# DY                           455.65             0.00
# Diboson                      189.35             0.78
# Triboson                       2.09             0.00
# W+jets                    11,204.39            34.95
# Z+jets                     6,256.76            10.09
# Total                     19,034.50            46.15

# %%
outdir = './csv/Cutflow/EventCount_Weighted/'
outname = f'SR_BDT_ctau-{int(ct)}-based_trained_5to50_Background_EventCount_Weighted'

df_to_save = bkg_cts_df

save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/Cutflow/EventCount_Weighted//SR_BDT_ctau-1-based_trained_5to50_Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histos, 'cutflow_nevts')

bkg_cts_raw_df
# Out:
#           Preselections  0 < n(jet) < 3 & n(good vertex) > 0  \
# QCD               12311                                  381
# Top               49818                                 4688
# DY                  205                                   13
# Diboson           18067                                 1234
# Triboson           2257                                  170
# W+jets           697657                                48425
# Z+jets          1281459                                67427
# Total           2061774                               122338
#
#           computing BDT score  No b-tagged jets  Leading jet |eta| < 2.4  \
# QCD                       381               160                      159
# Top                      4688              3058                     2348
# DY                         13                11                       11
# Diboson                  1234               915                      860
# Triboson                  170               116                      106
# W+jets                  48425             37015                    35472
# Z+jets                  67427             52627                    50986
# Total                  122338             93902                    89942
#
#           Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# QCD                           159                          158
# Top                          2337                         2336
# DY                             11                           11
# Diboson                       852                          848
# Triboson                      105                          104
# W+jets                      35415                        35377
# Z+jets                      50934                        50903
# Total                       89813                        89737
#
#           dPhi(MET,all jets) > 0.75  BDT v2 Loose WP
# QCD                               3                0
# Top                            2006                3
# DY                                9                0
# Diboson                         767                3
# Triboson                         92                0
# W+jets                        29090              110
# Z+jets                        44480               75
# Total                         76447              191

# %%
outdir = './csv/Cutflow/EventCount_Raw/'
outname = f'SR_BDT_ctau-{int(ct)}-based_trained_5to50_Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/Cutflow/EventCount_Raw//SR_BDT_ctau-1-based_trained_5to50_Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 46.15

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['BDT v2 Loose WP']).transpose(), pd.DataFrame(bkg_cts_raw_df['BDT v2 Loose WP']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  QCD  Top   DY  Diboson  Triboson  W+jets  Z+jets  Total
# Weighted Counts 0.00 0.33 0.00     0.78      0.00   34.95   10.09  46.15
# Raw Counts      0.00 3.00 0.00     3.00      0.00  110.00   75.00 191.00

# %% [markdown]
# ## Signal

# %%
# Signal
sig_histo = util.load(f'{prefix}/signal{suffix}.coffea')[0]

# %%
si = utils.get_signal_point_dict(sig_histo)

pd.options.display.float_format = '{:,.1f}'.format
si
# Out:
#                                        mchi  dmchi  ctau    m1    m2  delta  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1    84.0    8.0   1.0  80.0  88.0    0.1
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1   77.0   14.0   1.0  70.0  84.0    0.2
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1   99.0   18.0   1.0  90.0 108.0    0.2
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1    94.5    9.0   1.0  90.0  99.0    0.1
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1    73.5    7.0   1.0  70.0  77.0    0.1
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1    63.0    6.0   1.0  60.0  66.0    0.1
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1   60.0   20.0   1.0  50.0  70.0    0.4
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1     5.2    0.5   1.0   5.0   5.5    0.1
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1   55.0   10.0   1.0  50.0  60.0    0.2
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      5.5    1.0   1.0   5.0   6.0    0.2
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1    52.5    5.0   1.0  50.0  55.0    0.1
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1    44.0    8.0   1.0  40.0  48.0    0.2
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1    33.0    6.0   1.0  30.0  36.0    0.2
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    42.0    4.0   1.0  40.0  44.0    0.1
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1    22.0    4.0   1.0  20.0  24.0    0.2
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    31.5    3.0   1.0  30.0  33.0    0.1
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1    11.0    2.0   1.0  10.0  12.0    0.2
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    21.0    2.0   1.0  20.0  22.0    0.1
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1 110.0   20.0   1.0 100.0 120.0    0.2
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    10.5    1.0   1.0  10.0  11.0    0.1
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1 105.0   10.0   1.0 100.0 110.0    0.1
#
#                                                                         name
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1      sig_2018_Mchi-84p0_dMchi-8p0_ctau-1
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1    sig_2018_Mchi-77p0_dMchi-14p0_ctau-1
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1    sig_2018_Mchi-99p0_dMchi-18p0_ctau-1
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1      sig_2018_Mchi-94p5_dMchi-9p0_ctau-1
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1      sig_2018_Mchi-73p5_dMchi-7p0_ctau-1
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1      sig_2018_Mchi-63p0_dMchi-6p0_ctau-1
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1    sig_2018_Mchi-60p0_dMchi-20p0_ctau-1
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      sig_2018_Mchi-5p25_dMchi-0p5_ctau-1
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1    sig_2018_Mchi-55p0_dMchi-10p0_ctau-1
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        sig_2018_Mchi-5p5_dMchi-1p0_ctau-1
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1      sig_2018_Mchi-52p5_dMchi-5p0_ctau-1
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1      sig_2018_Mchi-44p0_dMchi-8p0_ctau-1
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1      sig_2018_Mchi-33p0_dMchi-6p0_ctau-1
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1      sig_2018_Mchi-42p0_dMchi-4p0_ctau-1
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1      sig_2018_Mchi-22p0_dMchi-4p0_ctau-1
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1      sig_2018_Mchi-31p5_dMchi-3p0_ctau-1
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1      sig_2018_Mchi-11p0_dMchi-2p0_ctau-1
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1      sig_2018_Mchi-21p0_dMchi-2p0_ctau-1
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1  sig_2018_Mchi-110p0_dMchi-20p0_ctau-1
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1      sig_2018_Mchi-10p5_dMchi-1p0_ctau-1
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1  sig_2018_Mchi-105p0_dMchi-10p0_ctau-1

# %%
cutnames = utils.get_signal_list_of_cuts(sig_histo)

cutnames
# Out:
# ['Preselections',
#  '0 < n(jet) < 3 & n(good vertex) > 0',
#  'computing BDT score',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  'dPhi(MET,leading jet) > 1.5',
#  'dPhi(MET,all jets) > 0.75',
#  'BDT v2 Loose WP']

# %% [markdown]
# ### Efficiency

# %%
pd.options.display.float_format = '{:,.6f}'.format

# %%
eff_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow')

# %%
table = pd.DataFrame.from_dict(eff_cutflow, orient='index')
table.columns = cutnames

# %%
ct = 1.0

points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
df
# Out:
#                                        Preselections  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1         0.058112
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1        0.049041
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1        0.065041
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1         0.066110
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1         0.051428
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1         0.043559
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1        0.029875
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1         0.014782
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        0.033826
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          0.014484
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1         0.036318
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         0.026904
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1         0.020878
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1         0.030555
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         0.016920
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1         0.023214
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         0.014729
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1         0.018942
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       0.070618
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1         0.015928
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       0.073740
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                               0.011195
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                              0.011230
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                              0.015343
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                               0.013011
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                               0.009301
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                               0.007791
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                              0.007027
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                               0.002143
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                              0.006982
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                                0.001842
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                               0.006259
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                               0.005099
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                               0.003848
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                               0.005051
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                               0.002932
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                               0.003481
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                               0.002188
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                               0.002826
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                             0.017181
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                               0.002349
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                             0.014937
#
#                                        computing BDT score  No b-tagged jets  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1               0.011195          0.009729
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1              0.011230          0.009552
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1              0.015343          0.012976
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1               0.013011          0.011131
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1               0.009301          0.007902
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1               0.007791          0.006622
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1              0.007027          0.005808
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1               0.002143          0.001894
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1              0.006982          0.005961
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                0.001842          0.001519
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1               0.006259          0.005421
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1               0.005099          0.004306
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1               0.003848          0.003369
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1               0.005051          0.004338
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1               0.002932          0.002531
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1               0.003481          0.002980
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1               0.002188          0.001889
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1               0.002826          0.002381
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1             0.017181          0.014596
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               0.002349          0.002024
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1             0.014937          0.012755
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   0.009420
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                  0.009201
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                  0.012527
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   0.010744
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   0.007672
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   0.006351
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                  0.005631
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   0.001811
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    0.001421
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   0.004165
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   0.003242
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   0.004133
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   0.002386
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   0.002881
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   0.001805
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   0.002275
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                 0.014041
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   0.001882
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 0.012361
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   0.009420
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                  0.009201
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                  0.012527
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   0.010743
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   0.007672
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   0.006351
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                  0.005631
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   0.001811
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    0.001418
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   0.004161
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   0.003235
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   0.004127
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   0.002386
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   0.002881
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   0.001805
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   0.002273
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                 0.014037
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   0.001880
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 0.012357
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       0.009420
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                      0.009201
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      0.012527
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       0.010743
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                       0.007672
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                       0.006351
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      0.005631
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                       0.001811
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                      0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        0.001418
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                       0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       0.004161
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                       0.003235
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                       0.004127
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       0.002386
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                       0.002881
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       0.001805
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                       0.002273
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     0.014037
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                       0.001880
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     0.012357
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     0.009342
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                    0.009076
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.012353
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     0.010641
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     0.007581
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     0.006279
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                    0.005523
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                     0.001794
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    0.005651
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      0.001404
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     0.005197
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     0.004135
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                     0.003195
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     0.004103
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     0.002357
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                     0.002855
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     0.001794
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     0.002253
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.013793
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     0.001867
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   0.012238
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1           0.003499
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1          0.002978
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1          0.002660
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1           0.003674
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1           0.003051
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1           0.002625
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1          0.001627
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           0.000719
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          0.003160
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1            0.000697
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1           0.002415
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           0.002132
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           0.001824
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           0.001978
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           0.001254
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           0.001288
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1           0.000881
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           0.001053
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1         0.002504
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           0.000789
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1         0.003931

# %%
outdir = './csv/Cutflow/Efficiency/'
outname = f'SR_BDT_ctau-based_trained_5to50_Signal_ctau-{int(ct)}_samples_Efficiency'

df_to_save = df

save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_BDT_ctau-based_trained_5to50_Signal_ctau-1_samples_Efficiency.csv

# %% [markdown]
# ### Weighted Event count

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
count_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

# %%
table = pd.DataFrame.from_dict(count_cutflow, orient='index')
table.columns = cutnames

# %%
points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
#df.loc["Total"] = df.sum()

df
# Out:
#                                        Preselections  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1         2,122.81
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1           90.58
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1           51.58
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1         1,627.11
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1         2,928.06
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1         4,153.77
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1            5.68
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1        62,382.76
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          205.19
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          2,748.24
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1         6,562.28
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           512.94
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1        49,723.24
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1        16,193.18
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           995.45
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1        33,794.92
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         1,394.26
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1        30,374.51
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1          38.81
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1        39,395.49
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       1,263.57
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                                 408.93
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                                 20.74
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                 12.17
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                                 320.24
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                                 529.56
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                                 742.93
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                                  1.33
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                               9,045.04
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                                 42.35
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                                  349.57
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                               1,130.93
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                                  97.21
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                               9,164.66
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                               2,676.90
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                                 172.47
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                               5,067.47
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                                 207.15
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                               4,531.00
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                 9.44
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                               5,811.03
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                               255.95
#
#                                        computing BDT score  No b-tagged jets  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                 408.93            355.40
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                 20.74             17.64
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                 12.17             10.29
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                 320.24            273.97
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 529.56            449.92
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 742.93            631.48
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                  1.33              1.10
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1               9,045.04          7,993.01
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 42.35             36.16
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                  349.57            288.31
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1               1,130.93            979.54
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  97.21             82.10
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1               9,164.66          8,024.74
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1               2,676.90          2,298.73
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                 172.47            148.91
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1               5,067.47          4,338.18
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                 207.15            178.78
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1               4,531.00          3,817.78
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                 9.44              8.02
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               5,811.03          5,006.12
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1               255.95            218.56
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     264.43
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      269.62
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      79.40
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   7,722.24
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   2,190.27
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     140.36
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   4,193.56
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   3,648.14
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     7.72
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   4,654.25
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   211.80
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     264.40
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      268.98
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      79.34
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   7,704.44
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   2,187.08
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     140.36
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   4,193.56
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   3,644.60
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     7.71
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   4,648.89
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   211.74
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                         344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                         16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                          9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                         264.40
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                         436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                         605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                          1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                       7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                         34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                          268.98
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                         942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                          79.34
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                       7,704.44
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                       2,187.08
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                         140.36
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                       4,193.56
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                         170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                       3,644.60
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                         7.71
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                       4,648.89
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       211.74
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       341.27
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       16.76
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        9.80
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       261.91
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                       431.62
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                       598.76
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                        1.05
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                     7,572.31
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                       34.28
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        266.40
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                       939.12
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                        78.84
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                     7,609.52
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     2,174.33
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       138.67
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                     4,156.59
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       169.82
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     3,612.88
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                       7.58
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     4,616.98
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     209.71
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1             127.82
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1              5.50
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1              2.11
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1              90.43
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1             173.72
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1             250.29
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1              0.31
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           3,032.37
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1             19.17
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              132.25
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1             436.31
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1              40.64
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           4,344.52
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           1,048.15
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1              73.76
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           1,875.15
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1              83.43
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           1,688.01
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1             1.38
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           1,951.69
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            67.37

# %%
outdir = './csv/Cutflow/EventCount_Weighted/'
outname = f'SR_BDT_ctau-based_trained_5to50_Signal_ctau-{int(ct)}_samples_EventCount_Weighted'

df_to_save = df

save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/EventCount_Weighted//SR_BDT_ctau-based_trained_5to50_Signal_ctau-1_samples_EventCount_Weighted.csv

# %%
# without m1 = 30 GeV
m1 = 30.0

points = (si["ctau"] == ct) & (si["m1"] != m1)

df = table.loc[list(si[points].name)]
df.loc["Total"] = df.sum()

df
# Out:
#                                        Preselections  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1         2,122.81
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1           90.58
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1           51.58
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1         1,627.11
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1         2,928.06
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1         4,153.77
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1            5.68
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1        62,382.76
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          205.19
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          2,748.24
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1         6,562.28
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           512.94
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1        16,193.18
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           995.45
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         1,394.26
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1        30,374.51
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1          38.81
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1        39,395.49
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       1,263.57
# Total                                     173,046.25
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                                 408.93
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                                 20.74
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                 12.17
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                                 320.24
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                                 529.56
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                                 742.93
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                                  1.33
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                               9,045.04
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                                 42.35
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                                  349.57
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                               1,130.93
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                                  97.21
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                               2,676.90
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                                 172.47
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                                 207.15
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                               4,531.00
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                 9.44
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                               5,811.03
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                               255.95
# Total                                                            26,364.96
#
#                                        computing BDT score  No b-tagged jets  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                 408.93            355.40
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                 20.74             17.64
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                 12.17             10.29
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                 320.24            273.97
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 529.56            449.92
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 742.93            631.48
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                  1.33              1.10
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1               9,045.04          7,993.01
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 42.35             36.16
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                  349.57            288.31
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1               1,130.93            979.54
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  97.21             82.10
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1               2,676.90          2,298.73
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                 172.47            148.91
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                 207.15            178.78
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1               4,531.00          3,817.78
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                 9.44              8.02
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               5,811.03          5,006.12
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1               255.95            218.56
# Total                                            26,364.96         22,795.84
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     264.43
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      269.62
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      79.40
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   2,190.27
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     140.36
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   3,648.14
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     7.72
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   4,654.25
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   211.80
# Total                                                21,671.01
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     264.40
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      268.98
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      79.34
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   2,187.08
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     140.36
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   3,644.60
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     7.71
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   4,648.89
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   211.74
# Total                                                21,658.13
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                         344.10
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                         16.99
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                          9.93
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                         264.40
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                         436.79
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                         605.60
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                          1.07
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                       7,642.38
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                         34.55
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                          268.98
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                         942.72
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                          79.34
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                       2,187.08
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                         140.36
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                         170.89
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                       3,644.60
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                         7.71
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                       4,648.89
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       211.74
# Total                                                    21,658.13
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       341.27
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       16.76
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        9.80
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       261.91
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                       431.62
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                       598.76
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                        1.05
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                     7,572.31
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                       34.28
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        266.40
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                       939.12
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                        78.84
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     2,174.33
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       138.67
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       169.82
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     3,612.88
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                       7.58
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     4,616.98
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     209.71
# Total                                                  21,482.09
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1             127.82
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1              5.50
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1              2.11
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1              90.43
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1             173.72
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1             250.29
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1              0.31
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           3,032.37
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1             19.17
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              132.25
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1             436.31
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1              40.64
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           1,048.15
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1              73.76
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1              83.43
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           1,688.01
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1             1.38
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           1,951.69
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            67.37
# Total                                         9,224.71

# %% [markdown]
# ### Raw count

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
table = pd.DataFrame.from_dict(raw_cutflow, orient='index')
table.columns = cutnames

# %%
points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
#df.loc["Total"] = df.sum()

df
# Out:
#                                        Preselections  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1            12770
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1           10607
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1           31711
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1            48974
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1            13602
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1            11551
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1            7768
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1             3558
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1             761
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              4261
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1            14604
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1             8179
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1             8377
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1            10151
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1             7098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1            10056
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1             6536
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1             8600
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1          18196
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             7390
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1          59043
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                                   2460
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                                  2429
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                  7481
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                                   9639
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                                   2460
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                                   2066
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                                  1827
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                                    516
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                                   157
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                                     542
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                                   2517
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                                   1550
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                                   1544
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                                   1678
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                                   1230
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                                   1508
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                                    971
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                                   1283
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                 4427
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                   1090
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                11960
#
#                                        computing BDT score  No b-tagged jets  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   2460              2138
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                  2429              2066
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                  7481              6327
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   9639              8246
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   2460              2090
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   2066              1756
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                  1827              1510
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    516               456
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                   157               134
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     542               447
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   2517              2180
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   1550              1309
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   1544              1352
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   1678              1441
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   1230              1062
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   1508              1291
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    971               838
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   1283              1081
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                 4427              3761
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   1090               939
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                11960             10213
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       2070
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                      1990
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      6108
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       7959
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                       2029
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                       1684
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1464
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                        436
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                       128
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                         418
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                       2098
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       1266
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                       1301
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                       1373
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       1001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                       1248
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                        801
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                       1033
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     3618
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                        873
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     9897
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       2070
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                      1990
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                      6108
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       7958
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                       2029
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                       1684
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                      1464
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                        436
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                       128
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                         417
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                       2098
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       1265
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                       1298
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                       1371
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       1001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                       1248
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                        801
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                       1032
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                     3617
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                        872
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     9894
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                           2070
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                          1990
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                          6108
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                           7958
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                           2029
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                           1684
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                          1464
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                            436
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                           128
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                             417
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                           2098
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                           1265
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                           1298
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                           1371
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                           1001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                           1248
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                            801
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                           1032
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                         3617
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                            872
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                         9894
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                         2053
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                        1963
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        6023
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                         7883
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                         2005
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                         1665
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1                        1436
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                          432
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                         127
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                           413
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                         2090
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                         1257
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                         1282
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                         1363
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                          989
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                         1237
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                          796
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                         1023
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                       3554
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                          866
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       9799
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                769
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1               644
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1              1297
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1               2722
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                807
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                696
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1               423
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                173
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                71
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                 205
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                971
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                648
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                732
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                657
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                526
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                558
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                391
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                478
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1              645
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                366
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1             3148

# %%
outdir = './csv/Cutflow/EventCount_Raw/'
outname = f'SR_BDT_ctau-based_trained_5to50_Signal_ctau-{int(ct)}_samples_EventCount_Raw'

df_to_save = df

save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/EventCount_Raw//SR_BDT_ctau-based_trained_5to50_Signal_ctau-1_samples_EventCount_Raw.csv

# %% [markdown]
# ## S/sqrt(B)

# %%
nBkg
# Out:
# 46.14937863220887

# %%
count_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
table = pd.DataFrame.from_dict(count_cutflow, orient='index')
table.columns = cutnames

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
df = pd.DataFrame(table.loc[:, cutnames[-1]]) # last cut

m1_list = []
delta_list = []
ctau_list = []

for point in df.index.values:
    sig_dict = ptools.signalPoint(point)
    m1_list.append(sig_dict['m1'])
    delta_list.append(sig_dict['delta'])
    ctau_list.append(sig_dict['ctau'])

df['m1'] = m1_list
df['delta'] = delta_list
df['ctau'] = ctau_list

df = df.sort_values(by=['m1']) # sort by m1

# %%
# Missing rows
#df[ (df['m1'] == 60) & (df['delta'] == 0.2) ]

df.loc[len(df.index)] = [0, 60, 0.2, 1]
df.loc[len(df.index)] = [0, 80, 0.2, 1] 

df = df.sort_values(by=['m1']) # sort by m1

# %%
df = df.rename(columns={df.columns[0]: 'Signal'})

df['Background'] = nBkg
df
# Out:
#                                           Signal       m1  delta   ctau  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1   3,032.3719   5.0000 0.1000 1.0000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      132.2518   5.0000 0.2000 1.0000
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1      83.4290  10.0000 0.2000 1.0000
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1   1,951.6912  10.0000 0.1000 1.0000
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1   1,688.0138  20.0000 0.1000 1.0000
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1      73.7553  20.0000 0.2000 1.0000
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1   4,344.5185  30.0000 0.2000 1.0000
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1   1,875.1512  30.0000 0.1000 1.0000
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1      40.6448  40.0000 0.2000 1.0000
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1   1,048.1523  40.0000 0.1000 1.0000
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1     19.1678  50.0000 0.2000 1.0000
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1      0.3090  50.0000 0.4000 1.0000
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1     436.3098  50.0000 0.1000 1.0000
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1     250.2910  60.0000 0.1000 1.0000
# 21                                        0.0000  60.0000 0.2000 1.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      5.4997  70.0000 0.2000 1.0000
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1     173.7153  70.0000 0.1000 1.0000
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1     127.8210  80.0000 0.1000 1.0000
# 22                                        0.0000  80.0000 0.2000 1.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      2.1096  90.0000 0.2000 1.0000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1      90.4347  90.0000 0.1000 1.0000
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     1.3759 100.0000 0.2000 1.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1    67.3667 100.0000 0.1000 1.0000
#
#                                        Background
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       46.1494
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        46.1494
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1       46.1494
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       46.1494
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       46.1494
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1       46.1494
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1       46.1494
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       46.1494
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1       46.1494
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       46.1494
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1      46.1494
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1      46.1494
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       46.1494
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       46.1494
# 21                                        46.1494
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      46.1494
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       46.1494
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       46.1494
# 22                                        46.1494
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      46.1494
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       46.1494
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     46.1494
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     46.1494

# %%
df['S/sqrt(B)'] = df['Signal'] / np.sqrt(df['Background'])

df = df[['m1', 'delta', 'ctau', 'Signal', 'Background', 'S/sqrt(B)']]
df
# Out:
#                                             m1  delta   ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1     5.0000 0.1000 1.0000 3,032.3719
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      5.0000 0.2000 1.0000   132.2518
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1    10.0000 0.2000 1.0000    83.4290
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    10.0000 0.1000 1.0000 1,951.6912
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    20.0000 0.1000 1.0000 1,688.0138
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1    20.0000 0.2000 1.0000    73.7553
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1    30.0000 0.2000 1.0000 4,344.5185
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    30.0000 0.1000 1.0000 1,875.1512
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1    40.0000 0.2000 1.0000    40.6448
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    40.0000 0.1000 1.0000 1,048.1523
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1   50.0000 0.2000 1.0000    19.1678
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1   50.0000 0.4000 1.0000     0.3090
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1    50.0000 0.1000 1.0000   436.3098
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1    60.0000 0.1000 1.0000   250.2910
# 21                                     60.0000 0.2000 1.0000     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1   70.0000 0.2000 1.0000     5.4997
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1    70.0000 0.1000 1.0000   173.7153
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1    80.0000 0.1000 1.0000   127.8210
# 22                                     80.0000 0.2000 1.0000     0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1   90.0000 0.2000 1.0000     2.1096
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1    90.0000 0.1000 1.0000    90.4347
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1 100.0000 0.2000 1.0000     1.3759
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1 100.0000 0.1000 1.0000    67.3667
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       46.1494   446.3747
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        46.1494    19.4679
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1       46.1494    12.2810
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       46.1494   287.2951
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       46.1494   248.4809
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1       46.1494    10.8570
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1       46.1494   639.5268
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       46.1494   276.0281
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1       46.1494     5.9830
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       46.1494   154.2913
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1      46.1494     2.8216
# sig_2018_Mchi-60p0_dMchi-20p0_ctau-1      46.1494     0.0455
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       46.1494    64.2262
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       46.1494    36.8436
# 21                                        46.1494     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      46.1494     0.8096
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       46.1494    25.5714
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       46.1494    18.8156
# 22                                        46.1494     0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      46.1494     0.3105
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       46.1494    13.3123
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     46.1494     0.2025
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     46.1494     9.9166

# %%
outdir = './csv/SR_Yields/'
outname = f'SR_BDT_ctau-{int(ct)}-based_trained_5to50_S_over_B'

df_to_save = df

save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/SR_Yields//SR_BDT_ctau-1-based_trained_5to50_S_over_B.csv

# %% [markdown]
# ### ctau = 1mm signal points

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.1
delta = 0.1

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      5.0   0.1  1.0 3,032.3719
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1     10.0   0.1  1.0 1,951.6912
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1     20.0   0.1  1.0 1,688.0138
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1     30.0   0.1  1.0 1,875.1512
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1     40.0   0.1  1.0 1,048.1523
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1     50.0   0.1  1.0   436.3098
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1     60.0   0.1  1.0   250.2910
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1     70.0   0.1  1.0   173.7153
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1     80.0   0.1  1.0   127.8210
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1     90.0   0.1  1.0    90.4347
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1  100.0   0.1  1.0    67.3667
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       46.1494   446.3747
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       46.1494   287.2951
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       46.1494   248.4809
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       46.1494   276.0281
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       46.1494   154.2913
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       46.1494    64.2262
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       46.1494    36.8436
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       46.1494    25.5714
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       46.1494    18.8156
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       46.1494    13.3123
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     46.1494     9.9166

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.2
delta = 0.2

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau     Signal  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1       5.0   0.2  1.0   132.2518
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     10.0   0.2  1.0    83.4290
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1     20.0   0.2  1.0    73.7553
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1     30.0   0.2  1.0 4,344.5185
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1     40.0   0.2  1.0    40.6448
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1    50.0   0.2  1.0    19.1678
# 21                                      60.0   0.2  1.0     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1    70.0   0.2  1.0     5.4997
# 22                                      80.0   0.2  1.0     0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1    90.0   0.2  1.0     2.1096
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1  100.0   0.2  1.0     1.3759
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        46.1494    19.4679
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1       46.1494    12.2810
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1       46.1494    10.8570
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1       46.1494   639.5268
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1       46.1494     5.9830
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1      46.1494     2.8216
# 21                                        46.1494     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      46.1494     0.8096
# 22                                        46.1494     0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      46.1494     0.3105
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     46.1494     0.2025
