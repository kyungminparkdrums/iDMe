# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# See here: https://cms-analysis.docs.cern.ch/guidelines/plotting/colors/ for plot styling suggestions from PubComm

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'

#suffix = 'ABCD_VR1_goodvtx_v11_noNJetCut'
suffix = 'ABCD_VR1_goodvtx_v11_noNJetCut_ABCDscan'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
data_histo.keys()
# Out:
# dict_keys(['sel_e1_pt', 'sel_e1_eta', 'sel_e1_phi', 'sel_e1_dxy', 'sel_e1_dxySignif', 'sel_e1_vxy1', 'sel_e1_vz', 'sel_e2_pt', 'sel_e2_eta', 'sel_e2_phi', 'sel_e2_dxy', 'sel_e2_dxySignif', 'sel_e2_vxy1', 'sel_e2_vz', 'sel_e1_dxy_fromPV', 'sel_e2_dxy_fromPV', 'sel_vtx_dR', 'sel_vtx_mindxy', 'sel_vtx_vxy1', 'sel_vtx_vxy10', 'sel_vtx_vxy100', 'sel_vtx_leadpT', 'sel_vtx_METdPhi', 'sel_vtx_mindRj', 'sel_vtx_chi2', 'sel_vtx_mass', 'sel_vtx_mindPhiJ', 'sel_vtx_sign', 'sel_vtx_pt', 'sel_vtx_eta', 'sel_vtx_phi', 'sel_vtx_type', 'sel_vtx_minEleDrJ', 'sel_vtx_minEleDPhiJ', 'sel_vtx_mass_low', 'sel_vtx_mindxy_low', 'sel_vtx_sign_etaProd', 'sel_vtx_LxyCosThetaColl', 'sel_vtx_LxyCosThetaCollZoom', 'sel_vtx_LxyCosThetaCollZoomZoom', 'sel_vtx_eleDphi', 'sel_vtx_maxMiniRelIso', 'sel_vtx_maxMiniRelIsoCorr', 'sel_vtx_mass_refit', 'sel_vtx_mass_low_refit', 'sel_vtx_pt_refit', 'sel_vtx_eta_refit', 'sel_vtx_phi_refit', 'sel_vtx_dR_refit', 'sel_vtx_mass_refit_vs_sel_vtx_mass', 'sel_vtx_mass_low_refit_vs_sel_vtx_mass_low', 'sel_vtx_pt_refit_vs_sel_vtx_pt', 'sel_vtx_eta_refit_vs_sel_vtx_eta', 'sel_vtx_phi_refit_vs_sel_vtx_phi', 'sel_vtx_dR_refit_vs_sel_vtx_dR', 'sel_vtx_mass_vs_vxy', 'sel_vtx_mass_refit_vs_vxy', 'sel_e1_phi_vs_METphi', 'sel_e1_phi_vs_sel_e1_eta', 'sel_e1_phi_vs_sel_e1_pt', 'sel_e2_phi_vs_METphi', 'sel_e2_phi_vs_sel_e2_eta', 'sel_e2_phi_vs_sel_e2_pt', 'sel_vtx_phi_vs_sel_vtx_eta', 'sel_vtx_phi_vs_sel_vtx_pt', 'sel_vtx_phi_vs_sel_vtx_dR', 'sel_vtx_phi_vs_sel_vtx_pt800', 'sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom', 'sel_e1_phi_zoom_vs_sel_e1_eta', 'sel_e2_phi_zoom_vs_sel_e2_eta', 'sel_vtx_phi_vs_METphi', 'sel_vtx_phi_vs_lead_jet_phi', 'sel_vtx_phi_refit_vs_METphi', 'sel_vtx_phi_refit_vs_lead_jet_phi', 'METphi_vs_lead_jet_phi', 'sel_vtx_phi_refit_over_phi', 'sel_vtx_vx_vs_vy', 'PVx_vs_PVy', 'PFMET', 'PFMET1000', 'PFMETphi', 'jetMETdPhi', 'minJetMETdPhi', 'nJets', 'lead_jet_pt', 'lead_jet_eta', 'lead_jet_phi', 'jetMETratio', 'lead_jet_phi_vs_lead_jet_eta', 'PVx', 'PVy', 'sel_vtx_CosThetaColl', 'sel_vtx_ThetaColl_fromPV_refit_rad', 'sel_vtx_ThetaColl_fromPV_refit', 'sel_vtx_ThetaColl_fromPV', 'sel_vtx_CosThetaColl_fromPV', 'sel_vtx_CosThetaColl_fromPV_refit', 'sel_vtx_GenCosThetaColl', 'sel_vtx_GenThetaColl', 'sel_vtx_GenCosThetaColl_vs_sel_vtx_CosThetaColl_fromPV', 'sel_vtx_GenCosThetaColl_vs_sel_vtx_CosThetaColl_fromPV_refit', 'sel_vtx_GenThetaColl_vs_sel_vtx_ThetaColl_fromPV', 'sel_vtx_GenThetaColl_vs_sel_vtx_ThetaColl_fromPV_refit', 'sel_vtx_GenThetaColl_rad_vs_sel_vtx_ThetaColl_fromPV_refit_rad', 'sel_vtx_vxy1_fromPV_scalarSub', 'sel_vtx_vxy1_fromPV_vectorSub', 'sel_e1_dxy_refit', 'sel_e1_dxy_manual', 'sel_e1_dxy_manual_fromPV', 'bdtscore', 'bdtscore_vs_sel_vtx_CosThetaColl_fromPV_refit', 'bdtscore_vs_sel_vtx_sign', 'sel_vtx_CosThetaColl_fromPV_refit_vs_sel_vtx_sign', 'bdtscore_vs_sel_vtx_CosThetaColl_fromPV', 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit', 'bdtscore_vs_sel_vtx_thetaColl_fromPV', 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched', 'cutflow_vtx_matched_fromReco'])

# %%
variable = 'nJets'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$N_{jets}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 32
#       7 plot_dict = {
#       8     'variable': variable,
#       9     'cut': cut,
#      10     'year': 2018
#      11 }
#      13 style_dict = {
#      14     'fig': fig,
#      15     'ax': ax,
#    (...)
#      29     'outName': f'data_VR1_{variable}_{cut}.png'
#      30 }
# ---> 32 ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
#
# File /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/ABCD_studies/../../analysisTools/plotTools.py:1701, in plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
#    1698 fig = style_dict['fig']
#    1699 ax = style_dict['ax']
# -> 1701 plot_bkg_1d(bkg_histo, plot_dict, style_dict, processes = 'all')
#    1702 plot_bkg_1d_stacked_errbar(bkg_histo, plot_dict, style_dict, processes = 'all')
#    1703 plot_data_1d(data_histo, plot_dict, style_dict)
#
# File /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/ABCD_studies/../../analysisTools/plotTools.py:893, in plot_bkg_1d(bkg_histos, plot_dict, style_dict, isLegacy, processes)
#     891 # add histos to stack after rebinning and range setting
#     892 for process in sorted_entries.keys():
# --> 893     bkg[plot_dict['variable']][process] = bkg[plot_dict['variable']][process][plot_dict['cut'],::style_dict['rebin']]
#     895     # set x range manually
#     896     if style_dict['xlim'] != None:
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324, in BaseHist.__getitem__(self, index)
#     317 def __getitem__(  # type: ignore[override]
#     318     self: T, index: IndexingExpr
#     319 ) -> T | float | bh.accumulators.Accumulator:
#     320     """
#     321     Get histogram item.
#     322     """
# --> 324     return super().__getitem__(self._index_transform(index))
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:842, in Histogram.__getitem__(self, index)
#     838 def __getitem__(  # noqa: C901
#     839     self: H, index: IndexingExpr
#     840 ) -> Union[H, float, Accumulator]:
# --> 842     indexes = self._compute_commonindex(index)
#     844     # If this is (now) all integers, return the bin contents
#     845     # But don't try *dict!
#     846     if not hasattr(indexes, "items") and all(
#     847         isinstance(a, SupportsIndex) for a in indexes
#     848     ):
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:750, in Histogram._compute_commonindex(self, index)
#     748         indexes[i] = [self._compute_uhi_index(ind, i) for ind in indexes[i]]
#     749     else:
# --> 750         indexes[i] = self._compute_uhi_index(indexes[i], i)
#     752 return indexes
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:702, in Histogram._compute_uhi_index(self, index, axis)
#     698 # General locators
#     699 # Note that MyPy doesn't like these very much - the fix
#     700 # will be to properly set input types
#     701 if callable(index):
# --> 702     return index(self.axes[axis])
#     704 if isinstance(index, float):  # type: ignore[unreachable]
#     705     raise TypeError(f"Index {index} must be an integer, not float")
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/tag.py:73, in loc.__call__(self, axis)
#      72 def __call__(self, axis: AxisLike) -> int:
# ---> 73     return axis.index(self.value) + self.offset
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/axis.py:669, in StrCategory.index(self, value)
#     664 """
#     665 Return the fractional index(es) given a value (or values) on the axis.
#     666 """
#     668 if _isstr(value):
# --> 669     return self._ax.index(value)  # type: ignore[no-any-return]
#     671 msg = f"index({value}) must be a string or iterable of strings for a StrCategory axis"
#     672 raise TypeError(msg)
#
# KeyError: "'cut10' not in axis"

# %%
variable = 'sel_vtx_ThetaColl_fromPV_refit_rad'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 25j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.25',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 32
#       7 plot_dict = {
#       8     'variable': variable,
#       9     'cut': cut,
#      10     'year': 2018
#      11 }
#      13 style_dict = {
#      14     'fig': fig,
#      15     'ax': ax,
#    (...)
#      29     'outName': f'data_VR1_{variable}_{cut}.png'
#      30 }
# ---> 32 ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
#
# File /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/ABCD_studies/../../analysisTools/plotTools.py:1701, in plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
#    1698 fig = style_dict['fig']
#    1699 ax = style_dict['ax']
# -> 1701 plot_bkg_1d(bkg_histo, plot_dict, style_dict, processes = 'all')
#    1702 plot_bkg_1d_stacked_errbar(bkg_histo, plot_dict, style_dict, processes = 'all')
#    1703 plot_data_1d(data_histo, plot_dict, style_dict)
#
# File /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/ABCD_studies/../../analysisTools/plotTools.py:893, in plot_bkg_1d(bkg_histos, plot_dict, style_dict, isLegacy, processes)
#     891 # add histos to stack after rebinning and range setting
#     892 for process in sorted_entries.keys():
# --> 893     bkg[plot_dict['variable']][process] = bkg[plot_dict['variable']][process][plot_dict['cut'],::style_dict['rebin']]
#     895     # set x range manually
#     896     if style_dict['xlim'] != None:
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/hist/basehist.py:324, in BaseHist.__getitem__(self, index)
#     317 def __getitem__(  # type: ignore[override]
#     318     self: T, index: IndexingExpr
#     319 ) -> T | float | bh.accumulators.Accumulator:
#     320     """
#     321     Get histogram item.
#     322     """
# --> 324     return super().__getitem__(self._index_transform(index))
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:842, in Histogram.__getitem__(self, index)
#     838 def __getitem__(  # noqa: C901
#     839     self: H, index: IndexingExpr
#     840 ) -> Union[H, float, Accumulator]:
# --> 842     indexes = self._compute_commonindex(index)
#     844     # If this is (now) all integers, return the bin contents
#     845     # But don't try *dict!
#     846     if not hasattr(indexes, "items") and all(
#     847         isinstance(a, SupportsIndex) for a in indexes
#     848     ):
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:750, in Histogram._compute_commonindex(self, index)
#     748         indexes[i] = [self._compute_uhi_index(ind, i) for ind in indexes[i]]
#     749     else:
# --> 750         indexes[i] = self._compute_uhi_index(indexes[i], i)
#     752 return indexes
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/hist.py:702, in Histogram._compute_uhi_index(self, index, axis)
#     698 # General locators
#     699 # Note that MyPy doesn't like these very much - the fix
#     700 # will be to properly set input types
#     701 if callable(index):
# --> 702     return index(self.axes[axis])
#     704 if isinstance(index, float):  # type: ignore[unreachable]
#     705     raise TypeError(f"Index {index} must be an integer, not float")
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/tag.py:73, in loc.__call__(self, axis)
#      72 def __call__(self, axis: AxisLike) -> int:
# ---> 73     return axis.index(self.value) + self.offset
#
# File ~/nobackup/miniconda3/envs/debug/lib/python3.8/site-packages/boost_histogram/_internal/axis.py:669, in StrCategory.index(self, value)
#     664 """
#     665 Return the fractional index(es) given a value (or values) on the axis.
#     666 """
#     668 if _isstr(value):
# --> 669     return self._ax.index(value)  # type: ignore[no-any-return]
#     671 msg = f"index({value}) must be a string or iterable of strings for a StrCategory axis"
#     672 raise TypeError(msg)
#
# KeyError: "'cut10' not in axis"

# %%
variable = 'bdtscore'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'BDT score',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots//data_VR1_bdtscore_cut10.png
# Saved: ./plots//data_VR1_bdtscore_cut10.png
# Saved: ./plots//data_VR1_bdtscore_cut10.png

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut10'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 5j,
    'yrebin': 35j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
#ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')

plt.title(rf"All backgrounds", position=(0.8, 0.5))
plt.vlines(0.965, 0, 180, color='red', linewidth=2)
plt.hlines(1.22, 0, 1, color='red', linewidth=2)

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut10'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 25j,
    'yrebin': 25j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': 'BDT score',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_ABCD.png'
}

# Data
style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))

plt.title(rf"Data", position=(0.95, 0.5))
plt.vlines(0.96, 0, 180, color='red', linewidth=2)
plt.hlines(1.22, 0, 1, color='red', linewidth=2)


plt.text(0.5, 2.2, 'C', color='red', fontsize=20)
plt.text(0.5, 0.6, 'D', color='red', fontsize=20)

plt.text(0.97, 2.2, 'B', color='red', fontsize=20)
plt.text(0.97, 0.6, 'A', color='red', fontsize=20)

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# Saved: ./plots//data_VR1_ABCD.png

# %%
run = ['data_2018_Data_MET_UL18_MET_Run2018D', \
       'data_2018_Data_MET_UL18_MET_Run2018C', \
       'data_2018_Data_MET_UL18_MET_Run2018B', \
       'data_2018_Data_MET_UL18_MET_Run2018A']

cut = 'cut10'

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'][{"samp":run[0], "cut": cut}][:98,122:]
# Out:
# Hist(
#   Regular(98, 0, 0.098, name='bdtscore'),
#   Regular(193, 1.22, 3.15, name='theta_rad'),
#   storage=Weight()) # Sum: WeightedSum(value=1205, variance=1205) (WeightedSum(value=4345, variance=4345) with flow)

# %%
bdt_tightWP = 980
theta_WP = 122 # 70 deg, 1.22 rad

# %%
nC = 0

for idx, era in enumerate(run):
    nC += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'][{"samp":run[idx], "cut": cut}][:bdt_tightWP,theta_WP:].sum().value
    print(era)

print(nC)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 4289.0

# %%
nB = 0

for idx, era in enumerate(run):
    nB += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'][{"samp":run[idx], "cut": cut}][bdt_tightWP:,theta_WP:].sum().value
    print(era)

print(nB)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 13.0

# %%
nD = 0

for idx, era in enumerate(run):
    nD += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'][{"samp":run[idx], "cut": cut}][:bdt_tightWP,:theta_WP].sum().value
    print(era)

print(nD)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 3411.0

# %%
nA = 0

for idx, era in enumerate(run):
    nA += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'][{"samp":run[idx], "cut": cut}][bdt_tightWP:,:theta_WP].sum().value
    print(era)

print(nA)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 10.0

# %%
pred = nD*(nB/nC)
pred
# Out:
# 10.338773606901375

# %%
obs = nA
obs
# Out:
# 10.0

# %%
obs_err = np.sqrt(obs)

# %%
obs_err
# Out:
# 3.1622776601683795

# %%
pred_err = pred * np.sqrt((np.sqrt(nD)/nD)**2 + (np.sqrt(nB)/nB)**2 + (np.sqrt(nC)/nC)**2)

# %%
pred_err
# Out:
# 2.8772530304270547

# %% [markdown]
# ## Background

# %%
cut
# Out:
# 'cut10'

# %%
variable
# Out:
# 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit_rad'

# %%
processes = list(set(utils.get_bkg_point_dict(bkg_histo).loc[:, 'Process']))
        
subprocess = {process: [] for process in processes} # initialize the dictionary of bkg processes
        
availSubCat = list(bkg_histo[variable].axes['samp']) # get the list of subprocesses available for the histogram
for samp in availSubCat:
    process = utils.get_bkg_point_dict(bkg_histo).loc[samp][0]            
    if process in processes:
        subprocess[process].append(samp) # fill out the bkg process list with the available subprocesses
            
# Get histogram for each process
bkg={}
bkg[variable] = {process:bkg_histo[variable][{"samp":subprocess[process]}][{"samp": sum}] for process in processes}
        
# sort the histograms by the entries and stack
for process in processes:
    entries = {process: bkg[plot_dict['variable']][process].sum().value for process in processes}
        
sorted_entries = dict(sorted(entries.items(), key=lambda x:x[1], reverse = False))

bkg_stack = {}
        
# add histos to stack after rebinning and range setting
for idx, process in enumerate(sorted_entries.keys()):
    bkg[variable][process] = bkg[variable][process][cut,::1j,::1j]
        
    if idx == 0:
        bkg_stack = bkg[plot_dict['variable']][process]
    else:
        bkg_stack += bkg[plot_dict['variable']][process]

# %%
bkg_stack
# Out:
# Hist(
#   Regular(1000, 0, 1, name='bdtscore'),
#   Regular(315, 0, 3.15, name='theta_rad'),
#   storage=Weight()) # Sum: WeightedSum(value=6132.74, variance=2853.72) (WeightedSum(value=6135, variance=2854.47) with flow)

# %%
bdt_tightWP = 980
theta_WP = 122 # 70 deg, 1.22 rad

# %%
nC = bkg_stack[:bdt_tightWP,theta_WP:].sum().value

print(nC)
# Out:
# 3436.4587214162893

# %%
nB = bkg_stack[bdt_tightWP:,theta_WP:].sum().value

print(nB)
# Out:
# 12.264978866558522

# %%
nD = bkg_stack[:bdt_tightWP,:theta_WP].sum().value

print(nD)
# Out:
# 2675.224629014796

# %%
nA = bkg_stack[bdt_tightWP:,:theta_WP].sum().value

print(nA)
# Out:
# 8.787663308903575

# %%
pred = nD*(nB/nC)
pred
# Out:
# 9.548077308095962

# %%
obs = nA

# %%
obs_err = np.sqrt(obs)

# %%
obs_err
# Out:
# 2.964399316708796

# %%
pred_err = pred * np.sqrt((np.sqrt(nD)/nD)**2 + (np.sqrt(nB)/nB)**2 + (np.sqrt(nC)/nC)**2)

# %%
pred_err
# Out:
# 2.737448169087448
