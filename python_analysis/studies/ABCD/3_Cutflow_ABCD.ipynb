# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'

suffix = 'BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF'

# %%
# Signal
sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
sig_histo2 = util.load(f'{prefix}/signal_BDT_ABCD_goodvtx_v10_NJetG0L3_OSSF.coffea')[0]

# %% [markdown]
# ## Signal

# %%
sig_samples = list(sig_histo['cutflow'].keys())
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
cutnames = utils.get_signal_list_of_cuts(sig_histo)
cutnames
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'Leading jet pT > 80 GeV',
#  'Leading jet |eta| < 2.4',
#  'dPhi(MET,leading jet) > 2.0',
#  'dPhi(MET,all jets) > 0.75',
#  'OSSF',
#  'theta < 90',
#  'BDT']

# %%
# Efficiency
pd.options.display.float_format = '{:,.6f}'.format
eff_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow')

# %%
table = eff_cutflow
table.columns = cutnames

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_Efficiency'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_Efficiency.csv

# %%
# Weighted event count
pd.options.display.float_format = '{:,.4f}'.format
cts_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

# %%
table = cts_cutflow
table.columns = cutnames

# %%
# ctau = 1mm
ct = 1.0

points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
df
# Out:
#                                        Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.1691             27.5180
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       1,156.9315            666.7773
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       1,457.7156            827.0445
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1         74.7132             45.9089
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       1,964.2733          1,102.7526
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       2,725.2304          1,478.2941
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        1,620.1785            714.5297
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      33,765.0692         11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        167.4818            107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       4,184.6540          2,237.3733
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         403.5456            244.8587
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1      38,528.4000         22,915.1867
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1      20,174.8511         10,418.8342
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       9,916.8019          5,387.4485
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1      17,929.3616          8,851.4651
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         734.2812            421.4102
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         937.0399            499.5261
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.4857            540.0955
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.0246             21.2724
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1      22,229.4245          9,901.6350
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   27.4900
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   666.1743
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   825.9792
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   45.8901
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,102.0333
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,477.9960
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    714.5297
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,234.0401
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   244.4996
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,892.5142
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,405.9473
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,383.4982
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,828.4275
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   421.2750
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   499.3174
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 539.0392
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  21.2434
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,887.5434
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   44.1806
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,064.7355
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,424.9048
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    687.9354
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   236.3616
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,128.9703
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,178.4167
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,552.3517
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   404.3941
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   479.1320
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  20.5304
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,535.0728
#
#                                        dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       44.1744
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     1,064.7355
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     1,424.9048
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        687.9354
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                      103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       236.3616
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    10,128.9703
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     5,178.4167
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     8,552.3517
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       404.3941
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       479.1320
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                      20.5304
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     9,535.0728
#
#                                        dPhi(MET,all jets) > 0.75        OSSF  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                     26.2251     25.5668
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     635.0341    617.6829
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     787.3198    767.1020
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     43.5820     42.4655
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   1,050.8564  1,018.2555
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   1,406.4192  1,361.3700
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      680.3314    656.2454
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  10,978.4487 10,359.8293
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    102.3719     99.0149
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   2,126.5131  2,065.1446
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     232.8919    227.1468
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  21,771.3799 21,199.8001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  10,048.4450  9,726.3932
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   5,132.4027  4,964.1828
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   8,441.2445  8,180.3395
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     399.9393    388.0637
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     474.5553    461.0280
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   512.6493    502.1014
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                    20.2922     19.8342
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   9,422.3953  8,975.8855
#
#                                        theta < 90         BDT
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      22.4717     13.7269
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1      562.8351    407.0971
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1      705.7314    525.7613
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      38.6537     27.3563
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1      948.3520    740.9489
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1    1,279.0566  1,021.3892
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1       631.5549    536.5508
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1    9,706.0387  7,247.7758
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1      93.3244     78.3235
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1    1,959.9698  1,645.4519
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1      217.4534    184.3598
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1   20,322.7088 17,848.4130
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    9,217.7674  8,081.5284
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    4,710.4619  4,099.3572
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    7,819.9660  6,961.0950
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1      372.5339    335.1199
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1      443.3506    393.0100
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1    451.6573    308.7564
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     17.1425      9.9706
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    8,487.0062  7,283.9510

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_EventCount_Weighted'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_EventCount_Weighted.csv

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_Raw'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_Raw.csv

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [5, 10, 20, 30, 40],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_SR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m5to40.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_100_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_100_m5to40.png

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [50, 70, 90, 100],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_SR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m50to100.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_100_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'theta < 90', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_100_m50to100.png

# %% [markdown]
# ## Signal purity

# %%
purity_v11 = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')

# %%
purity_v11_reco = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched_fromReco')

# %%
purity_v10 = utils.get_signal_cutflow_dict(sig_histo2, 'cutflow_vtx_matched')

# %%
purity_v10_reco = utils.get_signal_cutflow_dict(sig_histo2, 'cutflow_vtx_matched_fromReco')

# %%
ct = 10
delta = 0.2

# %%
table = purity_v11

points = ((si["ctau"] == ct) & (si['delta'] == delta))

df = table.loc[list(si[points].name)]
df = utils.add_signal_info_to_df(df)

purity_v11_beforeOSSF = df['dPhi(MET,all jets) > 0.75'].to_list()
purity_v11_afterOSSF = df['OSSF'].to_list()
m_list = df['m1'].to_list()

# %%
table = purity_v10

points = ((si["ctau"] == ct) & (si['delta'] == delta))

df = table.loc[list(si[points].name)]
df = utils.add_signal_info_to_df(df)

purity_v10_beforeOSSF = df['dPhi(MET,all jets) > 0.75'].to_list()
purity_v10_afterOSSF = df['OSSF'].to_list()
m_list = df['m1'].to_list()

# %%
plt.plot(m_list, purity_v10_beforeOSSF, '-', color='blue', label='With OSSF in good_vtx def.')
plt.plot(m_list, purity_v11_beforeOSSF, '-', color='red', label='Without OSSF in good_vtx def.')
plt.plot(m_list, purity_v11_afterOSSF, 'o', color='red', label='Without OSSF in good_vtx def. + OSSF cut in SR')


plt.grid()
plt.ylim([0.5,1.01])

plt.xlabel('M1 [GeV]')
plt.ylabel('Purity = (Selected Vertex is True Vertex)/(All events after the cut)')

plt.legend()

plt.title(rf"$\Delta$={delta}, {ct}mm")
# Out:
# Text(0.5, 1.0, '$\\Delta$=0.2, 10mm')

# %%
table = purity_v11_reco

points = ((si["ctau"] == ct) & (si['delta'] == delta))

df = table.loc[list(si[points].name)]
df = utils.add_signal_info_to_df(df)

purity_v11_reco_beforeOSSF = df['dPhi(MET,all jets) > 0.75'].to_list()
purity_v11_reco_afterOSSF = df['OSSF'].to_list()
m_list = df['m1'].to_list()

# %%
table = purity_v10_reco

points = ((si["ctau"] == ct) & (si['delta'] == delta))

df = table.loc[list(si[points].name)]
df = utils.add_signal_info_to_df(df)

purity_v10_reco_beforeOSSF = df['dPhi(MET,all jets) > 0.75'].to_list()
purity_v10_reco_afterOSSF = df['OSSF'].to_list()
m_list = df['m1'].to_list()

# %%
plt.plot(m_list, purity_v10_reco_beforeOSSF, '-', color='blue', label='With OSSF in good_vtx def.')
plt.plot(m_list, purity_v11_reco_beforeOSSF, '-', color='red', label='Without OSSF in good_vtx def.')
plt.plot(m_list, purity_v11_reco_afterOSSF, 'o', color='red', label='Without OSSF in good_vtx def. + OSSF cut in SR')

plt.grid()
plt.ylim([0.8,1.01])

plt.xlabel('M1 [GeV]')
plt.ylabel('Purity = (Selected Vertex is True Vertex)/(Events with ee reconstructed)')

plt.legend()

plt.title(rf"$\Delta$={delta}, {ct}mm")
# Out:
# Text(0.5, 1.0, '$\\Delta$=0.2, 10mm')

# %% [markdown]
# ## Background

# %%
# efficiency
pd.options.display.float_format = '{:,.8f}'.format

bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow')
bkg_eff_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# QCD            0.00000249          0.00000001               0.00000001
# DY             0.00018701          0.00001151               0.00001141
# ZGamma         0.00032468          0.00001653               0.00001398
# Top            0.00039885          0.00001298               0.00001210
# Multiboson     0.00065832          0.00003441               0.00003004
# WJets          0.00101318          0.00003720               0.00003665
# ZJets          0.00242159          0.00007613               0.00007541
# Total          0.00001696          0.00000054               0.00000052
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# QCD                      0.00000001                   0.00000001
# DY                       0.00001094                   0.00001083
# ZGamma                   0.00001313                   0.00001310
# Top                      0.00001090                   0.00001077
# Multiboson               0.00002763                   0.00002678
# WJets                    0.00003480                   0.00003459
# ZJets                    0.00007141                   0.00007118
# Total                    0.00000049                   0.00000049
#
#             dPhi(MET,all jets) > 0.75       OSSF  theta < 90        BDT
# QCD                        0.00000000 0.00000000  0.00000000 0.00000000
# DY                         0.00000952 0.00000760  0.00000409 0.00000026
# ZGamma                     0.00001314 0.00000881  0.00000508 0.00000003
# Top                        0.00000985 0.00000627  0.00000334 0.00000009
# Multiboson                 0.00002517 0.00001774  0.00000845 0.00000000
# WJets                      0.00003180 0.00001672  0.00000861 0.00000024
# ZJets                      0.00006654 0.00003517  0.00001819 0.00000071
# Total                      0.00000044 0.00000024  0.00000013 0.00000000

# %%
# Save as csv
outdir = f'./csv/{suffix}/Cutflow/Efficiency/'
outname = f'Background_Efficiency'

df_to_save = bkg_eff_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF/Cutflow/Efficiency//Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_cts_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# QCD             53,432.27                            275.55
# DY               5,819.49                            358.21
# ZGamma           1,665.13                             84.77
# Top             26,174.93                            851.60
# Multiboson       4,588.16                            239.80
# WJets          214,692.24                          7,883.42
# ZJets           63,745.58                          2,003.91
# Total          370,117.80                         11,697.26
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# QCD                          275.55                   214.93
# DY                           355.08                   340.58
# ZGamma                        71.71                    67.31
# Top                          793.75                   715.64
# Multiboson                   209.34                   192.59
# WJets                      7,765.40                 7,373.78
# ZJets                      1,985.06                 1,879.87
# Total                     11,455.88                10,784.71
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75     OSSF  \
# QCD                              206.03                      32.90    16.05
# DY                               337.02                     296.39   236.56
# ZGamma                            67.20                      67.41    45.16
# Top                              706.97                     646.17   411.66
# Multiboson                       186.67                     175.45   123.66
# WJets                          7,330.01                   6,739.24 3,542.39
# ZJets                          1,873.73                   1,751.69   925.74
# Total                         10,707.63                   9,709.25 5,301.23
#
#             theta < 90   BDT
# QCD               0.00  0.00
# DY              127.32  8.13
# ZGamma           26.04  0.16
# Top             219.46  6.15
# Multiboson       58.88  0.00
# WJets         1,824.85 50.60
# ZJets           478.94 18.73
# Total         2,735.49 83.77

# %%
# Save to csv
outdir = f'./csv/{suffix}/Cutflow/EventCount_Weighted/'
outname = f'Background_EventCount_Weighted'

df_to_save = bkg_cts_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF/Cutflow/EventCount_Weighted//Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# QCD                 31490                  92                       92
# DY                 296131                7134                     7103
# ZGamma               6506                 343                      307
# Top                703976               21950                    20178
# Multiboson          25187                1310                     1106
# WJets             1177020               21199                    20944
# ZJets              738994               12563                    12452
# Total             2979304               64591                    62182
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# QCD                              90                           88
# DY                             6985                         6640
# ZGamma                          292                          279
# Top                           18131                        17729
# Multiboson                     1027                          966
# WJets                         20158                        19793
# ZJets                         11965                        11824
# Total                         58648                        57319
#
#             dPhi(MET,all jets) > 0.75   OSSF  theta < 90  BDT
# QCD                                 6      2           0    0
# DY                               4563   3734        1970  100
# ZGamma                            252    158          85    1
# Top                             16114  10382        5535  128
# Multiboson                        905    641         305    0
# WJets                           16850   8815        4576  130
# ZJets                           10144   5327        2756  108
# Total                           48834  29059       15227  467

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# QCD                 31490                                92
# DY                 296131                              7134
# ZGamma               6506                               343
# Top                703976                             21950
# Multiboson          25187                              1310
# WJets             1177020                             21199
# ZJets              738994                             12563
# Total             2979304                             64591
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# QCD                              92                       90
# DY                             7103                     6985
# ZGamma                          307                      292
# Top                           20178                    18131
# Multiboson                     1106                     1027
# WJets                         20944                    20158
# ZJets                         12452                    11965
# Total                         62182                    58648
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75   OSSF  \
# QCD                                  88                          6      2
# DY                                 6640                       4563   3734
# ZGamma                              279                        252    158
# Top                               17729                      16114  10382
# Multiboson                          966                        905    641
# WJets                             19793                      16850   8815
# ZJets                             11824                      10144   5327
# Total                             57319                      48834  29059
#
#             theta < 90  BDT
# QCD                  0    0
# DY                1970  100
# ZGamma              85    1
# Top               5535  128
# Multiboson         305    0
# WJets             4576  130
# ZJets             2756  108
# Total            15227  467

# %%
outdir = f'./csv/{suffix}/Cutflow/EventCount_Raw/'
outname = f'Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF/Cutflow/EventCount_Raw//Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 83.77

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df[bkg_cts_df.columns.values[-1]]).transpose(), pd.DataFrame(bkg_cts_raw_df[bkg_cts_df.columns.values[-1]]).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  QCD     DY  ZGamma    Top  Multiboson  WJets  ZJets  Total
# Weighted Counts 0.00   8.13    0.16   6.15        0.00  50.60  18.73  83.77
# Raw Counts      0.00 100.00    1.00 128.00        0.00 130.00 108.00 467.00

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df[bkg_cts_df.columns.values[-3]]).transpose(), pd.DataFrame(bkg_cts_raw_df[bkg_cts_df.columns.values[-3]]).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                   QCD       DY  ZGamma       Top  Multiboson    WJets  \
# Weighted Counts 16.05   236.56   45.16    411.66      123.66 3,542.39
# Raw Counts       2.00 3,734.00  158.00 10,382.00      641.00 8,815.00
#
#                    ZJets     Total
# Weighted Counts   925.74  5,301.23
# Raw Counts      5,327.00 29,059.00

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF/cutflow//Cutflow_background.png

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/BDT_ABCD_goodvtx_v11_NJetG0L3_OSSF/cutflow//Cutflow_background.png

# %% [markdown]
# ## S/B

# %%
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
nBkg = bkg_cts_df.loc['Total'][-1]

nBkg
# Out:
# 83.77390549330343

# %%
cts_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
table = cts_cutflow

cutnames = utils.get_signal_list_of_cuts(sig_histo)
table.columns = cutnames

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
df = pd.DataFrame(table.loc[:, cutnames[-1]]) # last cut
df = utils.add_signal_info_to_df(df)
df
# Out:
#                                                BDT       m1  delta     ctau
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100       6.3250   5.0000 0.1000 100.0000
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10      400.1640   5.0000 0.1000  10.0000
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1     7,247.7758   5.0000 0.1000   1.0000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        536.5508   5.0000 0.2000   1.0000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10        23.3508   5.0000 0.2000  10.0000
# ...                                            ...      ...    ...      ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10      1.0734 100.0000 0.2000  10.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     308.7564 100.0000 0.1000   1.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     0.9779 100.0000 0.1000 100.0000
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       9.9706 100.0000 0.2000   1.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10     29.2401 100.0000 0.1000  10.0000
#
# [62 rows x 4 columns]

# %%
# Missing rows
#df[ (df['m1'] == 60) & (df['delta'] == 0.2) ]

df.loc[len(df.index)] = [0, 60, 0.2, 1]
df.loc[len(df.index)] = [0, 60, 0.2, 10]
df.loc[len(df.index)] = [0, 60, 0.2, 100]
df.loc[len(df.index)] = [0, 80, 0.2, 1] 

df = df.sort_values(by=['m1']) # sort by m1

# %%
df = df.rename(columns={df.columns[0]: 'Signal'})

df['Background'] = nBkg
df['S/sqrt(B)'] = df['Signal'] / np.sqrt(df['Background'])

df = df[['m1', 'delta', 'ctau', 'Signal', 'Background', 'S/sqrt(B)']]

df
# Out:
#                                               m1  delta     ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100     5.0000 0.1000 100.0000     6.3250
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10      5.0000 0.1000  10.0000   400.1640
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       5.0000 0.1000   1.0000 7,247.7758
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        5.0000 0.2000   1.0000   536.5508
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10       5.0000 0.2000  10.0000    23.3508
# ...                                          ...    ...      ...        ...
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1   100.0000 0.1000   1.0000   308.7564
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100 100.0000 0.1000 100.0000     0.9779
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1   100.0000 0.2000   1.0000     9.9706
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10  100.0000 0.1000  10.0000    29.2401
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10  100.0000 0.2000  10.0000     1.0734
#
#                                          Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100       83.7739     0.6910
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10        83.7739    43.7203
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1         83.7739   791.8636
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          83.7739    58.6214
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10         83.7739     2.5512
# ...                                             ...        ...
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       83.7739    33.7335
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     83.7739     0.1068
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       83.7739     1.0893
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10      83.7739     3.1947
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10      83.7739     0.1173
#
# [66 rows x 6 columns]

# %%
outdir = './csv/SR_Yields/'
outname = f'SR_S_over_B'

df_to_save = df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/SR_Yields//SR_S_over_B.csv

# %%
ct = 1.0

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.1
delta = 0.1

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      5.0   0.1  1.0 7,247.7758
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1     10.0   0.1  1.0 7,283.9510
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1     20.0   0.1  1.0 6,961.0950
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1     30.0   0.1  1.0 8,081.5284
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1     40.0   0.1  1.0 4,099.3572
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1     50.0   0.1  1.0 1,645.4519
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1     60.0   0.1  1.0 1,021.3892
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1     70.0   0.1  1.0   740.9489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1     80.0   0.1  1.0   525.7613
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1     90.0   0.1  1.0   407.0971
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1  100.0   0.1  1.0   308.7564
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       83.7739   791.8636
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       83.7739   795.8159
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       83.7739   760.5420
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       83.7739   882.9561
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       83.7739   447.8797
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       83.7739   179.7756
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       83.7739   111.5930
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       83.7739    80.9532
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       83.7739    57.4426
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       83.7739    44.4778
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     83.7739    33.7335

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.2
delta = 0.2

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau      Signal  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1       5.0   0.2  1.0    536.5508
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     10.0   0.2  1.0    393.0100
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1     20.0   0.2  1.0    335.1199
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1     30.0   0.2  1.0 17,848.4130
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1     40.0   0.2  1.0    184.3598
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1    50.0   0.2  1.0     78.3235
# 62                                      60.0   0.2  1.0      0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1    70.0   0.2  1.0     27.3563
# 65                                      80.0   0.2  1.0      0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1    90.0   0.2  1.0     13.7269
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1  100.0   0.2  1.0      9.9706
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        83.7739    58.6214
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1       83.7739    42.9387
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1       83.7739    36.6139
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1       83.7739 1,950.0477
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1       83.7739    20.1424
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1      83.7739     8.5573
# 62                                        83.7739     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1      83.7739     2.9888
# 65                                        83.7739     0.0000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1      83.7739     1.4997
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1     83.7739     1.0893

# %%
ct = 10.0

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.1
delta = 0.1

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                            m1 delta  ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10      5.0   0.1  10.0   400.1640
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10     10.0   0.1  10.0   451.0674
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10     20.0   0.1  10.0   538.6863
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10     30.0   0.1  10.0 5,438.2412
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10     40.0   0.1  10.0   341.4805
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10     50.0   0.1  10.0   138.4658
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-10     60.0   0.1  10.0    88.7198
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-10     70.0   0.1  10.0    64.9506
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-10     80.0   0.1  10.0    48.7321
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-10     90.0   0.1  10.0    37.7400
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10  100.0   0.1  10.0    29.2401
#
#                                         Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10       83.7739    43.7203
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10       83.7739    49.2819
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10       83.7739    58.8548
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10       83.7739   594.1609
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10       83.7739    37.3088
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10       83.7739    15.1282
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-10       83.7739     9.6932
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-10       83.7739     7.0962
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-10       83.7739     5.3243
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-10       83.7739     4.1233
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10     83.7739     3.1947

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.2
delta = 0.2

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                            m1 delta  ctau     Signal  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10       5.0   0.2  10.0    23.3508
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10     10.0   0.2  10.0    20.7131
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10     20.0   0.2  10.0    21.6613
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10     30.0   0.2  10.0 4,101.9836
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10     40.0   0.2  10.0    13.5477
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10    50.0   0.2  10.0     5.4253
# 63                                       60.0   0.2  10.0     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-10    70.0   0.2  10.0     2.4459
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-10    80.0   0.2  10.0     1.7710
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10    90.0   0.2  10.0     1.3782
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10  100.0   0.2  10.0     1.0734
#
#                                         Background  S/sqrt(B)
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10        83.7739     2.5512
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10       83.7739     2.2630
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10       83.7739     2.3666
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10       83.7739   448.1667
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10       83.7739     1.4802
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10      83.7739     0.5927
# 63                                         83.7739     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-10      83.7739     0.2672
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-10      83.7739     0.1935
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10      83.7739     0.1506
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10     83.7739     0.1173

# %%
ct = 100.0

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.1
delta = 0.1

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                             m1 delta   ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100      5.0   0.1  100.0     6.3250
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100     10.0   0.1  100.0     8.1649
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100     20.0   0.1  100.0    11.5796
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100     30.0   0.1  100.0 1,727.9457
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100     40.0   0.1  100.0     8.5982
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100     50.0   0.1  100.0     3.8794
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-100     60.0   0.1  100.0     2.6289
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-100     70.0   0.1  100.0     1.8927
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-100     80.0   0.1  100.0     1.5109
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100     90.0   0.1  100.0     1.2161
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100  100.0   0.1  100.0     0.9779
#
#                                          Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100       83.7739     0.6910
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100       83.7739     0.8921
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100       83.7739     1.2651
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100       83.7739   188.7886
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100       83.7739     0.9394
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100       83.7739     0.4238
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-100       83.7739     0.2872
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-100       83.7739     0.2068
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-100       83.7739     0.1651
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100       83.7739     0.1329
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     83.7739     0.1068

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.2
delta = 0.2

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                             m1 delta   ctau   Signal  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100       5.0   0.2  100.0   0.3033
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100     10.0   0.2  100.0   0.3698
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100     20.0   0.2  100.0   0.4998
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100     30.0   0.2  100.0 118.5879
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100     40.0   0.2  100.0   0.3541
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100    50.0   0.2  100.0   0.1557
# 64                                        60.0   0.2  100.0   0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-100    70.0   0.2  100.0   0.0729
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100    80.0   0.2  100.0   0.0617
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100    90.0   0.2  100.0   0.0461
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-100  100.0   0.2  100.0   0.0377
#
#                                          Background  S/sqrt(B)
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100        83.7739     0.0331
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100       83.7739     0.0404
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100       83.7739     0.0546
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100       83.7739    12.9565
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100       83.7739     0.0387
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100      83.7739     0.0170
# 64                                          83.7739     0.0000
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-100      83.7739     0.0080
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100      83.7739     0.0067
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100      83.7739     0.0050
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-100     83.7739     0.0041
