# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = 'BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF'

# %%
# Signal
sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
# sig_histo / bkg_histo is a dictionary of variables
print(bkg_histo.keys())
# Out:
# dict_keys(['sel_e1_pt', 'sel_e1_eta', 'sel_e1_phi', 'sel_e1_dxy', 'sel_e1_dxySignif', 'sel_e1_vxy1', 'sel_e1_vz', 'sel_e2_pt', 'sel_e2_eta', 'sel_e2_phi', 'sel_e2_dxy', 'sel_e2_dxySignif', 'sel_e2_vxy1', 'sel_e2_vz', 'sel_e1_dxy_fromPV', 'sel_e2_dxy_fromPV', 'sel_vtx_dR', 'sel_vtx_mindxy', 'sel_vtx_vxy1', 'sel_vtx_vxy10', 'sel_vtx_vxy100', 'sel_vtx_leadpT', 'sel_vtx_METdPhi', 'sel_vtx_mindRj', 'sel_vtx_chi2', 'sel_vtx_mass', 'sel_vtx_mindPhiJ', 'sel_vtx_sign', 'sel_vtx_pt', 'sel_vtx_eta', 'sel_vtx_phi', 'sel_vtx_type', 'sel_vtx_minEleDrJ', 'sel_vtx_minEleDPhiJ', 'sel_vtx_mass_low', 'sel_vtx_mindxy_low', 'sel_vtx_sign_etaProd', 'sel_vtx_LxyCosThetaColl', 'sel_vtx_LxyCosThetaCollZoom', 'sel_vtx_LxyCosThetaCollZoomZoom', 'sel_vtx_eleDphi', 'sel_vtx_maxMiniRelIso', 'sel_vtx_maxMiniRelIsoCorr', 'sel_vtx_mass_refit', 'sel_vtx_mass_low_refit', 'sel_vtx_pt_refit', 'sel_vtx_eta_refit', 'sel_vtx_phi_refit', 'sel_vtx_dR_refit', 'sel_vtx_mass_refit_vs_sel_vtx_mass', 'sel_vtx_mass_low_refit_vs_sel_vtx_mass_low', 'sel_vtx_pt_refit_vs_sel_vtx_pt', 'sel_vtx_eta_refit_vs_sel_vtx_eta', 'sel_vtx_phi_refit_vs_sel_vtx_phi', 'sel_vtx_dR_refit_vs_sel_vtx_dR', 'sel_vtx_mass_vs_vxy', 'sel_vtx_mass_refit_vs_vxy', 'sel_e1_phi_vs_METphi', 'sel_e1_phi_vs_sel_e1_eta', 'sel_e1_phi_vs_sel_e1_pt', 'sel_e2_phi_vs_METphi', 'sel_e2_phi_vs_sel_e2_eta', 'sel_e2_phi_vs_sel_e2_pt', 'sel_vtx_phi_vs_sel_vtx_eta', 'sel_vtx_phi_vs_sel_vtx_pt', 'sel_vtx_phi_vs_sel_vtx_dR', 'sel_vtx_phi_vs_sel_vtx_pt800', 'sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom', 'sel_e1_phi_zoom_vs_sel_e1_eta', 'sel_e2_phi_zoom_vs_sel_e2_eta', 'sel_vtx_phi_vs_METphi', 'sel_vtx_phi_vs_lead_jet_phi', 'sel_vtx_phi_refit_vs_METphi', 'sel_vtx_phi_refit_vs_lead_jet_phi', 'METphi_vs_lead_jet_phi', 'sel_vtx_phi_refit_over_phi', 'sel_vtx_vx_vs_vy', 'PVx_vs_PVy', 'PFMET', 'PFMET1000', 'PFMETphi', 'jetMETdPhi', 'minJetMETdPhi', 'nJets', 'lead_jet_pt', 'lead_jet_eta', 'lead_jet_phi', 'jetMETratio', 'lead_jet_phi_vs_lead_jet_eta', 'PVx', 'PVy', 'sel_vtx_CosThetaColl', 'sel_vtx_ThetaColl_fromPV_refit', 'sel_vtx_ThetaColl_fromPV', 'sel_vtx_CosThetaColl_fromPV', 'sel_vtx_CosThetaColl_fromPV_refit', 'sel_vtx_GenCosThetaColl', 'sel_vtx_GenThetaColl', 'sel_vtx_GenCosThetaColl_vs_sel_vtx_CosThetaColl_fromPV', 'sel_vtx_GenCosThetaColl_vs_sel_vtx_CosThetaColl_fromPV_refit', 'sel_vtx_GenThetaColl_vs_sel_vtx_ThetaColl_fromPV', 'sel_vtx_GenThetaColl_vs_sel_vtx_ThetaColl_fromPV_refit', 'sel_vtx_vxy1_fromPV_scalarSub', 'sel_vtx_vxy1_fromPV_vectorSub', 'sel_e1_dxy_refit', 'sel_e1_dxy_manual', 'sel_e1_dxy_manual_fromPV', 'bdtscore', 'bdtscore_vs_sel_vtx_CosThetaColl_fromPV_refit', 'bdtscore_vs_sel_vtx_sign', 'sel_vtx_CosThetaColl_fromPV_refit_vs_sel_vtx_sign', 'bdtscore_vs_sel_vtx_CosThetaColl_fromPV', 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit', 'bdtscore_vs_sel_vtx_thetaColl_fromPV', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched', 'cutflow_vtx_matched_fromReco'])

# %% [markdown]
# ## Signal

# %%
sig_samples = list(sig_histo['cutflow'].keys())
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
cutnames = utils.get_signal_list_of_cuts(sig_histo)
cutnames
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'Leading jet pT > 80 GeV',
#  'Leading jet |eta| < 2.4',
#  'dPhi(MET,leading jet) > 2.0',
#  'dPhi(MET,all jets) > 0.75',
#  'OSSF',
#  'BDT']

# %%
# Efficiency
pd.options.display.float_format = '{:,.6f}'.format
eff_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow')

# %%
table = eff_cutflow
table.columns = cutnames

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'VR_Signal_ctau-{int(ct)}_samples_Efficiency'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-1_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-10_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-100_samples_Efficiency.csv

# %%
# Weighted event count
pd.options.display.float_format = '{:,.4f}'.format
cts_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

# %%
table = cts_cutflow
table.columns = cutnames

# %%
# ctau = 1mm
ct = 1.0

points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
df
# Out:
#                                        Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.1691             27.5180
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       1,156.9315            666.7773
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       1,457.7156            827.0445
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1         74.7132             45.9089
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       1,964.2733          1,102.7526
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        1,620.1785            714.5297
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       2,725.2304          1,478.2941
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      33,765.0692         11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        167.4818            107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       4,184.6540          2,237.3733
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         403.5456            244.8587
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       9,916.8019          5,387.4485
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1      38,528.4000         22,915.1867
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1      20,174.8511         10,418.8342
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         734.2812            421.4102
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1      17,929.3616          8,851.4651
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         937.0399            499.5261
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1      22,229.4245          9,901.6350
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.4857            540.0955
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.0246             21.2724
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   27.4900
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   666.1743
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   825.9792
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   45.8901
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,102.0333
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    714.5297
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,477.9960
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,234.0401
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   244.4996
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,383.4982
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,892.5142
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,405.9473
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   421.2750
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,828.4275
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   499.3174
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,887.5434
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 539.0392
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  21.2434
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   44.1806
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,064.7355
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    687.9354
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,424.9048
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   236.3616
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,178.4167
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,128.9703
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   404.3941
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,552.3517
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   479.1320
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,535.0728
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  20.5304
#
#                                        dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       44.1744
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     1,064.7355
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        687.9354
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     1,424.9048
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                      103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       236.3616
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     5,178.4167
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    10,128.9703
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       404.3941
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     8,552.3517
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       479.1320
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     9,535.0728
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                      20.5304
#
#                                        dPhi(MET,all jets) > 0.75        OSSF  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                     26.2251     25.5668
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     635.0341    617.6829
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     787.3198    767.1020
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     43.5820     42.4655
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   1,050.8564  1,018.2555
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      680.3314    656.2454
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   1,406.4192  1,361.3700
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  10,978.4487 10,359.8293
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    102.3719     99.0149
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   2,126.5131  2,065.1446
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     232.8919    227.1468
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   5,132.4027  4,964.1828
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  21,771.3799 21,199.8001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  10,048.4450  9,726.3932
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     399.9393    388.0637
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   8,441.2445  8,180.3395
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     474.5553    461.0280
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   9,422.3953  8,975.8855
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   512.6493    502.1014
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                    20.2922     19.8342
#
#                                            BDT
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1    0.6317
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1    10.3888
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1    12.6530
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1    0.6298
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1    17.8432
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      8.8604
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1    19.6825
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1   141.3810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1    1.0363
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1    18.0748
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1     1.3772
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    48.6169
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1   107.6805
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    83.5890
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1     1.3514
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    61.3147
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     2.7020
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    65.7772
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1   8.2336
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1   0.5554

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'VR_Signal_ctau-{int(ct)}_samples_EventCount_Weighted'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-1_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-10_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-100_samples_EventCount_Weighted.csv

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# ctau = 1mm
ct = 1.0

points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
df
# Out:
#                                        Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.1691             27.5180
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       1,156.9315            666.7773
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       1,457.7156            827.0445
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1         74.7132             45.9089
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       1,964.2733          1,102.7526
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        1,620.1785            714.5297
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       2,725.2304          1,478.2941
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      33,765.0692         11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        167.4818            107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       4,184.6540          2,237.3733
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         403.5456            244.8587
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       9,916.8019          5,387.4485
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1      38,528.4000         22,915.1867
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1      20,174.8511         10,418.8342
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         734.2812            421.4102
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1      17,929.3616          8,851.4651
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         937.0399            499.5261
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1      22,229.4245          9,901.6350
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.4857            540.0955
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.0246             21.2724
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   27.4900
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   666.1743
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   825.9792
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   45.8901
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,102.0333
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    714.5297
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,477.9960
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,685.7826
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  107.2824
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,234.0401
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   244.4996
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,383.4982
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,892.5142
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,405.9473
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   421.2750
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,828.4275
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   499.3174
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,887.5434
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 539.0392
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  21.2434
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   44.1806
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,064.7355
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    687.9354
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,424.9048
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   236.3616
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,178.4167
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,128.9703
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   404.3941
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 8,552.3517
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   479.1320
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,535.0728
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  20.5304
#
#                                        dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       26.5657
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       642.8489
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       797.3672
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       44.1744
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     1,064.7355
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        687.9354
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     1,424.9048
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    11,173.1411
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                      103.1451
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     2,160.7601
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       236.3616
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     5,178.4167
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    22,077.3725
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    10,128.9703
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       404.3941
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     8,552.3517
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       479.1320
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     9,535.0728
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     520.8847
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                      20.5304
#
#                                        dPhi(MET,all jets) > 0.75        OSSF  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                     26.2251     25.5668
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     635.0341    617.6829
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     787.3198    767.1020
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     43.5820     42.4655
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   1,050.8564  1,018.2555
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      680.3314    656.2454
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   1,406.4192  1,361.3700
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  10,978.4487 10,359.8293
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    102.3719     99.0149
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   2,126.5131  2,065.1446
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     232.8919    227.1468
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   5,132.4027  4,964.1828
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  21,771.3799 21,199.8001
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  10,048.4450  9,726.3932
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     399.9393    388.0637
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   8,441.2445  8,180.3395
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     474.5553    461.0280
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   9,422.3953  8,975.8855
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   512.6493    502.1014
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                    20.2922     19.8342
#
#                                            BDT
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1    0.6317
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1    10.3888
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1    12.6530
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1    0.6298
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1    17.8432
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      8.8604
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1    19.6825
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1   141.3810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1    1.0363
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1    18.0748
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1     1.3772
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    48.6169
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1   107.6805
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    83.5890
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1     1.3514
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    61.3147
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     2.7020
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    65.7772
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1   8.2336
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1   0.5554

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'VR_Signal_ctau-{int(ct)}_samples_Raw'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-1_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-10_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//VR_Signal_ctau-100_samples_Raw.csv

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [5, 10, 20, 30, 40],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_VR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m5to40.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_100_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_100_m5to40.png

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [50, 70, 90, 100],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_VR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m50to100.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p1_ct_100_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'OSSF', 'BDT']
# Saved: ./plots/cutflow//Cutflow_VR_signal_delta_0p2_ct_100_m50to100.png

# %% [markdown]
# ## Background

# %%
# efficiency
pd.options.display.float_format = '{:,.8f}'.format

bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow')
bkg_eff_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# DY             0.00018701          0.00001151               0.00001141
# Top            0.00039885          0.00001298               0.00001210
# Multiboson     0.00065832          0.00003441               0.00003004
# WJets          0.00101318          0.00003720               0.00003665
# ZJets          0.00242159          0.00007613               0.00007541
# QCD            0.00000249          0.00000001               0.00000001
# ZGamma         0.00032468          0.00001653               0.00001398
# Total          0.00001696          0.00000054               0.00000052
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# DY                       0.00001094                   0.00001083
# Top                      0.00001090                   0.00001077
# Multiboson               0.00002763                   0.00002678
# WJets                    0.00003480                   0.00003459
# ZJets                    0.00007141                   0.00007118
# QCD                      0.00000001                   0.00000001
# ZGamma                   0.00001313                   0.00001310
# Total                    0.00000049                   0.00000049
#
#             dPhi(MET,all jets) > 0.75       OSSF        BDT
# DY                         0.00000952 0.00000760 0.00000070
# Top                        0.00000985 0.00000627 0.00000059
# Multiboson                 0.00002517 0.00001774 0.00000175
# WJets                      0.00003180 0.00001672 0.00000276
# ZJets                      0.00006654 0.00003517 0.00000968
# QCD                        0.00000000 0.00000000 0.00000000
# ZGamma                     0.00001314 0.00000881 0.00000204
# Total                      0.00000044 0.00000024 0.00000004

# %%
# Save as csv
outdir = f'./csv/{suffix}/Cutflow/Efficiency/'
outname = f'Background_Efficiency'

df_to_save = bkg_eff_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF/Cutflow/Efficiency//Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_cts_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# DY               5,819.49                            358.21
# Top             26,174.93                            851.60
# Multiboson       4,588.16                            239.80
# WJets          214,692.24                          7,883.42
# ZJets           63,745.58                          2,003.91
# QCD             53,432.27                            275.55
# ZGamma           1,665.13                             84.77
# Total          370,117.80                         11,697.26
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# DY                           355.08                   340.58
# Top                          793.75                   715.64
# Multiboson                   209.34                   192.59
# WJets                      7,765.40                 7,373.78
# ZJets                      1,985.06                 1,879.87
# QCD                          275.55                   214.93
# ZGamma                        71.71                    67.31
# Total                     11,455.88                10,784.71
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75     OSSF  \
# DY                               337.02                     296.39   236.56
# Top                              706.97                     646.17   411.66
# Multiboson                       186.67                     175.45   123.66
# WJets                          7,330.01                   6,739.24 3,542.39
# ZJets                          1,873.73                   1,751.69   925.74
# QCD                              206.03                      32.90    16.05
# ZGamma                            67.20                      67.41    45.16
# Total                         10,707.63                   9,709.25 5,301.23
#
#               BDT
# DY          21.69
# Top         38.86
# Multiboson  12.22
# WJets      585.65
# ZJets      254.86
# QCD          8.02
# ZGamma      10.45
# Total      931.76

# %%
# Save to csv
outdir = f'./csv/{suffix}/Cutflow/EventCount_Weighted/'
outname = f'Background_EventCount_Weighted'

df_to_save = bkg_cts_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF/Cutflow/EventCount_Weighted//Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# DY                 296131                7134                     7103
# Top                703976               21950                    20178
# Multiboson          25187                1310                     1106
# WJets             1177020               21199                    20944
# ZJets              738994               12563                    12452
# QCD                 31490                  92                       92
# ZGamma               6506                 343                      307
# Total             2979304               64591                    62182
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# DY                             6985                         6640
# Top                           18131                        17729
# Multiboson                     1027                          966
# WJets                         20158                        19793
# ZJets                         11965                        11824
# QCD                              90                           88
# ZGamma                          292                          279
# Total                         58648                        57319
#
#             dPhi(MET,all jets) > 0.75   OSSF   BDT
# DY                               4563   3734   240
# Top                             16114  10382   915
# Multiboson                        905    641    55
# WJets                           16850   8815  1291
# ZJets                           10144   5327  1443
# QCD                                 6      2     1
# ZGamma                            252    158    22
# Total                           48834  29059  3967

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# DY                 296131                              7134
# Top                703976                             21950
# Multiboson          25187                              1310
# WJets             1177020                             21199
# ZJets              738994                             12563
# QCD                 31490                                92
# ZGamma               6506                               343
# Total             2979304                             64591
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# DY                             7103                     6985
# Top                           20178                    18131
# Multiboson                     1106                     1027
# WJets                         20944                    20158
# ZJets                         12452                    11965
# QCD                              92                       90
# ZGamma                          307                      292
# Total                         62182                    58648
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75   OSSF  \
# DY                                 6640                       4563   3734
# Top                               17729                      16114  10382
# Multiboson                          966                        905    641
# WJets                             19793                      16850   8815
# ZJets                             11824                      10144   5327
# QCD                                  88                          6      2
# ZGamma                              279                        252    158
# Total                             57319                      48834  29059
#
#              BDT
# DY           240
# Top          915
# Multiboson    55
# WJets       1291
# ZJets       1443
# QCD            1
# ZGamma        22
# Total       3967

# %%
outdir = f'./csv/{suffix}/Cutflow/EventCount_Raw/'
outname = f'Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF/Cutflow/EventCount_Raw//Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 931.76

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df[bkg_cts_df.columns.values[-1]]).transpose(), pd.DataFrame(bkg_cts_raw_df[bkg_cts_df.columns.values[-1]]).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                     DY    Top  Multiboson    WJets    ZJets  QCD  ZGamma  \
# Weighted Counts  21.69  38.86       12.22   585.65   254.86 8.02   10.45
# Raw Counts      240.00 915.00       55.00 1,291.00 1,443.00 1.00   22.00
#
#                    Total
# Weighted Counts   931.76
# Raw Counts      3,967.00

# %% [markdown]
# ## Data

# %%
pd.options.display.float_format = '{:,.1f}'.format
data_cts_df = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
data_cts_df
# Out:
#                                       Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_MET_Run2018D      364,388.0            11,961.0
# data_2018_Data_MET_UL18_MET_Run2018C       82,311.0             2,778.0
# data_2018_Data_MET_UL18_MET_Run2018B       63,816.0             2,697.0
# data_2018_Data_MET_UL18_MET_Run2018A      125,215.0             5,118.0
# Total                                     635,730.0            22,554.0
#
#                                       Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_MET_Run2018D                 11,710.0
# data_2018_Data_MET_UL18_MET_Run2018C                  2,716.0
# data_2018_Data_MET_UL18_MET_Run2018B                  2,637.0
# data_2018_Data_MET_UL18_MET_Run2018A                  5,020.0
# Total                                                22,083.0
#
#                                       Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_MET_Run2018D                  7,588.0
# data_2018_Data_MET_UL18_MET_Run2018C                  1,667.0
# data_2018_Data_MET_UL18_MET_Run2018B                  1,551.0
# data_2018_Data_MET_UL18_MET_Run2018A                  2,751.0
# Total                                                13,557.0
#
#                                       dPhi(MET,leading jet) > 2.0  \
# data_2018_Data_MET_UL18_MET_Run2018D                      7,521.0
# data_2018_Data_MET_UL18_MET_Run2018C                      1,658.0
# data_2018_Data_MET_UL18_MET_Run2018B                      1,536.0
# data_2018_Data_MET_UL18_MET_Run2018A                      2,714.0
# Total                                                    13,429.0
#
#                                       dPhi(MET,all jets) > 0.75    OSSF  \
# data_2018_Data_MET_UL18_MET_Run2018D                    6,629.0 3,481.0
# data_2018_Data_MET_UL18_MET_Run2018C                    1,488.0   784.0
# data_2018_Data_MET_UL18_MET_Run2018B                    1,376.0   738.0
# data_2018_Data_MET_UL18_MET_Run2018A                    2,434.0 1,327.0
# Total                                                  11,927.0 6,330.0
#
#                                          BDT
# data_2018_Data_MET_UL18_MET_Run2018D   654.0
# data_2018_Data_MET_UL18_MET_Run2018C   145.0
# data_2018_Data_MET_UL18_MET_Run2018B   126.0
# data_2018_Data_MET_UL18_MET_Run2018A   257.0
# Total                                1,182.0

# %%
pd.options.display.float_format = '{:,.1f}'.format

data_composition = pd.DataFrame(data_cts_df[data_cts_df.columns.values[-1]]).transpose()

data_composition = data_composition.rename(index={data_cts_df.columns.values[-1]: 'Data Yield'})
data_composition = data_composition.rename(columns={'data_2018_Data_MET_UL18_MET_Run2018C': 'Run2018C', \
                                                   'data_2018_Data_MET_UL18_MET_Run2018B': 'Run2018B', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018A': 'Run2018A', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018D': 'Run2018D'
                                                   })

data_composition = data_composition.reindex(sorted(data_composition.columns), axis=1)

data_composition
# Out:
#             Run2018A  Run2018B  Run2018C  Run2018D   Total
# Data Yield     257.0     126.0     145.0     654.0 1,182.0

# %%
# Data/background MC
data_yield = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
mc_yield = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']

data_yield / mc_yield
# Out:
# Preselections                 1.7
# n(good vertex) > 0            1.9
# Leading jet pT > 80 GeV       1.9
# Leading jet |eta| < 2.4       1.3
# dPhi(MET,leading jet) > 2.0   1.3
# dPhi(MET,all jets) > 0.75     1.2
# OSSF                          1.2
# BDT                           1.3
# Name: Total, dtype: float64

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                 635,730.0
# n(good vertex) > 0             22,554.0
# Leading jet pT > 80 GeV        22,083.0
# Leading jet |eta| < 2.4        13,557.0
# dPhi(MET,leading jet) > 2.0    13,429.0
# dPhi(MET,all jets) > 0.75      11,927.0
# OSSF                            6,330.0
# BDT                             1,182.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                 370,117.8
# n(good vertex) > 0             11,697.3
# Leading jet pT > 80 GeV        11,455.9
# Leading jet |eta| < 2.4        10,784.7
# dPhi(MET,leading jet) > 2.0    10,707.6
# dPhi(MET,all jets) > 0.75       9,709.3
# OSSF                            5,301.2
# BDT                               931.8
# Name: Total, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(7,7))

mplhep.cms.label('', data=True, year=2018)

data_cutflow = np.array(utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total'].to_list())
bkg_cutflow = np.array(utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total'].to_list())

plt.plot(data_cutflow, '-o', label='Data')
plt.plot(bkg_cutflow, '-o', label='Background MC (Total)')

plt.legend()

ratio_length = (ax.get_position().y1 - ax.get_position().y0) / 3
ax_ratio = fig.add_axes([ax.get_position().x0, ax.get_position().y0 - ratio_length * 1.2, \
                         ax.get_position().x1 - ax.get_position().x0, ratio_length]) 

ax.get_shared_x_axes().join(ax, ax_ratio)
ax.xaxis.set_ticklabels([])

ax_ratio.set_xlabel(ax.get_xlabel())
ax.set_xlabel('')
ax_ratio.set_ylabel('Data/MC')
ax_ratio.set_ylim([0,2.5])

ratio = data_cutflow / bkg_cutflow
    
ax_ratio.plot(ratio, 'o', color='black')
    
ax_ratio.axhline(y=1, color='black', linestyle='--', linewidth=0.8)

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

plt.xticks(ticks = np.arange(len(data_cutflow)), labels = cuts, rotation = 45, ha = 'right')

ax.set_ylabel('Events')
ax.set_yscale('log')
# Out:
# /tmp/ipykernel_1157809/1904301384.py:17: MatplotlibDeprecationWarning: The join function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.get_shared_x_axes().join(ax, ax_ratio)

# %% [markdown]
# ### Plot the efficiency

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF/cutflow//Cutflow_background.png

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                 635,730.0
# n(good vertex) > 0             22,554.0
# Leading jet pT > 80 GeV        22,083.0
# Leading jet |eta| < 2.4        13,557.0
# dPhi(MET,leading jet) > 2.0    13,429.0
# dPhi(MET,all jets) > 0.75      11,927.0
# OSSF                            6,330.0
# BDT                             1,182.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# DY                5,819.5               358.2                    355.1
# Top              26,174.9               851.6                    793.7
# Multiboson        4,588.2               239.8                    209.3
# WJets           214,692.2             7,883.4                  7,765.4
# ZJets            63,745.6             2,003.9                  1,985.1
# QCD              53,432.3               275.6                    275.6
# ZGamma            1,665.1                84.8                     71.7
# Total           370,117.8            11,697.3                 11,455.9
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# DY                            340.6                        337.0
# Top                           715.6                        707.0
# Multiboson                    192.6                        186.7
# WJets                       7,373.8                      7,330.0
# ZJets                       1,879.9                      1,873.7
# QCD                           214.9                        206.0
# ZGamma                         67.3                         67.2
# Total                      10,784.7                     10,707.6
#
#             dPhi(MET,all jets) > 0.75    OSSF   BDT
# DY                              296.4   236.6  21.7
# Top                             646.2   411.7  38.9
# Multiboson                      175.5   123.7  12.2
# WJets                         6,739.2 3,542.4 585.7
# ZJets                         1,751.7   925.7 254.9
# QCD                              32.9    16.0   8.0
# ZGamma                           67.4    45.2  10.4
# Total                         9,709.3 5,301.2 931.8

# %%
cmap = ["#3f90da", "#ffa90e", "#bd1f01", "#94a4a2", "#832db6", "#a96b59", "#e76300", "#b9ac70", "#717581", "#92dadd"] # cms-recommended

bkg_cmap = {
    "QCD": cmap[0],
    "WJets": cmap[1],
    "ZJets": cmap[2],
    "DY-M4to50": cmap[3],
    "DY-M50": cmap[4],
    "TTbar": cmap[5],
    "SingleTop": cmap[6],
    "Multiboson": cmap[7],
    "ZGamma": cmap[8],
    "TTX": cmap[9]
}

df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
processes = df.index.values.tolist()

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

# Color map for each process
for process in processes:
    if 'Total' in process:
        plt.plot(cuts, df.loc[process], label=process, color='black')
    else:
        plt.plot(cuts, df.loc[process], label=process, color = bkg_cmap[process])

# plot data
df_data = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
plt.plot(cuts, df_data.loc['Total'], label='Data: Run2018[A-D]', color = 'blue', marker='o', linestyle='--')

if plot_dict_bkg_eff['doLog']:
    plt.yscale('log')

if plot_dict_bkg_eff['ylim'] != None:
    plt.ylim(plot_dict_bkg_eff['ylim'][0], plot_dict_bkg_eff['ylim'][1])
    
plt.grid()
    
plt.ylabel(plot_dict_bkg_eff['ylabel'])
plt.title(plot_dict_bkg_eff['title'])
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cuts, rotation = 45, ha = 'right')
    
plt.legend(loc='upper right')
    
if plot_dict_bkg_eff['doSave']:
    os.makedirs(plot_dict_bkg_eff['outDir'], exist_ok=True)
    plt.tight_layout()
    plt.savefig(f"{plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    print(f"Saved: {plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 28
#      26         plt.plot(cuts, df.loc[process], label=process, color='black')
#      27     else:
# ---> 28         plt.plot(cuts, df.loc[process], label=process, color = bkg_cmap[process])
#      30 # plot data
#      31 df_data = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
#
# KeyError: 'DY'
