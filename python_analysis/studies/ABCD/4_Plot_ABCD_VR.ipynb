# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils
import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# See here: https://cms-analysis.docs.cern.ch/guidelines/plotting/colors/ for plot styling suggestions from PubComm

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
#suffix = 'BDT_ABCD_goodvtx_v11_NJetG3_SSSF_BDT0p965_Theta70'
#suffix = 'BDT_ABCD_goodvtx_v11_NJetG3_SSSF_BDT0p965_Theta70_ABCDscan'
suffix = 'BDT_ABCD_goodvtx_v11_NJetG3_SSSF_BDT0p96_Theta70_ABCDscan'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
#data_histo.keys()

# %%
variable = 'nJets'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$N_{jets}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots//data_VR1_nJets_cut10.png
# Saved: ./plots//data_VR1_nJets_cut10.png
# Saved: ./plots//data_VR1_nJets_cut10.png

# %%
variable = 'sel_vtx_ThetaColl_fromPV_refit_rad'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 25j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/0.25',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_rad_cut10.png
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_rad_cut10.png
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_rad_cut10.png

# %%
variable = 'sel_vtx_ThetaColl_fromPV_refit'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 15j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events / 15',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_cut10.png
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_cut10.png
# Saved: ./plots//data_VR1_sel_vtx_ThetaColl_fromPV_refit_cut10.png

# %%
variable = 'bdtscore'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': 'BDT score',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)
# Out:
# Saved: ./plots//data_VR1_bdtscore_cut10.png
# Saved: ./plots//data_VR1_bdtscore_cut10.png
# Saved: ./plots//data_VR1_bdtscore_cut10.png

# %%
variable = 'bdtscore'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'sel_vtx_CosThetaColl_fromPV_refit'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'sel_vtx_ThetaColl_fromPV_refit'
cut = 'cut10'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 15j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events / 15 deg',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut10'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 50j,
    'yrebin': 15j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
#ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')

plt.title(rf"All backgrounds", position=(0.8, 0.5))
plt.vlines(0.965, 0, 180, color='red', linewidth=2)
plt.hlines(70, 0, 1, color='red', linewidth=2)

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut10'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 50j,
    'yrebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': 'BDT score',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR1_ABCD.png'
}

# Data
style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))

plt.title(rf"Data", position=(0.95, 0.5))
plt.vlines(0.96, 0, 180, color='red', linewidth=2)
plt.hlines(70, 0, 1, color='red', linewidth=2)


plt.text(0.5, 125, 'C', color='red', fontsize=20)
plt.text(0.5, 35, 'D', color='red', fontsize=20)

plt.text(0.97, 125, 'B', color='red', fontsize=20)
plt.text(0.97, 35, 'A', color='red', fontsize=20)

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)
# Out:
# [  0  20  40  60  80 100 120 140 160 180]
# Saved: ./plots//data_VR1_ABCD.png

# %%
run = ['data_2018_Data_MET_UL18_MET_Run2018D', \
       'data_2018_Data_MET_UL18_MET_Run2018C', \
       'data_2018_Data_MET_UL18_MET_Run2018B', \
       'data_2018_Data_MET_UL18_MET_Run2018A']

cut = 'cut10'

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[0], "cut": cut}][:955,70:]
# Out:
# Hist(
#   Regular(955, 0, 0.955, name='bdtscore'),
#   Regular(110, 70, 180, name='theta'),
#   storage=Weight()) # Sum: WeightedSum(value=651, variance=651) (WeightedSum(value=1197, variance=1197) with flow)

# %%
bdt_WP = 955
theta_WP = 70

# %%
nC = 0

for idx, era in enumerate(run):
    nC += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][:bdt_WP,theta_WP:].sum().value
    print(era)

print(nC)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 1169.0

# %%
nB = 0

for idx, era in enumerate(run):
    nB += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][bdt_WP:,theta_WP:].sum().value
    print(era)

print(nB)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 13.0

# %%
nD = 0

for idx, era in enumerate(run):
    nD += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][:bdt_WP,:theta_WP].sum().value
    print(era)

print(nD)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 934.0

# %%
nA = 0

for idx, era in enumerate(run):
    nA += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][bdt_WP:,:theta_WP].sum().value
    print(era)

print(nA)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 9.0

# %%
pred = nD*(nB/nC)
pred
# Out:
# 10.386655260906757

# %%
obs = nA

# %%
pred_err = pred * np.sqrt((np.sqrt(nD)/nD)**2 + (np.sqrt(nB)/nB)**2 + (np.sqrt(nC)/nC)**2)

# %%
pred_err
# Out:
# 2.9165826499168648

# %%
obs_err = np.sqrt(obs)

# %%
obs_err
# Out:
# 3.0
