# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# See here: https://cms-analysis.docs.cern.ch/guidelines/plotting/colors/ for plot styling suggestions from PubComm

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = 'BDT_ABCD_VR3_goodvtx_v11_NJetG0L3_OSSF'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
#data_histo.keys()

# %%
variable = 'nJets'
cut = 'cut11'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$N_{jets}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'bdtscore'
cut = 'cut11'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'sel_vtx_CosThetaColl_fromPV_refit'
cut = 'cut11'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 8j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
variable = 'sel_vtx_ThetaColl_fromPV_refit'
cut = 'cut11'

fig, ax = plt.subplots(figsize=(6,6))

# Plot settings
plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 15j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': True, 
    'xlabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events / 15 deg',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Data',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./AN_Plots/{suffix}/data_bkg/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

ptools.plot_data_MC_ratio(data_histo, bkg_histo, plot_dict, style_dict)

# %%
fig, ax = plt.subplots(figsize=(7,7))

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut11'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 50j,
    'yrebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': False,
    'outDir': f'./plots/{suffix}/data/sel_vtx/',
    'outName': f'data_VR_{variable}_{cut}.png'
}

# Data
#ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)


# Bkg

style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))
ptools.plot_bkg_2D(bkg_histo, plot_dict, style_2d_dict, processes = 'all')

plt.title(rf"All backgrounds", position=(0.8, 0.5))
plt.vlines(0.2, 0, 180, color='red', linewidth=2)
plt.vlines(0.4, 0, 180, color='red', linewidth=2)
plt.vlines(0.5, 0, 180, color='red', linewidth=2)
plt.vlines(0.96, 0, 180, color='red', linewidth=2)

plt.hlines(70, 0, 1, color='red', linewidth=2)

# %%
# Plot settings
#fig, ax = plt.subplots(figsize=(7,7))

cut = 'cut11'
variable = 'bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'

plot_dict = {
    'variable': variable,
    'cut': cut,
    'year': 2018
}

style_2d_dict = {
    'fig': fig,
    'ax': ax,
    'xrebin': 50j,
    'yrebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]  
    'ylim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doLogz': True,
    'xlabel': 'BDT score',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': r"$\theta_{coll}$",   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'zlabel': 'Events',   
    'flow': None,     # overflow
    'doSave': True,
    'outDir': f'./plots/',
    'outName': f'data_VR2_ABCD.png'
}

# Data
style_2d_dict['fig'], style_2d_dict['ax'] = plt.subplots(figsize=(7,7))

plt.title(rf"Data", position=(0.95, 0.5))

plt.vlines(0.2, 0, 180, color='red', linewidth=2)
plt.vlines(0.4, 0, 180, color='red', linewidth=2)
plt.vlines(0.5, 0, 180, color='red', linewidth=2)
plt.vlines(0.96, 0, 180, color='red', linewidth=2)

plt.hlines(70, 0, 1, color='red', linewidth=2)

plt.text(0.27, 125, 'C1', color='red', fontsize=20)
plt.text(0.27, 35, 'D1', color='red', fontsize=20)

plt.text(0.42, 125, 'C2', color='red', fontsize=20)
plt.text(0.42, 35, 'D2', color='red', fontsize=20)

ptools.plot_data_2D(data_histo, plot_dict, style_2d_dict)

# %%
run = ['data_2018_Data_MET_UL18_MET_Run2018D', \
       'data_2018_Data_MET_UL18_MET_Run2018C', \
       'data_2018_Data_MET_UL18_MET_Run2018B', \
       'data_2018_Data_MET_UL18_MET_Run2018A']

cut = 'cut11'

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[0], "cut": cut}][0:400,0:70]
# Out:
# Hist(
#   Regular(400, 0, 0.4, name='bdtscore'),
#   Regular(70, 0, 70, name='theta'),
#   storage=Weight()) # Sum: WeightedSum(value=229, variance=229) (WeightedSum(value=654, variance=654) with flow)

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[0], "cut": cut}][400:,70:]
# Out:
# Hist(
#   Regular(600, 0.4, 1, name='bdtscore'),
#   Regular(110, 70, 180, name='theta'),
#   storage=Weight()) # Sum: WeightedSum(value=94, variance=94) (WeightedSum(value=654, variance=654) with flow)

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[0], "cut": cut}][:,:70]
# Out:
# Hist(
#   Regular(1000, 0, 1, name='bdtscore'),
#   Regular(70, 0, 70, name='theta'),
#   storage=Weight()) # Sum: WeightedSum(value=308, variance=308) (WeightedSum(value=654, variance=654) with flow)

# %%
data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[0], "cut": cut}][:,70:]
# Out:
# Hist(
#   Regular(1000, 0, 1, name='bdtscore'),
#   Regular(110, 70, 180, name='theta'),
#   storage=Weight()) # Sum: WeightedSum(value=344, variance=344) (WeightedSum(value=654, variance=654) with flow)

# %%
bdt_WP = 400
theta_WP = 70

# %%
nC1 = 0

for idx, era in enumerate(run):
    nC1 += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][:bdt_WP,theta_WP:].sum().value
    print(era)

print(nC1)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 446.0

# %%
nC2 = 0

for idx, era in enumerate(run):
    nC2 += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][bdt_WP:,theta_WP:].sum().value
    print(era)

print(nC2)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 170.0

# %%
nD1 = 0

for idx, era in enumerate(run):
    nD1 += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][:bdt_WP,:theta_WP].sum().value
    print(era)

print(nD1)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 413.0

# %%
nD2 = 0

for idx, era in enumerate(run):
    nD2 += data_histo['bdtscore_vs_sel_vtx_thetaColl_fromPV_refit'][{"samp":run[idx], "cut": cut}][bdt_WP:,:theta_WP].sum().value
    print(era)

print(nD2)
# Out:
# data_2018_Data_MET_UL18_MET_Run2018D
# data_2018_Data_MET_UL18_MET_Run2018C
# data_2018_Data_MET_UL18_MET_Run2018B
# data_2018_Data_MET_UL18_MET_Run2018A
# 149.0

# %%
nD1*(nC2/nC1)
# Out:
# 157.42152466367713

# %%
pred = nD1*(nC2/nC1)
pred
# Out:
# 157.42152466367713

# %%
obs = nD2

# %%
obs
# Out:
# 149.0

# %%
pred_err = pred * np.sqrt((np.sqrt(nD1)/nD1)**2 + (np.sqrt(nC2)/nC2)**2 + (np.sqrt(nC1)/nC1)**2)

# %%
pred_err
# Out:
# 16.16605848298365

# %%
obs_err = np.sqrt(obs)

# %%
obs_err
# Out:
# 12.206555615733702
