# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prefix = '/uscms/home/kyungmip/nobackup/CMSSW_10_6_26_8April2024_BACKUP/src/iDMe/python_analysis/studies/OneBinSR/'

# %%
df_cut = pd.read_csv(f'{prefix}SR_Cut-based/csv/SR_Yields/SR_Cut-based_S_over_B.csv')

df_ctau_1 = pd.read_csv(f'{prefix}ctau-split-BDT/csv/SR_Yields/SR_BDT_ctau-1-based_trained_5to100_S_over_B.csv')
df_ctau_10 = pd.read_csv(f'{prefix}ctau-split-BDT/csv/SR_Yields/SR_BDT_ctau-10-based_trained_5to100_S_over_B.csv')
df_ctau_100 = pd.read_csv(f'{prefix}ctau-split-BDT/csv/SR_Yields/SR_BDT_ctau-100-based_trained_5to100_S_over_B.csv')
df_ctau_OR = pd.read_csv(f'{prefix}ctau-split-BDT/csv/SR_Yields/SR_BDT_ctau-OR-based_trained_5to100_S_over_B.csv')

df_lxy = pd.read_csv(f'{prefix}SR_BDT_Lxy-based_trained_5to100/csv/SR_Yields/SR_BDT_Lxy-based_trained_5to100_S_over_B.csv')

df_inclusive = pd.read_csv(f'{prefix}inclusive-BDT-new-variables/csv/SR_Yields/SR_BDTv3_S_over_B.csv')

# %%
df_new = pd.read_csv(f'./csv/SR_Yields//SR_S_over_B.csv')

# %%
ctau = 1
delta = 0.1

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
for ctau in [1,10,100]:
    for delta in [0.1,0.2]:
        an_v1 = []
        an_v2 = []
        
        for m1 in m1s:
            an_v1.append(df_inclusive[ (df_inclusive.m1 == m1) & (df_inclusive.delta == delta) & (df_inclusive.ctau == ctau) ].iloc[:,-1].to_list()[0])
            an_v2.append(df_new[ (df_new.m1 == m1) & (df_new.delta == delta) & (df_new.ctau == ctau) ].iloc[:,-1].to_list()[0])
        
        plt.plot(m1s, np.array(an_v2)/np.array(an_v1), label=f'{delta} splitting')
        
        plt.legend()
        
        plt.xlabel('M1 [GeV]')
        plt.ylabel('S/sqrt(B) ratio: ANv2/ANv1')
        
        #plt.ylim([0,7])
        
        plt.title(f'ctau = {ctau}mm')
    
    plt.grid()
    plt.show()

# %% [markdown]
# ## ctau = 1mm, delta = 0.1

# %%
ratio_ctau_1 = []

for m1 in m1s:
    df = df_ctau_1
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_1.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %% [markdown]
# ## ctau = 1mm, delta = 0.2

# %%
ctau = 1
delta = 0.2

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
ratio_ctau_1 = []

for m1 in m1s:
    df = df_ctau_1
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_1.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %%
plt.plot(m1s, ratio_ctau_1, label='ctau-1-BDT')
plt.plot(m1s, ratio_ctau_OR, label='ctau-OR-BDTs')
plt.plot(m1s, ratio_lxy, label='Lxy-split-BDT')
plt.plot(m1s, ratio_inclusive, label='New BDT')

plt.legend()
plt.grid()

plt.xlabel('M1 [GeV]')
plt.ylabel('S/sqrt(B) Ratio to cut-based one')

plt.ylim([0,7])

plt.title(f'ctau = {ctau}mm, delta = {delta}')
# Out:
# Text(0.5, 1.0, 'ctau = 1mm, delta = 0.2')

# %% [markdown]
# ## ctau = 10mm, delta = 0.1

# %%
ctau = 10
delta = 0.1

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
ratio_ctau_10 = []

for m1 in m1s:
    df = df_ctau_10
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_10.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %%
plt.plot(m1s, ratio_ctau_10, label='ctau-10-BDT')
plt.plot(m1s, ratio_ctau_OR, label='ctau-OR-BDTs')
plt.plot(m1s, ratio_lxy, label='Lxy-split-BDT')
plt.plot(m1s, ratio_inclusive, label='New BDT')

plt.legend()
plt.grid()

plt.xlabel('M1 [GeV]')
plt.ylabel('S/sqrt(B) Ratio to cut-based one')

plt.ylim([0,7])

plt.title(f'ctau = {ctau}mm, delta = {delta}')
# Out:
# Text(0.5, 1.0, 'ctau = 10mm, delta = 0.1')

# %% [markdown]
# ## ctau = 10mm, delta = 0.2

# %%
ctau = 10
delta = 0.2

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
ratio_ctau_10 = []

for m1 in m1s:
    df = df_ctau_10
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_10.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %%
plt.plot(m1s, ratio_ctau_10, label='ctau-10-BDT')
plt.plot(m1s, ratio_ctau_OR, label='ctau-OR-BDTs')
plt.plot(m1s, ratio_lxy, label='Lxy-split-BDT')
plt.plot(m1s, ratio_inclusive, label='New BDT')

plt.legend()
plt.grid()

plt.xlabel('M1 [GeV]')
plt.ylabel('S/sqrt(B) Ratio to cut-based one')

plt.ylim([0,7])

plt.title(f'ctau = {ctau}mm, delta = {delta}')
# Out:
# Text(0.5, 1.0, 'ctau = 10mm, delta = 0.2')

# %% [markdown]
# ## ctau = 100mm, delta = 0.1

# %%
ctau = 100
delta = 0.1

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
ratio_ctau_100 = []

for m1 in m1s:
    df = df_ctau_100
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_100.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %%
plt.plot(m1s, ratio_ctau_100, label='ctau-100-BDT')
plt.plot(m1s, ratio_ctau_OR, label='ctau-OR-BDTs')
plt.plot(m1s, ratio_lxy, label='Lxy-split-BDT')
plt.plot(m1s, ratio_inclusive, label='New BDT')

plt.legend()
plt.grid()

plt.xlabel('M1 [GeV]')
plt.ylabel('S/sqrt(B) Ratio to cut-based one')

plt.ylim([0,7])

plt.title(f'ctau = {ctau}mm, delta = {delta}')
# Out:
# Text(0.5, 1.0, 'ctau = 100mm, delta = 0.1')

# %% [markdown]
# ## ctau = 100mm, delta = 0.2

# %%
ctau = 100
delta = 0.2

m1s = [5, 10, 20, 30, 40, 50, 70, 90, 100]

# %%
ratio_ctau_100 = []

for m1 in m1s:
    df = df_ctau_100
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_100.append(s_over_b_df/s_over_b_cut)

# %%
ratio_ctau_OR = []

for m1 in m1s:
    df = df_ctau_OR
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_ctau_OR.append(s_over_b_df/s_over_b_cut)

# %%
ratio_lxy = []

for m1 in m1s:
    df = df_lxy
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_lxy.append(s_over_b_df/s_over_b_cut)

# %%
ratio_inclusive = []

for m1 in m1s:
    df = df_inclusive
    s_over_b_df = df[ (df.m1 == m1) & (df.delta == delta) & (df.ctau == ctau) ].iloc[:,-1].to_list()[0]
    s_over_b_cut = df_cut[ (df_cut.m1 == m1) & (df_cut.delta == delta) & (df_cut.ctau == ctau) ].iloc[:,-1].to_list()[0]

    ratio_inclusive.append(s_over_b_df/s_over_b_cut)

# %%
plt.plot(m1s, ratio_ctau_100, label='ctau-100-BDT')
plt.plot(m1s, ratio_ctau_OR, label='ctau-OR-BDTs')
plt.plot(m1s, ratio_lxy, label='Lxy-split-BDT')
plt.plot(m1s, ratio_inclusive, label='New BDT')

plt.legend()
plt.grid()

plt.xlabel('M1 [GeV]')
plt.ylabel('S/sqrt(B) Ratio to cut-based one')

plt.ylim([0,7])

plt.title(f'ctau = {ctau}mm, delta = {delta}')
# Out:
# Text(0.5, 1.0, 'ctau = 100mm, delta = 0.2')
