# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../../analysisTools/")
import plotTools as ptools

# %%
# Initialize some dictionary that will later be used
signal_df = {} # yield
signal_match_df = {} # gen matched vtx

signal_reco_df = {} # yield only counting the events where gen ee are reconstructed
signal_match_reco_df = {} # gen matched vtx, out of the events where gen ee are reconstructed

for delta in ['0p1','0p2']:
    signal_df[delta] = {}
    signal_match_df[delta] = {}
    signal_reco_df[delta] = {}
    signal_match_reco_df[delta] = {}

# %%
sqrtBs = {'1': 0, '10': 0, '100': 0}

# %%
def plot_efficiency_signal_varying_M1(df_sig, dict_eff, cuts, cutNames, delta, ct, ylim = [1e-5,5e-2], ylabel='Efficiency', doLegend=True, doLog=True, doSave=False, outDir = 'plots/cutflow/', outName='efficiency.png'):
    m1s = sorted(list(set(df_sig[(df_sig.delta==delta)&(df_sig.ctau==ct)].m1)))
        
    for m1 in m1s:
        pt = df_sig[(df_sig.delta==delta) & (df_sig.m1==m1) & (df_sig.ctau==ct)].name[0]
        effs = [dict_eff[pt][cut] for cut in cuts]
        plt.plot(np.arange(len(cuts)), effs, label=r"$M_1 = {0}$ GeV".format(m1), color=f"C{m1s.index(m1)}")

    if doLog:
        plt.yscale('log')

    plt.ylabel(ylabel)
    
    labels = [cutNames[c] for c in cuts]
    # Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
    cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
    cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
    
    plt.xticks(ticks = np.arange(len(cuts)), labels = cut, rotation = 45, ha = 'right')

    plt.grid()

    plt.title(r"$\Delta = {0:.1f}$, $c\tau = {1}$ mm".format(delta,ct))

    plt.ylim(ylim)
    
    if doLegend:
        plt.legend()
    
    if doSave:
        if not os.path.isdir(outDir):
            os.makedirs(outDir)
        plt.savefig(f'{outDir}/{outName}')
        print(f'Saved: {outDir}/{outName}')

# %%
def plot_counts_signal_varying_M1(df_sig, dict_eff, cuts, cutNames, delta, ct, ylabel='Events', doLegend=True, doLog=True, doSave=False, outDir = 'plots/cutflow/', outName='efficiency.png'):
    m1s = sorted(list(set(df_sig[(df_sig.delta==delta)&(df_sig.ctau==ct)].m1)))
        
    for m1 in m1s:
        pt = df_sig[(df_sig.delta==delta) & (df_sig.m1==m1) & (df_sig.ctau==ct)].name[0]
        effs = [dict_eff[pt][cut] for cut in cuts]
        plt.plot(np.arange(len(cuts)), effs, label=r"$M_1 = {0}$ GeV".format(m1), color=f"C{m1s.index(m1)}")

    if doLog:
        plt.yscale('log')

    plt.ylabel(ylabel)
    
    labels = [cutNames[c] for c in cuts]
    # Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
    cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
    cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
    
    plt.xticks(ticks = np.arange(len(cuts)), labels = cut, rotation = 45, ha = 'right')

    plt.grid()

    plt.title(r"$\Delta = {0:.1f}$, $c\tau = {1}$ mm".format(delta,ct))

    if doLegend:
        plt.legend()
    
    if doSave:
        if not os.path.isdir(outDir):
            os.makedirs(outDir)
        plt.savefig(f'{outDir}/{outName}')
        print(f'Saved: {outDir}/{outName}')

# %% [markdown]
# ## Ctau-1

# %% [markdown]
# ### Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = '_SR_BDTv2_ctau-1_5to50_skimmed'

# %%
# Signal
f_sig = "signal"
sig_histo = util.load(f'{prefix}/{f_sig}{suffix}.coffea')[0]

# %%
# Background
bkg_files = {
    "QCD": "bkg_2018_QCD_TuneCP5_PSWeights", # No entry for QCD
    "Top": "bkg_2018_Top",
    "DY": "bkg_2018_DY",
    "Diboson": "bkg_2018_Diboson",
    "Triboson": "bkg_2018_Triboson",
    "W+jets": "bkg_2018_WJets",
    "Z+jets": "bkg_2018_ZJets",
}

bkg_histos = {}
histograms = []

for b in bkg_files.keys():
    bkg_histos[b] = util.load(f'{prefix}/{bkg_files[b]}{suffix}.coffea')[0]
    histograms = list(bkg_histos[b].keys())

# %% [markdown]
# ### Cutflow Dataframe -- signal

# %%
sig_samples = list(sig_histo['cutflow'].keys()) # names of signal sub-process, i.e. mass point, lifetime etc.
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
# signal efficiencies by delta/ctau
cf_s = sig_histo['cutflow']              # efficiency
ct_s = sig_histo['cutflow_cts']          # xsec-weighted event count
fr_s = sig_histo['cutflow_vtx_matched'] # fraction that selected vtx is truth-matched, for signal
desc = sig_histo['cutDesc']

# %%
# signal efficiencies, when only looking at the events where the gen ee are reconstructed (dR(gen,reco) < 0.1)
cf_s_reco = sig_histo['cutflow_genEEreconstructed']              # efficiency
ct_s_reco = sig_histo['cutflow_cts_genEEreconstructed']          # xsec-weighted event count
fr_s_reco = sig_histo['cutflow_vtx_matched_genEEreconstructed']  # fraction that selected vtx is truth-matched, for signal

# %%
cuts = list(sig_histo['cutflow'][sig_samples[0]].keys())
cutNames = {cname:ptools.getCut(sig_histo['cutDesc'][cname]) for cname in sig_histo['cutDesc'].keys()}

# %%
deltas = sorted(list(set(si.delta)))

# %% [markdown]
# #### For signal events

# %%
sig_columns = list(cf_s.keys())
sig_efficiency = {c: [ cf_s[samp][c] for samp in sig_columns ] for c in cuts}
sig_match = {c: [ fr_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_eff_df = pd.DataFrame.from_dict(sig_efficiency).transpose()
sig_eff_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_eff_df.index = cut

# %%
sig_eff_df.transpose()
# Out:
#                                       Preselections  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1       0.033826
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1         0.014484
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1        0.014782
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1        0.036318
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1        0.026904
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1        0.030555
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1        0.020878
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1        0.023214
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1        0.016920
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1        0.018942
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1        0.014729
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1        0.015928
#
#                                       0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                             0.006982
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                               0.001842
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                              0.002143
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                              0.006259
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                              0.005099
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                              0.005051
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                              0.003848
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                              0.003481
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                              0.002932
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                              0.002826
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                              0.002188
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                              0.002349
#
#                                       No b-tagged jets  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          0.005961
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1            0.001519
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           0.001894
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1           0.005421
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           0.004306
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           0.004338
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           0.003369
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           0.002980
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           0.002531
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           0.002381
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1           0.001889
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           0.002024
#
#                                       Leading jet |eta| < 2.4  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.001421
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.001811
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.004165
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.004133
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.003242
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.002881
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.002386
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.002275
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.001805
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.001882
#
#                                       Leading jet pT > 80 GeV  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.001418
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.001811
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.004161
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.004127
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.003235
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.002881
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.002386
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.002273
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.001805
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.001880
#
#                                       dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     0.005695
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                       0.001418
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                      0.001811
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                      0.005217
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      0.004161
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                      0.004127
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                      0.003235
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                      0.002881
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                      0.002386
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                      0.002273
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                      0.001805
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                      0.001880
#
#                                       dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                   0.005651
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     0.001404
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    0.001794
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                    0.005197
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                    0.004135
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                    0.004103
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    0.003195
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    0.002855
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                    0.002357
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                    0.002253
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    0.001794
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    0.001867
#
#                                       BDT v2 Loose WP
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1         0.002804
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1           0.000677
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1          0.000660
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1          0.002280
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1          0.002033
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1          0.001869
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1          0.001754
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1          0.001233
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1          0.001225
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1          0.000991
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1          0.000841
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1          0.000744

# %%
sig_counts = {c: [ ct_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_cts_df = pd.DataFrame.from_dict(sig_counts).transpose()
sig_cts_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_df.index = cut

# %%
sig_cts_df.transpose()
# Out:
#                                       Preselections  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1     205.186408
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1      2748.241352
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1    62382.764516
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1     6562.275287
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1      512.935117
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1    16193.175659
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1    49723.242758
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1    33794.918905
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1      995.446769
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1    30374.507403
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     1394.264143
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1    39395.490506
#
#                                       0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                            42.353992
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                             349.572905
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                           9045.039685
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                           1130.926755
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                             97.210475
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                           2676.895268
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                           9164.659073
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                           5067.472655
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                            172.473503
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                           4531.002909
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                            207.145122
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                           5811.027344
#
#                                       No b-tagged jets  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1         36.160985
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          288.308597
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1        7993.005413
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1         979.542736
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1          82.100675
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1        2298.731658
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1        8024.742583
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1        4338.181148
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         148.909471
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1        3817.775056
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         178.784314
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1        5006.120331
#
#                                       Leading jet |eta| < 2.4  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                34.547900
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                 269.621849
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1               7642.383575
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                942.715841
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                 79.402845
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1               2190.267595
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1               7722.235274
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1               4193.564237
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                140.358362
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1               3648.137891
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                170.888834
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               4654.252295
#
#                                       Leading jet pT > 80 GeV  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                34.547900
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                 268.976334
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1               7642.383575
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                942.715841
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                 79.340009
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1               2187.083708
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1               7704.441742
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1               4193.564237
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                140.358362
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1               3644.603971
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                170.888834
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               4648.894588
#
#                                       dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    34.547900
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     268.976334
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                   7642.383575
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                    942.715841
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     79.340009
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   2187.083708
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                   7704.441742
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                   4193.564237
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                    140.358362
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   3644.603971
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    170.888834
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   4648.894588
#
#                                       dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  34.276942
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   266.400081
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                 7572.305104
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  939.115692
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   78.839199
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 2174.327218
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                 7609.524639
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                 4156.591358
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  138.674840
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 3612.884287
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  169.824212
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 4616.983394
#
#                                       BDT v2 Loose WP
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        17.007244
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1         128.365134
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       2787.316093
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1        412.044822
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         38.762997
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1        990.728036
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1       4178.235083
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       1794.503944
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         72.072975
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       1589.161260
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         79.588482
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       1839.613547

# %%
sig_match_df = pd.DataFrame.from_dict(sig_match).transpose()
sig_match_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_df.index = cut

# %%
sig_match_df.transpose()
# Out:
#                                       Preselections  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1            1.0
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             1.0
#
#                                       0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                             0.599086
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                               0.500157
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                              0.422538
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                              0.520468
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                              0.571031
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                              0.504216
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                              0.583515
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                              0.477517
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                              0.534935
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                              0.479327
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                              0.488216
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                              0.440402
#
#                                       No b-tagged jets  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          0.612185
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1            0.516939
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           0.434271
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1           0.531196
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           0.587514
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           0.512162
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           0.585022
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           0.475646
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           0.544248
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           0.477280
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1           0.496499
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           0.440961
#
#                                       Leading jet |eta| < 2.4  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.526463
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.586940
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.513494
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.584129
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.483015
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.444533
#
#                                       Leading jet pT > 80 GeV  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.527727
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.586613
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.513512
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.584708
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.482514
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.445046
#
#                                       dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                       0.527727
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                      0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                      0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      0.586613
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                      0.513512
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                      0.584708
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                      0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                      0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                      0.482514
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                      0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                      0.445046
#
#                                       dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                   0.630122
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     0.530413
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    0.439877
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                    0.533993
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                    0.587957
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                    0.515058
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    0.587327
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    0.476192
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                    0.546006
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                    0.483828
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    0.497567
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    0.445817
#
#                                       BDT v2 Loose WP
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1         0.984090
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1           0.979881
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1          0.974871
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1          0.974913
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1          0.980599
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1          0.971012
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1          0.970185
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1          0.968183
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1          0.972771
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1          0.966696
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1          0.970554
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1          0.950705

# %% [markdown]
# #### For signal events having gen ee reconstructed (having reco e with dR < 0.1)

# %%
sig_columns_reco = list(cf_s_reco.keys())
sig_efficiency_reco = {c: [ cf_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}
sig_match_reco = {c: [ fr_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_eff_reco_df = pd.DataFrame.from_dict(sig_efficiency_reco).transpose()
sig_eff_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_eff_reco_df.index = cut

# %%
sig_eff_reco_df
# Out:
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-1  \
# Preselections                                                    0.018895
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.005339
# No b-tagged jets                                                 0.004673
# Leading jet |eta| < 2.4                                          0.004540
# Leading jet pT > 80 GeV                                          0.004540
# dPhi(MET,leading jet) > 1.5                                      0.004540
# dPhi(MET,all jets) > 0.75                                        0.004495
# BDT v2 Loose WP                                                  0.002759
#
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-1  \
# Preselections                                                  0.007196
# 0 < n(jet) < 3 & n(good vertex) > 0                            0.001282
# No b-tagged jets                                               0.001078
# Leading jet |eta| < 2.4                                        0.001027
# Leading jet pT > 80 GeV                                        0.001027
# dPhi(MET,leading jet) > 1.5                                    0.001027
# dPhi(MET,all jets) > 0.75                                      0.001020
# BDT v2 Loose WP                                                0.000670
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  \
# Preselections                                                   0.005871
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.001300
# No b-tagged jets                                                0.001159
# Leading jet |eta| < 2.4                                         0.001121
# Leading jet pT > 80 GeV                                         0.001121
# dPhi(MET,leading jet) > 1.5                                     0.001121
# dPhi(MET,all jets) > 0.75                                       0.001113
# BDT v2 Loose WP                                                 0.000660
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-1  \
# Preselections                                                   0.017167
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.004382
# No b-tagged jets                                                0.003842
# Leading jet |eta| < 2.4                                         0.003716
# Leading jet pT > 80 GeV                                         0.003716
# dPhi(MET,leading jet) > 1.5                                     0.003716
# dPhi(MET,all jets) > 0.75                                       0.003701
# BDT v2 Loose WP                                                 0.002258
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-1  \
# Preselections                                                   0.014365
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.003796
# No b-tagged jets                                                0.003237
# Leading jet |eta| < 2.4                                         0.003132
# Leading jet pT > 80 GeV                                         0.003129
# dPhi(MET,leading jet) > 1.5                                     0.003129
# dPhi(MET,all jets) > 0.75                                       0.003106
# BDT v2 Loose WP                                                 0.002013
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-1  \
# Preselections                                                   0.014169
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.003393
# No b-tagged jets                                                0.002944
# Leading jet |eta| < 2.4                                         0.002827
# Leading jet pT > 80 GeV                                         0.002821
# dPhi(MET,leading jet) > 1.5                                     0.002821
# dPhi(MET,all jets) > 0.75                                       0.002805
# BDT v2 Loose WP                                                 0.001854
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-1  \
# Preselections                                                   0.010975
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.002956
# No b-tagged jets                                                0.002587
# Leading jet |eta| < 2.4                                         0.002485
# Leading jet pT > 80 GeV                                         0.002480
# dPhi(MET,leading jet) > 1.5                                     0.002480
# dPhi(MET,all jets) > 0.75                                       0.002457
# BDT v2 Loose WP                                                 0.001732
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  \
# Preselections                                                   0.010520
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.002348
# No b-tagged jets                                                0.002031
# Leading jet |eta| < 2.4                                         0.001966
# Leading jet pT > 80 GeV                                         0.001966
# dPhi(MET,leading jet) > 1.5                                     0.001966
# dPhi(MET,all jets) > 0.75                                       0.001953
# BDT v2 Loose WP                                                 0.001221
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-1  \
# Preselections                                                   0.008736
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.002138
# No b-tagged jets                                                0.001864
# Leading jet |eta| < 2.4                                         0.001756
# Leading jet pT > 80 GeV                                         0.001756
# dPhi(MET,leading jet) > 1.5                                     0.001756
# dPhi(MET,all jets) > 0.75                                       0.001742
# BDT v2 Loose WP                                                 0.001223
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  \
# Preselections                                                   0.008445
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.001892
# No b-tagged jets                                                0.001590
# Leading jet |eta| < 2.4                                         0.001544
# Leading jet pT > 80 GeV                                         0.001542
# dPhi(MET,leading jet) > 1.5                                     0.001542
# dPhi(MET,all jets) > 0.75                                       0.001533
# BDT v2 Loose WP                                                 0.000980
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-1  \
# Preselections                                                   0.007452
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.001548
# No b-tagged jets                                                0.001346
# Leading jet |eta| < 2.4                                         0.001282
# Leading jet pT > 80 GeV                                         0.001282
# dPhi(MET,leading jet) > 1.5                                     0.001282
# dPhi(MET,all jets) > 0.75                                       0.001276
# BDT v2 Loose WP                                                 0.000839
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-1
# Preselections                                                   0.006861
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.001535
# No b-tagged jets                                                0.001296
# Leading jet |eta| < 2.4                                         0.001212
# Leading jet pT > 80 GeV                                         0.001212
# dPhi(MET,leading jet) > 1.5                                     0.001212
# dPhi(MET,all jets) > 0.75                                       0.001203
# BDT v2 Loose WP                                                 0.000731

# %%
sig_counts_reco = {c: [ ct_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_cts_reco_df = pd.DataFrame.from_dict(sig_counts_reco).transpose()
sig_cts_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_reco_df.index = cut

# %%
sig_cts_reco_df
# Out:
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-1  \
# Preselections                                                  114.614464
# 0 < n(jet) < 3 & n(good vertex) > 0                             32.386537
# No b-tagged jets                                                28.346091
# Leading jet |eta| < 2.4                                         27.537828
# Leading jet pT > 80 GeV                                         27.537828
# dPhi(MET,leading jet) > 1.5                                     27.537828
# dPhi(MET,all jets) > 0.75                                       27.266874
# BDT v2 Loose WP                                                 16.736664
#
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-1  \
# Preselections                                               1365.476804
# 0 < n(jet) < 3 & n(good vertex) > 0                          243.181188
# No b-tagged jets                                             204.476061
# Leading jet |eta| < 2.4                                      194.806789
# Leading jet pT > 80 GeV                                      194.806789
# dPhi(MET,leading jet) > 1.5                                  194.806789
# dPhi(MET,all jets) > 0.75                                    193.518798
# BDT v2 Loose WP                                              127.074408
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  \
# Preselections                                               24776.055248
# 0 < n(jet) < 3 & n(good vertex) > 0                          5486.757891
# No b-tagged jets                                             4890.702896
# Leading jet |eta| < 2.4                                      4732.804149
# Leading jet pT > 80 GeV                                      4732.804149
# dPhi(MET,leading jet) > 1.5                                  4732.804149
# dPhi(MET,all jets) > 0.75                                    4697.843379
# BDT v2 Loose WP                                              2787.316093
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-1  \
# Preselections                                                3101.831764
# 0 < n(jet) < 3 & n(good vertex) > 0                           791.708021
# No b-tagged jets                                              694.246498
# Leading jet |eta| < 2.4                                       671.352937
# Leading jet pT > 80 GeV                                       671.352937
# dPhi(MET,leading jet) > 1.5                                   671.352937
# dPhi(MET,all jets) > 0.75                                     668.649776
# BDT v2 Loose WP                                               408.001326
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-1  \
# Preselections                                                 273.875965
# 0 < n(jet) < 3 & n(good vertex) > 0                            72.375507
# No b-tagged jets                                               61.717310
# Leading jet |eta| < 2.4                                        59.709943
# Leading jet pT > 80 GeV                                        59.647115
# dPhi(MET,leading jet) > 1.5                                    59.647115
# dPhi(MET,all jets) > 0.75                                      59.208792
# BDT v2 Loose WP                                                38.387746
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-1  \
# Preselections                                                7508.961545
# 0 < n(jet) < 3 & n(good vertex) > 0                          1797.940479
# No b-tagged jets                                             1560.117606
# Leading jet |eta| < 2.4                                      1497.937569
# Leading jet pT > 80 GeV                                      1494.753860
# dPhi(MET,leading jet) > 1.5                                  1494.753860
# dPhi(MET,all jets) > 0.75                                    1486.781453
# BDT v2 Loose WP                                               982.756605
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-1  \
# Preselections                                               26139.124169
# 0 < n(jet) < 3 & n(good vertex) > 0                          7038.875821
# No b-tagged jets                                             6160.297188
# Leading jet |eta| < 2.4                                      5917.129676
# Leading jet pT > 80 GeV                                      5905.259315
# dPhi(MET,leading jet) > 1.5                                  5905.259315
# dPhi(MET,all jets) > 0.75                                    5851.900112
# BDT v2 Loose WP                                              4124.890517
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  \
# Preselections                                               15314.917103
# 0 < n(jet) < 3 & n(good vertex) > 0                          3417.531197
# No b-tagged jets                                             2956.999665
# Leading jet |eta| < 2.4                                      2862.763424
# Leading jet pT > 80 GeV                                      2862.763424
# dPhi(MET,leading jet) > 1.5                                  2862.763424
# dPhi(MET,all jets) > 0.75                                    2842.585441
# BDT v2 Loose WP                                              1777.665582
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-1  \
# Preselections                                                 513.957969
# 0 < n(jet) < 3 & n(good vertex) > 0                           125.769029
# No b-tagged jets                                              109.642462
# Leading jet |eta| < 2.4                                       103.335736
# Leading jet pT > 80 GeV                                       103.335736
# dPhi(MET,leading jet) > 1.5                                   103.335736
# dPhi(MET,all jets) > 0.75                                     102.493126
# BDT v2 Loose WP                                                71.933028
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  \
# Preselections                                               13541.063436
# 0 < n(jet) < 3 & n(good vertex) > 0                          3033.485521
# No b-tagged jets                                             2549.684920
# Leading jet |eta| < 2.4                                      2475.493613
# Leading jet pT > 80 GeV                                      2471.959428
# dPhi(MET,leading jet) > 1.5                                  2471.959428
# dPhi(MET,all jets) > 0.75                                    2457.881697
# BDT v2 Loose WP                                              1571.503625
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-1  \
# Preselections                                                 705.454724
# 0 < n(jet) < 3 & n(good vertex) > 0                           146.561050
# No b-tagged jets                                              127.369315
# Leading jet |eta| < 2.4                                       121.396524
# Leading jet pT > 80 GeV                                       121.396524
# dPhi(MET,leading jet) > 1.5                                   121.396524
# dPhi(MET,all jets) > 0.75                                     120.757685
# BDT v2 Loose WP                                                79.375994
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-1
# Preselections                                               16968.666968
# 0 < n(jet) < 3 & n(good vertex) > 0                          3796.110522
# No b-tagged jets                                             3204.558647
# Leading jet |eta| < 2.4                                      2996.709036
# Leading jet pT > 80 GeV                                      2996.709036
# dPhi(MET,leading jet) > 1.5                                  2996.709036
# dPhi(MET,all jets) > 0.75                                    2975.416989
# BDT v2 Loose WP                                              1807.605719

# %%
sig_match_reco_df = pd.DataFrame.from_dict(sig_match_reco).transpose()
sig_match_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_reco_df.index = cut

# %%
sig_match_reco_df.transpose()
# Out:
#                                       Preselections  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1            1.0
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             1.0
#
#                                       0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                             0.783464
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                               0.718975
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                              0.696563
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                              0.743470
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                              0.766975
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                              0.750711
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                              0.759740
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                              0.708056
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                              0.733584
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                              0.715952
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                              0.690030
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                              0.674161
#
#                                       No b-tagged jets  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          0.780961
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1            0.728877
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           0.709741
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1           0.749488
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           0.781552
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           0.754638
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           0.762082
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           0.697816
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           0.739163
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           0.714657
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1           0.696920
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           0.688864
#
#                                       Leading jet |eta| < 2.4  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.784326
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.728650
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.707484
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.748982
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.780519
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.750825
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.762326
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.694928
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.738166
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.711820
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.696058
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.690414
#
#                                       Leading jet pT > 80 GeV  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.784326
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.728650
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.707484
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.748982
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.780288
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.751358
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.762854
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.694928
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.738166
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.711408
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.696058
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.690414
#
#                                       dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     0.784326
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                       0.728650
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                      0.707484
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                      0.748982
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      0.780288
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                      0.751358
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                      0.762854
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                      0.694928
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                      0.738166
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                      0.711408
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                      0.696058
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                      0.690414
#
#                                       dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                   0.792120
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     0.730172
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    0.709024
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                    0.749991
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                    0.782891
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                    0.753241
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    0.763731
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    0.696315
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                    0.738754
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                    0.711188
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    0.699740
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    0.691778
#
#                                       BDT v2 Loose WP
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1         1.000000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1           0.989834
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1          0.974871
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1          0.984575
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1          0.990185
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1          0.978888
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1          0.982732
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1          0.977354
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1          0.974663
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1          0.977558
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1          0.973152
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1          0.967539

# %%
sig_match_df.transpose()
# Out:
#                                       Preselections  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1            1.0
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             1.0
#
#                                       0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                             0.599086
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                               0.500157
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                              0.422538
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                              0.520468
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                              0.571031
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                              0.504216
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                              0.583515
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                              0.477517
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                              0.534935
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                              0.479327
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                              0.488216
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                              0.440402
#
#                                       No b-tagged jets  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1          0.612185
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1            0.516939
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1           0.434271
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1           0.531196
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1           0.587514
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1           0.512162
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1           0.585022
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1           0.475646
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1           0.544248
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1           0.477280
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1           0.496499
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           0.440961
#
#                                       Leading jet |eta| < 2.4  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.526463
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.586940
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.513494
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.584129
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.483015
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.444533
#
#                                       Leading jet pT > 80 GeV  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                 0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                   0.527727
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                  0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                  0.586613
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                  0.513512
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  0.584708
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                  0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                  0.482514
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                  0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.445046
#
#                                       dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                     0.625180
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                       0.527727
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                      0.438133
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                      0.533386
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                      0.586613
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                      0.513512
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                      0.584708
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                      0.474397
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                      0.543458
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                      0.482514
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                      0.494468
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                      0.445046
#
#                                       dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                   0.630122
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                     0.530413
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    0.439877
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                    0.533993
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                    0.587957
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                    0.515058
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    0.587327
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    0.476192
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                    0.546006
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                    0.483828
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                    0.497567
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    0.445817
#
#                                       BDT v2 Loose WP
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1         0.984090
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1           0.979881
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1          0.974871
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1          0.974913
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1          0.980599
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1          0.971012
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1          0.970185
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1          0.968183
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1          0.972771
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1          0.966696
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1          0.970554
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1          0.950705

# %% [markdown]
# ### Cutflow Dataframe -- background

# %%
cuts = list(bkg_histos['W+jets']['cutflow']['bkg_2018_WJetsLNu_HT2500toInf'])

# %%
tot_bkg_cts = {} 
tot_bkg_effs = {} 
total_bkg_counts = {}

# %%
for b in bkg_histos.keys():
    
    total_bkg_counts[b] = 0
    for k in bkg_histos[b]['cutflow'].keys():
        total_bkg_counts[b] += bkg_histos[b]['cutflow_cts'][k]['all'] / bkg_histos[b]['cutflow'][k]['all']

# %%
for b in bkg_histos.keys():
    cfd = bkg_histos[b]['cutflow_cts']
    effd = bkg_histos[b]['cutflow']

    cts_dict = {k:0 for k in cuts}
    
    for k in cfd.keys():
        for c in cuts:
            cts_dict[c] += cfd[k][c]

    tot_bkg_cts[b] = cts_dict # subprocess summed
    tot_bkg_effs[b] = {c:cts_dict[c]/total_bkg_counts[b] for c in cuts}

# %%
bkg_summed_cts = {c:sum([tot_bkg_cts[b][c] for b in tot_bkg_cts.keys()]) for c in cuts}

# %%
bkg_summed_eff = {c: bkg_summed_cts[c] / sum(total_bkg_counts.values()) for c in cuts}

# %%
bkg_columns = list(bkg_histos.keys())
bkg_columns.append('total')

tot_bkg_effs['total'] = bkg_summed_eff
tot_bkg_cts['total'] = bkg_summed_cts

# %%
bkg_efficiency = {c: [ tot_bkg_effs[samp][c] for samp in bkg_columns ] for c in cuts}
bkg_counts = {c: [ tot_bkg_cts[samp][c] for samp in bkg_columns ] for c in cuts}

# %%
bkg_eff_df = pd.DataFrame.from_dict(bkg_efficiency).transpose()
bkg_eff_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_eff_df.index = cut

# %%
bkg_eff_df
# Out:
#                                               QCD           Top            DY  \
# Preselections                        1.765167e-06  1.294682e-04  1.126054e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  8.736155e-08  1.277478e-05  5.215843e-07
# No b-tagged jets                     6.157029e-08  7.989828e-06  4.841556e-07
# Leading jet |eta| < 2.4              6.120635e-08  7.173793e-06  4.841556e-07
# Leading jet pT > 80 GeV              6.120635e-08  7.149992e-06  4.841556e-07
# dPhi(MET,leading jet) > 1.5          6.117856e-08  7.149145e-06  4.841556e-07
# dPhi(MET,all jets) > 0.75            2.933839e-08  6.716169e-06  3.539610e-07
# BDT v2 Loose WP                      0.000000e+00  7.461726e-09  0.000000e+00
#
#                                           Diboson  Triboson        W+jets  \
# Preselections                        6.373026e-04  0.001933  2.309964e-03
# 0 < n(jet) < 3 & n(good vertex) > 0  4.435487e-05  0.000158  1.729308e-04
# No b-tagged jets                     3.273392e-05  0.000104  1.387287e-04
# Leading jet |eta| < 2.4              3.073427e-05  0.000092  1.315265e-04
# Leading jet pT > 80 GeV              3.043376e-05  0.000091  1.312650e-04
# dPhi(MET,leading jet) > 1.5          3.029834e-05  0.000091  1.312209e-04
# dPhi(MET,all jets) > 0.75            2.727575e-05  0.000076  1.139098e-04
# BDT v2 Loose WP                      7.046273e-08  0.000000  2.391631e-07
#
#                                            Z+jets         total
# Preselections                        6.645339e-03  1.878092e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  3.983155e-04  1.258685e-06
# No b-tagged jets                     3.251023e-04  1.005441e-06
# Leading jet |eta| < 2.4              3.095805e-04  9.577009e-07
# Leading jet pT > 80 GeV              3.090021e-04  9.559090e-07
# dPhi(MET,leading jet) > 1.5          3.089645e-04  9.556166e-07
# dPhi(MET,all jets) > 0.75            2.923517e-04  8.272960e-07
# BDT v2 Loose WP                      3.544899e-07  1.387641e-09

# %%
bkg_cts_df = pd.DataFrame.from_dict(bkg_counts).transpose()
bkg_cts_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_cts_df.index = cut

# %%
bkg_cts_df
# Out:
#                                               QCD          Top            DY  \
# Preselections                        38039.826987  5667.491120  14495.724273
# 0 < n(jet) < 3 & n(good vertex) > 0   1882.665324   559.218223    671.436619
# No b-tagged jets                      1326.856559   349.755962    623.254666
# Leading jet |eta| < 2.4               1319.013605   314.033934    623.254666
# Leading jet pT > 80 GeV               1319.013605   312.992040    623.254666
# dPhi(MET,leading jet) > 1.5           1318.414646   312.954947    623.254666
# dPhi(MET,all jets) > 0.75              632.250399   294.001347    455.654738
# BDT v2 Loose WP                          0.000000     0.326638      0.000000
#
#                                          Diboson   Triboson         W+jets  \
# Preselections                        4424.202428  52.996922  227212.601036
# 0 < n(jet) < 3 & n(good vertex) > 0   307.914836   4.324318   17009.814573
# No b-tagged jets                      227.241343   2.854129   13645.628528
# Leading jet |eta| < 2.4               213.359570   2.510261   12937.207075
# Leading jet pT > 80 GeV               211.273431   2.506022   12911.488177
# dPhi(MET,leading jet) > 1.5           210.333328   2.501784   12907.145737
# dPhi(MET,all jets) > 0.75             189.350279   2.086892   11204.390252
# BDT v2 Loose WP                         0.489158   0.000000      23.524556
#
#                                             Z+jets          total
# Preselections                        142220.153499  432112.996264
# 0 < n(jet) < 3 & n(good vertex) > 0    8524.545695   28959.919588
# No b-tagged jets                       6957.674053   23133.265240
# Leading jet |eta| < 2.4                6625.483327   22034.862439
# Leading jet pT > 80 GeV                6613.106470   21993.634411
# dPhi(MET,leading jet) > 1.5            6612.301368   21986.906477
# dPhi(MET,all jets) > 0.75              6256.761468   19034.495374
# BDT v2 Loose WP                           7.586612      31.926964

# %%
# bkg efficiencies summed over sub-samples

plt.figure(figsize=(8,6))
plt.title(r"Background Efficiencies: BDT-based, $c\tau$=1 SR")

for b in bkg_histos.keys():
    cfbs = tot_bkg_effs[b]
    effs = [cfbs[c] for c in cuts]
    plt.plot(np.arange(len(effs)),effs,label=b)
    #plt.ylim([1e-12,1])

plt.yscale('log')
plt.ylabel("Efficiency")
plt.legend(loc='upper right',ncol=2)
plt.grid()

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
cut = list(map(lambda x: x.replace('BDT v2 Loose WP', 'BDT Loose WP'), cut))
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cut, rotation = 45, ha = 'right')

plt.ylim([1e-8, 5e-2])
plt.show()

#os.makedirs("plots/cutflows/")
plt.savefig(f"plots/bkg_BDT-ctau1_combined_efficiencies.png")

# %% [markdown]
# ### Bkg Yield

# %%
sqrtB = np.sqrt(bkg_cts_df.iloc[-1].loc['total'])

print('Total background after last SR cut: {:.2f}'.format(bkg_cts_df['total'].iloc[-1]))
print('sqrt(B) = {:.2f}'.format(sqrtB))
# Out:
# Total background after last SR cut: 31.93
# sqrt(B) = 5.65

# %%
sqrtBs['1'] = sqrtB

# %% [markdown]
# ### Signal Yield and Vtx Gen Matching Fraction

# %%
s_df = sig_cts_df.iloc[-1]
s_match_df = sig_match_df.iloc[-1]

# when only looking at the events where gen ee are reconstructed (dR(gen,reco)<0.1)
s_reco_df = sig_cts_reco_df.iloc[-1]
s_match_reco_df = sig_match_reco_df.iloc[-1]

# %%
columns_ctau = {'1': {'0p1': [], '0p2': []}, '10': {'0p1': [], '0p2': []}, '100': {'0p1': [], '0p2': []}}

for name in sig_columns:
    
    mchi = ptools.signalPoint(name)['mchi']
    dmchi = ptools.signalPoint(name)['dmchi']
    delta = ptools.signalPoint(name)['delta']

    if 'ctau-10' not in name:
        if delta == 0.1:
            columns_ctau['1']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['1']['0p2'].append(name)
    elif 'ctau-100' not in name:
        if delta == 0.1:
            columns_ctau['10']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['10']['0p2'].append(name)
    else:
        if delta == 0.1:
            columns_ctau['100']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['100']['0p2'].append(name)

ct = '1'
delta = '0p1'
print(columns_ctau[ct][delta])
# Out:
# ['sig_2018_Mchi-5p25_dMchi-0p5_ctau-1', 'sig_2018_Mchi-52p5_dMchi-5p0_ctau-1', 'sig_2018_Mchi-42p0_dMchi-4p0_ctau-1', 'sig_2018_Mchi-31p5_dMchi-3p0_ctau-1', 'sig_2018_Mchi-21p0_dMchi-2p0_ctau-1', 'sig_2018_Mchi-10p5_dMchi-1p0_ctau-1']

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['1']:
        signal_df[delta][ctau] = s_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_df[delta][ctau].rename(index = {signal_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_df[delta][ctau] = s_match_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_df[delta][ctau].rename(index = {signal_match_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield for delta = 0.1, ctau = 1')
signal_df['0p1']['1'].transpose()
# Out:
# Signal yield for delta = 0.1, ctau = 1
#                                              1mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1  1839.613547
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  1589.161260
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  1794.503944
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1   990.728036
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1   412.044822
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  2787.316093

# %%
print('Vertex purity for delta = 0.1, ctau = 1')
signal_match_df['0p1']['1'].transpose()
# Out:
# Vertex purity for delta = 0.1, ctau = 1
#                                           1mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1  0.950705
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  0.966696
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  0.968183
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1  0.971012
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1  0.974913
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  0.974871

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['1']:
        signal_reco_df[delta][ctau] = s_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_reco_df[delta][ctau].rename(index = {signal_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_reco_df[delta][ctau] = s_match_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_reco_df[delta][ctau].rename(index = {signal_match_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 1')
signal_reco_df['0p1']['1'].transpose()
# Out:
# Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 1
#                                              1mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1  1807.605719
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  1571.503625
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  1777.665582
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1   982.756605
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1   408.001326
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  2787.316093

# %%
print('Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 1')
signal_match_reco_df['0p1']['1'].transpose()
# Out:
# Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 1
#                                           1mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1  0.967539
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1  0.977558
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1  0.977354
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1  0.978888
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1  0.984575
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1  0.974871

# %%
deltas = [0.1,0.2]

ct = 1

fig,axes = plt.subplots(1,len(deltas),figsize=(6*len(deltas),6))

for i, delta in enumerate(deltas):
    plt.sca(axes[i])
    plot_efficiency_signal_varying_M1( df_sig = si, dict_eff = cf_s, cuts = cuts, cutNames = cutNames, 
                                       delta = delta, ct = ct)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ctau-10

# %% [markdown]
# ### Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = '_SR_BDTv2_ctau-10_5to50_skimmed'

# %%
# Signal
f_sig = "signal"
sig_histo = util.load(f'{prefix}/{f_sig}{suffix}.coffea')[0]

# %%
# Background
bkg_files = {
    "QCD": "bkg_2018_QCD_TuneCP5_PSWeights", # No entry for QCD
    "Top": "bkg_2018_Top",
    "DY": "bkg_2018_DY",
    "Diboson": "bkg_2018_Diboson",
    "Triboson": "bkg_2018_Triboson",
    "W+jets": "bkg_2018_WJets",
    "Z+jets": "bkg_2018_ZJets",
}

bkg_histos = {}
histograms = []

for b in bkg_files.keys():
    bkg_histos[b] = util.load(f'{prefix}/{bkg_files[b]}{suffix}.coffea')[0]
    histograms = list(bkg_histos[b].keys())

# %% [markdown]
# ### Cutflow Dataframe -- signal

# %%
sig_samples = list(sig_histo['cutflow'].keys()) # names of signal sub-process, i.e. mass point, lifetime etc.
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
# signal efficiencies by delta/ctau
cf_s = sig_histo['cutflow']              # efficiency
ct_s = sig_histo['cutflow_cts']          # xsec-weighted event count
fr_s = sig_histo['cutflow_vtx_matched'] # fraction that selected vtx is truth-matched, for signal
desc = sig_histo['cutDesc']

# %%
# signal efficiencies, when only looking at the events where the gen ee are reconstructed (dR(gen,reco) < 0.1)
cf_s_reco = sig_histo['cutflow_genEEreconstructed']              # efficiency
ct_s_reco = sig_histo['cutflow_cts_genEEreconstructed']          # xsec-weighted event count
fr_s_reco = sig_histo['cutflow_vtx_matched_genEEreconstructed']  # fraction that selected vtx is truth-matched, for signal

# %%
cuts = list(sig_histo['cutflow'][sig_samples[0]].keys())
cutNames = {cname:ptools.getCut(sig_histo['cutDesc'][cname]) for cname in sig_histo['cutDesc'].keys()}

# %%
deltas = sorted(list(set(si.delta)))

# %% [markdown]
# #### For signal events

# %%
sig_columns = list(cf_s.keys())
sig_efficiency = {c: [ cf_s[samp][c] for samp in sig_columns ] for c in cuts}
sig_match = {c: [ fr_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_eff_df = pd.DataFrame.from_dict(sig_efficiency).transpose()
sig_eff_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
cut = list(map(lambda x: x.replace('BDT v2 Loose WP', 'BDT Loose WP'), cut))


sig_eff_df.index = cut

# %%
sig_eff_df.transpose()
# Out:
#                                        Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10         0.010930
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10       0.031125
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10        0.010676
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10        0.032445
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10        0.025875
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10        0.019309
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10        0.024702
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10        0.020128
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10        0.016286
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10        0.012593
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10        0.015838
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10        0.012434
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                               0.001187
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                             0.005252
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                              0.001022
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                              0.004564
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                              0.003520
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                              0.002550
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                              0.003809
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                              0.002757
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                              0.001989
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                              0.001410
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                              0.001936
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                              0.001380
#
#                                        No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10            0.000987
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10          0.004562
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10           0.000847
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10           0.003903
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10           0.003022
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10           0.002202
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10           0.003226
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10           0.002373
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10           0.001734
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10           0.001150
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10           0.001685
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10           0.001180
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.000935
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.004329
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.000792
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.003752
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.002902
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.002122
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.003090
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.002303
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.001669
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.001083
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.001584
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.001116
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.000931
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.004329
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.000792
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.003752
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.002902
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.002120
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.003090
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.002301
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.001669
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.001083
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.001584
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.001116
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                       0.000931
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                     0.004329
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                      0.000792
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                      0.003752
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                      0.002902
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                      0.002120
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                      0.003090
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                      0.002301
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                      0.001669
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                      0.001083
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                      0.001584
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      0.001116
#
#                                        dPhi(MET,all jets) > 0.75  BDT Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                     0.000876      0.000235
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                   0.004260      0.002026
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                    0.000771      0.000147
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                    0.003708      0.001414
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                    0.002875      0.001118
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                    0.002075      0.000990
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                    0.003027      0.001360
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                    0.002280      0.000865
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                    0.001649      0.000515
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                    0.001046      0.000354
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                    0.001549      0.000681
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                    0.001085      0.000306

# %%
sig_counts = {c: [ ct_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_cts_df = pd.DataFrame.from_dict(sig_counts).transpose()
sig_cts_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_df.index = cut

# %%
sig_cts_df.transpose()
# Out:
#                                        Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10       211.621136
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10      18.964345
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10     6090.241352
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10      625.950369
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10     1569.133425
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10    15555.452101
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10       47.304640
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10    27263.502227
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10     3043.716823
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10      118.479518
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10       93.998636
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10     3591.894377
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                              22.976276
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                             3.200085
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                            583.268175
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                             88.057684
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                            213.483994
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                           2054.322570
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                              7.295161
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                           3734.673787
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                            371.803097
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                             13.269842
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                             11.489254
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                            398.724018
#
#                                        No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10           19.101673
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10          2.779586
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10         483.383984
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10          75.299194
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10         183.289395
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10        1773.838230
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10           6.178194
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10        3214.536713
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10         324.157435
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10          10.814831
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10          10.001554
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10         340.802750
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                  18.099530
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 2.637744
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                451.729326
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                 72.378771
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                176.009913
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10               1709.695777
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  5.917338
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10               3119.890211
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                312.003112
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                 10.192790
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  9.400079
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                322.406777
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                  18.033157
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 2.637744
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                451.729326
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                 72.378771
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                176.009913
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10               1707.690425
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  5.917338
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10               3117.259784
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                312.003112
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                 10.192790
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  9.400079
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                322.406777
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                      18.033157
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                     2.637744
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                    451.729326
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                     72.378771
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                    176.009913
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                   1707.690425
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                      5.917338
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                   3117.259784
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                    312.003112
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                     10.192790
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                      9.400079
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                    322.406777
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                    16.965408
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                   2.595839
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  439.550936
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                   71.542770
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  174.341026
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                 1671.585091
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                    5.797324
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                 3088.326520
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  308.264550
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                    9.839573
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                    9.195837
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  313.433122
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10           4.543953
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10         1.234690
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10         84.007888
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10         27.287742
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10         67.818152
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10        797.807828
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10          2.603764
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10       1171.794549
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10         96.233563
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10          3.330175
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10          4.041440
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10         88.454491

# %%
sig_match_df = pd.DataFrame.from_dict(sig_match).transpose()
sig_match_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_df.index = cut

# %%
sig_match_df.transpose()
# Out:
#                                        Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10              1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10            1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10             1.0
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                               0.296610
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                             0.537021
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                              0.265125
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                              0.456355
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                              0.438500
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                              0.503462
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                              0.502103
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                              0.412978
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                              0.358085
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                              0.363771
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                              0.442683
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                              0.350253
#
#                                        No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10            0.314809
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10          0.548269
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10           0.284620
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10           0.448635
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10           0.446179
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10           0.510812
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10           0.508406
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10           0.420965
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10           0.357367
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10           0.363912
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10           0.456297
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10           0.350479
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.306420
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.517052
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.426144
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.356567
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.307548
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.517659
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.425660
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.356567
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                       0.307548
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                     0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                      0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                      0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                      0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                      0.517659
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                      0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                      0.425660
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                      0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                      0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                      0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      0.356567
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                     0.322959
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                   0.558713
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                    0.290839
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                    0.453389
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                    0.454287
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                    0.520439
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                    0.520219
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                    0.427091
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                    0.354561
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                    0.377762
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                    0.467873
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                    0.362470
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10           0.941216
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10         0.987220
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10          0.883988
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10          0.977909
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10          0.973147
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10          0.987457
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10          0.975969
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10          0.975273
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10          0.941807
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10          0.969699
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10          0.966278
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10          0.959399

# %% [markdown]
# #### For signal events having gen ee reconstructed (having reco e with dR < 0.1)

# %%
sig_columns_reco = list(cf_s_reco.keys())
sig_efficiency_reco = {c: [ cf_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}
sig_match_reco = {c: [ fr_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_eff_reco_df = pd.DataFrame.from_dict(sig_efficiency_reco).transpose()
sig_eff_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_eff_reco_df.index = cut

# %%
sig_eff_reco_df
# Out:
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-10  \
# Preselections                                                   0.002953
# 0 < n(jet) < 3 & n(good vertex) > 0                             0.000521
# No b-tagged jets                                                0.000445
# Leading jet |eta| < 2.4                                         0.000421
# Leading jet pT > 80 GeV                                         0.000421
# dPhi(MET,leading jet) > 1.5                                     0.000421
# dPhi(MET,all jets) > 0.75                                       0.000404
# BDT v2 Loose WP                                                 0.000228
#
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-10  \
# Preselections                                                     0.013324
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.003597
# No b-tagged jets                                                  0.003148
# Leading jet |eta| < 2.4                                           0.003001
# Leading jet pT > 80 GeV                                           0.003001
# dPhi(MET,leading jet) > 1.5                                       0.003001
# dPhi(MET,all jets) > 0.75                                         0.002958
# BDT v2 Loose WP                                                   0.002009
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-10  \
# Preselections                                                    0.002087
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.000420
# No b-tagged jets                                                 0.000369
# Leading jet |eta| < 2.4                                          0.000350
# Leading jet pT > 80 GeV                                          0.000350
# dPhi(MET,leading jet) > 1.5                                      0.000350
# dPhi(MET,all jets) > 0.75                                        0.000339
# BDT v2 Loose WP                                                  0.000141
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-10  \
# Preselections                                                    0.011383
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.002751
# No b-tagged jets                                                 0.002338
# Leading jet |eta| < 2.4                                          0.002263
# Leading jet pT > 80 GeV                                          0.002263
# dPhi(MET,leading jet) > 1.5                                      0.002263
# dPhi(MET,all jets) > 0.75                                        0.002234
# BDT v2 Loose WP                                                  0.001400
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-10  \
# Preselections                                                    0.009238
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.002102
# No b-tagged jets                                                 0.001814
# Leading jet |eta| < 2.4                                          0.001767
# Leading jet pT > 80 GeV                                          0.001767
# dPhi(MET,leading jet) > 1.5                                      0.001767
# dPhi(MET,all jets) > 0.75                                        0.001754
# BDT v2 Loose WP                                                  0.001103
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-10  \
# Preselections                                                    0.007543
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.001655
# No b-tagged jets                                                 0.001441
# Leading jet |eta| < 2.4                                          0.001403
# Leading jet pT > 80 GeV                                          0.001403
# dPhi(MET,leading jet) > 1.5                                      0.001403
# dPhi(MET,all jets) > 0.75                                        0.001376
# BDT v2 Loose WP                                                  0.000988
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-10  \
# Preselections                                                    0.010259
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.002417
# No b-tagged jets                                                 0.002054
# Leading jet |eta| < 2.4                                          0.001989
# Leading jet pT > 80 GeV                                          0.001989
# dPhi(MET,leading jet) > 1.5                                      0.001989
# dPhi(MET,all jets) > 0.75                                        0.001959
# BDT v2 Loose WP                                                  0.001349
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  \
# Preselections                                                    0.006725
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.001519
# No b-tagged jets                                                 0.001308
# Leading jet |eta| < 2.4                                          0.001284
# Leading jet pT > 80 GeV                                          0.001282
# dPhi(MET,leading jet) > 1.5                                      0.001282
# dPhi(MET,all jets) > 0.75                                        0.001277
# BDT v2 Loose WP                                                  0.000861
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-10  \
# Preselections                                                    0.004959
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.001032
# No b-tagged jets                                                 0.000887
# Leading jet |eta| < 2.4                                          0.000850
# Leading jet pT > 80 GeV                                          0.000850
# dPhi(MET,leading jet) > 1.5                                      0.000850
# dPhi(MET,all jets) > 0.75                                        0.000842
# BDT v2 Loose WP                                                  0.000500
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-10  \
# Preselections                                                    0.004207
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.000765
# No b-tagged jets                                                 0.000627
# Leading jet |eta| < 2.4                                          0.000597
# Leading jet pT > 80 GeV                                          0.000597
# dPhi(MET,leading jet) > 1.5                                      0.000597
# dPhi(MET,all jets) > 0.75                                        0.000590
# BDT v2 Loose WP                                                  0.000350
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-10  \
# Preselections                                                    0.005956
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.001176
# No b-tagged jets                                                 0.001025
# Leading jet |eta| < 2.4                                          0.000979
# Leading jet pT > 80 GeV                                          0.000979
# dPhi(MET,leading jet) > 1.5                                      0.000979
# dPhi(MET,all jets) > 0.75                                        0.000960
# BDT v2 Loose WP                                                  0.000668
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-10
# Preselections                                                    0.003264
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.000693
# No b-tagged jets                                                 0.000589
# Leading jet |eta| < 2.4                                          0.000564
# Leading jet pT > 80 GeV                                          0.000564
# dPhi(MET,leading jet) > 1.5                                      0.000564
# dPhi(MET,all jets) > 0.75                                        0.000552
# BDT v2 Loose WP                                                  0.000298

# %%
sig_counts_reco = {c: [ ct_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_cts_reco_df = pd.DataFrame.from_dict(sig_counts_reco).transpose()
sig_cts_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_reco_df.index = cut

# %%
sig_cts_reco_df
# Out:
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-10  \
# Preselections                                                  57.180228
# 0 < n(jet) < 3 & n(good vertex) > 0                            10.088073
# No b-tagged jets                                                8.618702
# Leading jet |eta| < 2.4                                         8.151389
# Leading jet pT > 80 GeV                                         8.151389
# dPhi(MET,leading jet) > 1.5                                     8.151389
# dPhi(MET,all jets) > 0.75                                       7.816946
# BDT v2 Loose WP                                                 4.410148
#
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-10  \
# Preselections                                                     8.118168
# 0 < n(jet) < 3 & n(good vertex) > 0                               2.191445
# No b-tagged jets                                                  1.918127
# Leading jet |eta| < 2.4                                           1.828723
# Leading jet pT > 80 GeV                                           1.828723
# dPhi(MET,leading jet) > 1.5                                       1.828723
# dPhi(MET,all jets) > 0.75                                         1.802543
# BDT v2 Loose WP                                                   1.224196
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-10  \
# Preselections                                                 1190.665743
# 0 < n(jet) < 3 & n(good vertex) > 0                            239.882501
# No b-tagged jets                                               210.620371
# Leading jet |eta| < 2.4                                        199.669941
# Leading jet pT > 80 GeV                                        199.669941
# dPhi(MET,leading jet) > 1.5                                    199.669941
# dPhi(MET,all jets) > 0.75                                      193.575064
# BDT v2 Loose WP                                                 80.348722
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-10  \
# Preselections                                                  219.612491
# 0 < n(jet) < 3 & n(good vertex) > 0                             53.079174
# No b-tagged jets                                                45.099587
# Leading jet |eta| < 2.4                                         43.662325
# Leading jet pT > 80 GeV                                         43.662325
# dPhi(MET,leading jet) > 1.5                                     43.662325
# dPhi(MET,all jets) > 0.75                                       43.105379
# BDT v2 Loose WP                                                 27.009639
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-10  \
# Preselections                                                  560.229583
# 0 < n(jet) < 3 & n(good vertex) > 0                            127.453176
# No b-tagged jets                                               110.008161
# Leading jet |eta| < 2.4                                        107.127099
# Leading jet pT > 80 GeV                                        107.127099
# dPhi(MET,leading jet) > 1.5                                    107.127099
# dPhi(MET,all jets) > 0.75                                      106.368538
# BDT v2 Loose WP                                                 66.908321
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-10  \
# Preselections                                                 6077.058542
# 0 < n(jet) < 3 & n(good vertex) > 0                           1332.950630
# No b-tagged jets                                              1160.672436
# Leading jet |eta| < 2.4                                       1130.570090
# Leading jet pT > 80 GeV                                       1130.570090
# dPhi(MET,leading jet) > 1.5                                   1130.570090
# dPhi(MET,all jets) > 0.75                                     1108.501708
# BDT v2 Loose WP                                                795.806789
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-10  \
# Preselections                                                   19.646746
# 0 < n(jet) < 3 & n(good vertex) > 0                              4.628290
# No b-tagged jets                                                 3.934190
# Leading jet |eta| < 2.4                                          3.808996
# Leading jet pT > 80 GeV                                          3.808996
# dPhi(MET,leading jet) > 1.5                                      3.808996
# dPhi(MET,all jets) > 0.75                                        3.751665
# BDT v2 Loose WP                                                  2.582899
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  \
# Preselections                                                 9108.794445
# 0 < n(jet) < 3 & n(good vertex) > 0                           2057.511851
# No b-tagged jets                                              1771.216758
# Leading jet |eta| < 2.4                                       1739.634497
# Leading jet pT > 80 GeV                                       1737.003785
# dPhi(MET,leading jet) > 1.5                                   1737.003785
# dPhi(MET,all jets) > 0.75                                     1729.109791
# BDT v2 Loose WP                                               1166.521911
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-10  \
# Preselections                                                  926.846150
# 0 < n(jet) < 3 & n(good vertex) > 0                            192.901624
# No b-tagged jets                                               165.806615
# Leading jet |eta| < 2.4                                        158.798775
# Leading jet pT > 80 GeV                                        158.798775
# dPhi(MET,leading jet) > 1.5                                    158.798775
# dPhi(MET,all jets) > 0.75                                      157.395984
# BDT v2 Loose WP                                                 93.430809
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-10  \
# Preselections                                                   39.578707
# 0 < n(jet) < 3 & n(good vertex) > 0                              7.198891
# No b-tagged jets                                                 5.903361
# Leading jet |eta| < 2.4                                          5.617535
# Leading jet pT > 80 GeV                                          5.617535
# dPhi(MET,leading jet) > 1.5                                      5.617535
# dPhi(MET,all jets) > 0.75                                        5.550187
# BDT v2 Loose WP                                                  3.296574
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-10  \
# Preselections                                                   35.351179
# 0 < n(jet) < 3 & n(good vertex) > 0                              6.982371
# No b-tagged jets                                                 6.085103
# Leading jet |eta| < 2.4                                          5.812612
# Leading jet pT > 80 GeV                                          5.812612
# dPhi(MET,leading jet) > 1.5                                      5.812612
# dPhi(MET,all jets) > 0.75                                        5.699044
# BDT v2 Loose WP                                                  3.961948
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-10
# Preselections                                                  942.926858
# 0 < n(jet) < 3 & n(good vertex) > 0                            200.260840
# No b-tagged jets                                               170.168770
# Leading jet |eta| < 2.4                                        162.991234
# Leading jet pT > 80 GeV                                        162.991234
# dPhi(MET,leading jet) > 1.5                                    162.991234
# dPhi(MET,all jets) > 0.75                                      159.398524
# BDT v2 Loose WP                                                 86.209302

# %%
sig_match_reco_df = pd.DataFrame.from_dict(sig_match_reco).transpose()
sig_match_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_reco_df.index = cut

# %%
sig_match_reco_df.transpose()
# Out:
#                                        Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10              1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10            1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10             1.0
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                               0.675550
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                             0.784191
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                              0.644644
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                              0.757087
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                              0.734488
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                              0.775928
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                              0.791420
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                              0.749614
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                              0.690181
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                              0.670545
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                              0.728420
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                              0.697362
#
#                                        No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10            0.697712
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10          0.794504
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10           0.653216
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10           0.749050
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10           0.743399
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10           0.780667
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10           0.798393
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10           0.763998
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10           0.698664
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10           0.666679
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10           0.749975
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10           0.701915
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.680382
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.793083
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.652473
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.749274
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.744983
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.781908
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.795876
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.764254
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.691227
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.667683
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.748014
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.705312
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.680382
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.793083
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.652473
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.749274
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.744983
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.781908
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.795876
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.763897
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.691227
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.667683
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.748014
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.705312
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                       0.680382
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                     0.793083
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                      0.652473
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                      0.749274
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                      0.744983
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                      0.781908
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                      0.795876
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                      0.763897
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                      0.691227
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                      0.667683
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                      0.748014
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      0.705312
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                     0.700929
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                   0.804601
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                    0.660408
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                    0.752498
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                    0.744590
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                    0.784805
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                    0.803877
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                    0.762819
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                    0.694417
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                    0.669710
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                    0.754949
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                    0.712742
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10           0.969773
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10         0.995682
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10          0.924246
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10          0.987978
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10          0.986380
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10          0.989940
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10          0.983854
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10          0.979682
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10          0.970060
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10          0.979583
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10          0.985666
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10          0.984385

# %%
sig_match_df.transpose()
# Out:
#                                        Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10              1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10            1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10             1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10             1.0
#
#                                        0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                               0.296610
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                             0.537021
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                              0.265125
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                              0.456355
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                              0.438500
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                              0.503462
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                              0.502103
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                              0.412978
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                              0.358085
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                              0.363771
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                              0.442683
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                              0.350253
#
#                                        No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10            0.314809
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10          0.548269
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10           0.284620
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10           0.448635
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10           0.446179
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10           0.510812
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10           0.508406
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10           0.420965
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10           0.357367
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10           0.363912
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10           0.456297
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10           0.350479
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.306420
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.517052
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.426144
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.356567
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                   0.307548
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                 0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                  0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                  0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                  0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                  0.517659
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                  0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                  0.425660
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                  0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                  0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                  0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                  0.356567
#
#                                        dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                       0.307548
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                     0.549837
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                      0.288401
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                      0.451998
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                      0.453428
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                      0.517659
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                      0.512306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                      0.425660
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                      0.351811
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                      0.367979
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                      0.462540
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      0.356567
#
#                                        dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10                     0.322959
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10                   0.558713
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10                    0.290839
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10                    0.453389
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10                    0.454287
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10                    0.520439
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10                    0.520219
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10                    0.427091
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10                    0.354561
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10                    0.377762
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10                    0.467873
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                    0.362470
#
#                                        BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-10           0.941216
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-10         0.987220
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10          0.883988
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10          0.977909
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10          0.973147
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-10          0.987457
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-10          0.975969
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10          0.975273
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10          0.941807
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-10          0.969699
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-10          0.966278
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10          0.959399

# %% [markdown]
# ### Cutflow Dataframe -- background

# %%
cuts = list(bkg_histos['W+jets']['cutflow']['bkg_2018_WJetsLNu_HT2500toInf'])

# %%
tot_bkg_cts = {} 
tot_bkg_effs = {} 
total_bkg_counts = {}

# %%
for b in bkg_histos.keys():
    
    total_bkg_counts[b] = 0
    for k in bkg_histos[b]['cutflow'].keys():
        total_bkg_counts[b] += bkg_histos[b]['cutflow_cts'][k]['all'] / bkg_histos[b]['cutflow'][k]['all']

# %%
for b in bkg_histos.keys():
    cfd = bkg_histos[b]['cutflow_cts']
    effd = bkg_histos[b]['cutflow']

    cts_dict = {k:0 for k in cuts}
    
    for k in cfd.keys():
        for c in cuts:
            cts_dict[c] += cfd[k][c]

    tot_bkg_cts[b] = cts_dict # subprocess summed
    tot_bkg_effs[b] = {c:cts_dict[c]/total_bkg_counts[b] for c in cuts}

# %%
bkg_summed_cts = {c:sum([tot_bkg_cts[b][c] for b in tot_bkg_cts.keys()]) for c in cuts}

# %%
bkg_summed_eff = {c: bkg_summed_cts[c] / sum(total_bkg_counts.values()) for c in cuts}

# %%
bkg_columns = list(bkg_histos.keys())
bkg_columns.append('total')

tot_bkg_effs['total'] = bkg_summed_eff
tot_bkg_cts['total'] = bkg_summed_cts

# %%
bkg_efficiency = {c: [ tot_bkg_effs[samp][c] for samp in bkg_columns ] for c in cuts}
bkg_counts = {c: [ tot_bkg_cts[samp][c] for samp in bkg_columns ] for c in cuts}

# %%
bkg_eff_df = pd.DataFrame.from_dict(bkg_efficiency).transpose()
bkg_eff_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_eff_df.index = cut

# %%
bkg_eff_df
# Out:
#                                               QCD           Top            DY  \
# Preselections                        1.765167e-06  1.294682e-04  1.126054e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  8.736155e-08  1.277478e-05  5.215843e-07
# No b-tagged jets                     6.157029e-08  7.989828e-06  4.841556e-07
# Leading jet |eta| < 2.4              6.120635e-08  7.173793e-06  4.841556e-07
# Leading jet pT > 80 GeV              6.120635e-08  7.149992e-06  4.841556e-07
# dPhi(MET,leading jet) > 1.5          6.117856e-08  7.149145e-06  4.841556e-07
# dPhi(MET,all jets) > 0.75            2.933839e-08  6.716169e-06  3.539610e-07
# BDT v2 Loose WP                      0.000000e+00  5.767040e-09  0.000000e+00
#
#                                           Diboson  Triboson        W+jets  \
# Preselections                        6.373026e-04  0.001933  2.309964e-03
# 0 < n(jet) < 3 & n(good vertex) > 0  4.435487e-05  0.000158  1.729308e-04
# No b-tagged jets                     3.273392e-05  0.000104  1.387287e-04
# Leading jet |eta| < 2.4              3.073427e-05  0.000092  1.315265e-04
# Leading jet pT > 80 GeV              3.043376e-05  0.000091  1.312650e-04
# dPhi(MET,leading jet) > 1.5          3.029834e-05  0.000091  1.312209e-04
# dPhi(MET,all jets) > 0.75            2.727575e-05  0.000076  1.139098e-04
# BDT v2 Loose WP                      4.192895e-08  0.000000  5.666668e-08
#
#                                            Z+jets         total
# Preselections                        6.645339e-03  1.878092e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  3.983155e-04  1.258685e-06
# No b-tagged jets                     3.251023e-04  1.005441e-06
# Leading jet |eta| < 2.4              3.095805e-04  9.577009e-07
# Leading jet pT > 80 GeV              3.090021e-04  9.559090e-07
# dPhi(MET,leading jet) > 1.5          3.089645e-04  9.556166e-07
# dPhi(MET,all jets) > 0.75            2.923517e-04  8.272960e-07
# BDT v2 Loose WP                      1.083628e-07  3.666755e-10

# %%
bkg_cts_df = pd.DataFrame.from_dict(bkg_counts).transpose()
bkg_cts_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_cts_df.index = cut

# %%
bkg_cts_df
# Out:
#                                               QCD          Top            DY  \
# Preselections                        38039.826987  5667.491120  14495.724273
# 0 < n(jet) < 3 & n(good vertex) > 0   1882.665324   559.218223    671.436619
# No b-tagged jets                      1326.856559   349.755962    623.254666
# Leading jet |eta| < 2.4               1319.013605   314.033934    623.254666
# Leading jet pT > 80 GeV               1319.013605   312.992040    623.254666
# dPhi(MET,leading jet) > 1.5           1318.414646   312.954947    623.254666
# dPhi(MET,all jets) > 0.75              632.250399   294.001347    455.654738
# BDT v2 Loose WP                          0.000000     0.252453      0.000000
#
#                                          Diboson   Triboson         W+jets  \
# Preselections                        4424.202428  52.996922  227212.601036
# 0 < n(jet) < 3 & n(good vertex) > 0   307.914836   4.324318   17009.814573
# No b-tagged jets                      227.241343   2.854129   13645.628528
# Leading jet |eta| < 2.4               213.359570   2.510261   12937.207075
# Leading jet pT > 80 GeV               211.273431   2.506022   12911.488177
# dPhi(MET,leading jet) > 1.5           210.333328   2.501784   12907.145737
# dPhi(MET,all jets) > 0.75             189.350279   2.086892   11204.390252
# BDT v2 Loose WP                         0.291074   0.000000       5.573847
#
#                                             Z+jets          total
# Preselections                        142220.153499  432112.996264
# 0 < n(jet) < 3 & n(good vertex) > 0    8524.545695   28959.919588
# No b-tagged jets                       6957.674053   23133.265240
# Leading jet |eta| < 2.4                6625.483327   22034.862439
# Leading jet pT > 80 GeV                6613.106470   21993.634411
# dPhi(MET,leading jet) > 1.5            6612.301368   21986.906477
# dPhi(MET,all jets) > 0.75              6256.761468   19034.495374
# BDT v2 Loose WP                           2.319126       8.436500

# %%
# bkg efficiencies summed over sub-samples

plt.figure(figsize=(8,6))
plt.title("Background Efficiencies: BDTv2, ctau-10 SR")

for b in bkg_histos.keys():
    cfbs = tot_bkg_effs[b]
    effs = [cfbs[c] for c in cuts]
    plt.plot(np.arange(len(effs)),effs,label=b)
    #plt.ylim([1e-12,1])

plt.yscale('log')
plt.ylabel("Efficiency")
plt.legend(loc='upper right',ncol=2)
plt.grid()

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cut, rotation = 45, ha = 'right')

plt.ylim([1e-8, 5e-2])
plt.show()

#os.makedirs("plots/cutflows/")
#plt.savefig(f"plots/cutflows/bkg_combined_efficiencies.png")

# %% [markdown]
# ### Bkg Yield

# %%
sqrtB = np.sqrt(bkg_cts_df.iloc[-1].loc['total'])

print('Total background after last SR cut: {:.2f}'.format(bkg_cts_df['total'].iloc[-1]))
print('sqrt(B) = {:.2f}'.format(sqrtB))
# Out:
# Total background after last SR cut: 8.44
# sqrt(B) = 2.90

# %%
sqrtBs['10'] = sqrtB

# %% [markdown]
# ### Signal Yield and Vtx Gen Matching Fraction

# %%
s_df = sig_cts_df.iloc[-1]
s_match_df = sig_match_df.iloc[-1]

# when only looking at the events where gen ee are reconstructed (dR(gen,reco)<0.1)
s_reco_df = sig_cts_reco_df.iloc[-1]
s_match_reco_df = sig_match_reco_df.iloc[-1]

# %%
columns_ctau = {'1': {'0p1': [], '0p2': []}, '10': {'0p1': [], '0p2': []}, '100': {'0p1': [], '0p2': []}}

for name in sig_columns:
    
    mchi = ptools.signalPoint(name)['mchi']
    dmchi = ptools.signalPoint(name)['dmchi']
    delta = ptools.signalPoint(name)['delta']

    if 'ctau-10' not in name:
        if delta == 0.1:
            columns_ctau['1']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['1']['0p2'].append(name)
    elif 'ctau-100' not in name:
        if delta == 0.1:
            columns_ctau['10']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['10']['0p2'].append(name)
    else:
        if delta == 0.1:
            columns_ctau['100']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['100']['0p2'].append(name)

ct = '10'
delta = '0p1'
print(columns_ctau[ct][delta])
# Out:
# ['sig_2018_Mchi-5p25_dMchi-0p5_ctau-10', 'sig_2018_Mchi-52p5_dMchi-5p0_ctau-10', 'sig_2018_Mchi-42p0_dMchi-4p0_ctau-10', 'sig_2018_Mchi-31p5_dMchi-3p0_ctau-10', 'sig_2018_Mchi-21p0_dMchi-2p0_ctau-10', 'sig_2018_Mchi-10p5_dMchi-1p0_ctau-10']

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['10']:
        signal_df[delta][ctau] = s_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_df[delta][ctau].rename(index = {signal_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_df[delta][ctau] = s_match_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_df[delta][ctau].rename(index = {signal_match_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield for delta = 0.1, ctau = 10')
signal_df['0p1']['10'].transpose()
# Out:
# Signal yield for delta = 0.1, ctau = 10
#                                              10mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10    88.454491
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10    96.233563
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  1171.794549
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10    67.818152
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10    27.287742
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10    84.007888

# %%
print('Vertex purity for delta = 0.1, ctau = 10')
signal_match_df['0p1']['10'].transpose()
# Out:
# Vertex purity for delta = 0.1, ctau = 10
#                                           10mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10  0.959399
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10  0.941807
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  0.975273
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10  0.973147
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10  0.977909
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10  0.883988

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['10']:
        signal_reco_df[delta][ctau] = s_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_reco_df[delta][ctau].rename(index = {signal_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_reco_df[delta][ctau] = s_match_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_reco_df[delta][ctau].rename(index = {signal_match_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 10')
signal_reco_df['0p1']['10'].transpose()
# Out:
# Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 10
#                                              10mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10    86.209302
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10    93.430809
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  1166.521911
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10    66.908321
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10    27.009639
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10    80.348722

# %%
print('Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 10')
signal_match_reco_df['0p1']['10'].transpose()
# Out:
# Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 10
#                                           10mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10  0.984385
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-10  0.970060
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-10  0.979682
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-10  0.986380
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-10  0.987978
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10  0.924246

# %%
deltas = [0.1,0.2]

ct = 10

fig,axes = plt.subplots(1,len(deltas),figsize=(6*len(deltas),6))

for i, delta in enumerate(deltas):
    plt.sca(axes[i])
    plot_efficiency_signal_varying_M1( df_sig = si, dict_eff = cf_s, cuts = cuts, cutNames = cutNames, 
                                       delta = delta, ct = ct)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ctau-100

# %% [markdown]
# ### Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = '_SR_BDTv2_ctau-100_5to50_skimmed'

# %%
# Signal
f_sig = "signal"
sig_histo = util.load(f'{prefix}/{f_sig}{suffix}.coffea')[0]

# %%
# Background
bkg_files = {
    "QCD": "bkg_2018_QCD_TuneCP5_PSWeights", # No entry for QCD
    "Top": "bkg_2018_Top",
    "DY": "bkg_2018_DY",
    "Diboson": "bkg_2018_Diboson",
    "Triboson": "bkg_2018_Triboson",
    "W+jets": "bkg_2018_WJets",
    "Z+jets": "bkg_2018_ZJets",
}

bkg_histos = {}
histograms = []

for b in bkg_files.keys():
    bkg_histos[b] = util.load(f'{prefix}/{bkg_files[b]}{suffix}.coffea')[0]
    histograms = list(bkg_histos[b].keys())

# %% [markdown]
# ### Cutflow Dataframe -- signal

# %%
sig_samples = list(sig_histo['cutflow'].keys()) # names of signal sub-process, i.e. mass point, lifetime etc.
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
# signal efficiencies by delta/ctau
cf_s = sig_histo['cutflow']              # efficiency
ct_s = sig_histo['cutflow_cts']          # xsec-weighted event count
fr_s = sig_histo['cutflow_vtx_matched'] # fraction that selected vtx is truth-matched, for signal
desc = sig_histo['cutDesc']

# %%
# signal efficiencies, when only looking at the events where the gen ee are reconstructed (dR(gen,reco) < 0.1)
cf_s_reco = sig_histo['cutflow_genEEreconstructed']              # efficiency
ct_s_reco = sig_histo['cutflow_cts_genEEreconstructed']          # xsec-weighted event count
fr_s_reco = sig_histo['cutflow_vtx_matched_genEEreconstructed']  # fraction that selected vtx is truth-matched, for signal

# %%
cuts = list(sig_histo['cutflow'][sig_samples[0]].keys())
cutNames = {cname:ptools.getCut(sig_histo['cutDesc'][cname]) for cname in sig_histo['cutDesc'].keys()}

# %%
deltas = sorted(list(set(si.delta)))

# %% [markdown]
# #### For signal events

# %%
sig_columns = list(cf_s.keys())
sig_efficiency = {c: [ cf_s[samp][c] for samp in sig_columns ] for c in cuts}
sig_match = {c: [ fr_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_eff_df = pd.DataFrame.from_dict(sig_efficiency).transpose()
sig_eff_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_eff_df.index = cut

# %%
sig_eff_df.transpose()
# Out:
#                                         Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100         0.007414
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100        0.007306
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100       0.022439
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100        0.022522
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100        0.013585
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100        0.017576
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100        0.017664
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100        0.013536
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100        0.010335
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100        0.010649
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100        0.007977
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100        0.008039
#
#                                         0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                               0.000647
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                              0.000596
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                             0.002420
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                              0.002231
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                              0.001285
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                              0.001802
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                              0.001657
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                              0.001197
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                              0.000922
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                              0.000928
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                              0.000601
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                              0.000647
#
#                                         No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100            0.000562
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100           0.000504
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100          0.002063
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100           0.001905
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100           0.001082
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100           0.001476
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100           0.001419
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100           0.001041
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100           0.000793
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100           0.000818
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100           0.000507
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100           0.000545
#
#                                         Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.000528
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.000475
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.001980
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.001847
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.001052
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.001411
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.001371
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.000995
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.000760
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.000775
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.000483
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.000515
#
#                                         Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.000528
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.000475
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.001980
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.001847
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.001052
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.001411
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.001371
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.000995
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.000760
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.000775
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.000483
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.000515
#
#                                         dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                       0.000528
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                      0.000475
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                     0.001980
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                      0.001847
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                      0.001052
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                      0.001411
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                      0.001371
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                      0.000995
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                      0.000760
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                      0.000775
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                      0.000483
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                      0.000515
#
#                                         dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                     0.000501
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                    0.000457
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                   0.001893
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                    0.001804
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                    0.001011
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                    0.001364
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                    0.001331
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                    0.000966
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                    0.000722
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                    0.000749
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                    0.000467
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                    0.000504
#
#                                         BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100           0.000051
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          0.000032
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100         0.000504
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100          0.000412
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100          0.000228
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100          0.000344
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100          0.000303
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100          0.000177
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100          0.000162
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          0.000111
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100          0.000075
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          0.000065

# %%
sig_counts = {c: [ ct_s[samp][c] for samp in sig_columns ] for c in cuts}

# %%
sig_cts_df = pd.DataFrame.from_dict(sig_counts).transpose()
sig_cts_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_df.index = cut

# %%
sig_cts_df.transpose()
# Out:
#                                         Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100        14.287467
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100      443.657710
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100       1.367489
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100       43.757275
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100     1302.773429
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100        3.352116
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100      108.825066
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100    24707.114125
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100        6.142378
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100      200.845707
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100        7.599038
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100      238.687780
#
#                                         0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                               1.246745
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                             36.186419
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                             0.147453
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                              4.335275
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                            123.246286
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                              0.343599
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                             10.209122
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                           2184.597749
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                              0.548201
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                             17.499996
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                              0.572359
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                             19.205951
#
#                                         No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100            1.082620
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          30.606686
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100          0.125749
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100           3.701598
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100         103.804582
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100           0.281474
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100           8.740354
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100        1899.409931
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100           0.471416
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          15.419565
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100           0.482576
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          16.193824
#
#                                         Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   1.017052
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                 28.817702
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.120663
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  3.588904
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                100.854231
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.269112
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  8.445451
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100               1816.958888
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.451724
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                 14.610412
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.460453
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                 15.286139
#
#                                         Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   1.017052
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                 28.817702
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.120663
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  3.588904
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                100.854231
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.269112
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  8.445451
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100               1816.958888
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.451724
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                 14.610412
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.460453
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                 15.286139
#
#                                         dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                       1.017052
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                     28.817702
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                     0.120663
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                      3.588904
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                    100.854231
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                      0.269112
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                      8.445451
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                   1816.958888
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                      0.451724
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                     14.610412
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                      0.460453
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                     15.286139
#
#                                         dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                     0.964478
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                   27.734501
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                   0.115385
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                    3.504454
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                   96.920244
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                    0.260240
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                    8.197402
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                 1763.830603
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                    0.429092
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                   14.120705
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                    0.444844
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                   14.977307
#
#                                         BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100           0.098396
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          1.915313
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100         0.030711
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100          0.800294
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100         21.898237
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100          0.065606
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100          1.864469
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100        322.907075
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100          0.096455
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          2.084500
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100          0.071560
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          1.930462

# %%
sig_match_df = pd.DataFrame.from_dict(sig_match).transpose()
sig_match_df.columns = sig_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_df.index = cut

# %%
sig_match_df.transpose()
# Out:
#                                         Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100             1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100            1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100             1.0
#
#                                         0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                               0.094778
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                              0.082836
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                             0.281222
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                              0.242447
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                              0.225522
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                              0.252725
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                              0.224672
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                              0.182426
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                              0.213699
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                              0.140124
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                              0.140934
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                              0.122626
#
#                                         No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100            0.103057
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100           0.082989
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100          0.292453
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100           0.251210
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100           0.227500
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100           0.271336
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100           0.229426
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100           0.179953
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100           0.217179
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100           0.138395
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100           0.137480
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100           0.122783
#
#                                         Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.121234
#
#                                         Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.121234
#
#                                         dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                       0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                      0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                     0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                      0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                      0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                      0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                      0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                      0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                      0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                      0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                      0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                      0.121234
#
#                                         dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                     0.102060
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                    0.084089
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                   0.311935
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                    0.252486
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                    0.241132
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                    0.273995
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                    0.236464
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                    0.185987
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                    0.227127
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                    0.149381
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                    0.146230
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                    0.123734
#
#                                         BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100           0.933654
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          0.913109
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100         0.955395
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100          0.957745
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100          0.910162
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100          0.942012
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100          0.960489
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100          0.899046
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100          0.918445
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          0.929322
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100          0.909016
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          0.859860

# %% [markdown]
# #### For signal events having gen ee reconstructed (having reco e with dR < 0.1)

# %%
sig_columns_reco = list(cf_s_reco.keys())
sig_efficiency_reco = {c: [ cf_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}
sig_match_reco = {c: [ fr_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_eff_reco_df = pd.DataFrame.from_dict(sig_efficiency_reco).transpose()
sig_eff_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_eff_reco_df.index = cut

# %%
sig_eff_reco_df
# Out:
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-100  \
# Preselections                                                    0.000429
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.000089
# No b-tagged jets                                                 0.000075
# Leading jet |eta| < 2.4                                          0.000071
# Leading jet pT > 80 GeV                                          0.000071
# dPhi(MET,leading jet) > 1.5                                      0.000071
# dPhi(MET,all jets) > 0.75                                        0.000068
# BDT v2 Loose WP                                                  0.000048
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-100  \
# Preselections                                                     0.000304
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000076
# No b-tagged jets                                                  0.000066
# Leading jet |eta| < 2.4                                           0.000062
# Leading jet pT > 80 GeV                                           0.000062
# dPhi(MET,leading jet) > 1.5                                       0.000062
# dPhi(MET,all jets) > 0.75                                         0.000060
# BDT v2 Loose WP                                                   0.000029
#
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-100  \
# Preselections                                                      0.004794
# 0 < n(jet) < 3 & n(good vertex) > 0                                0.000979
# No b-tagged jets                                                   0.000854
# Leading jet |eta| < 2.4                                            0.000828
# Leading jet pT > 80 GeV                                            0.000828
# dPhi(MET,leading jet) > 1.5                                        0.000828
# dPhi(MET,all jets) > 0.75                                          0.000819
# BDT v2 Loose WP                                                    0.000494
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-100  \
# Preselections                                                     0.003601
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000744
# No b-tagged jets                                                  0.000640
# Leading jet |eta| < 2.4                                           0.000619
# Leading jet pT > 80 GeV                                           0.000619
# dPhi(MET,leading jet) > 1.5                                       0.000619
# dPhi(MET,all jets) > 0.75                                         0.000608
# BDT v2 Loose WP                                                   0.000405
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-100  \
# Preselections                                                     0.002362
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000413
# No b-tagged jets                                                  0.000356
# Leading jet |eta| < 2.4                                           0.000354
# Leading jet pT > 80 GeV                                           0.000354
# dPhi(MET,leading jet) > 1.5                                       0.000354
# dPhi(MET,all jets) > 0.75                                         0.000351
# BDT v2 Loose WP                                                   0.000218
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-100  \
# Preselections                                                     0.003440
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000650
# No b-tagged jets                                                  0.000557
# Leading jet |eta| < 2.4                                           0.000532
# Leading jet pT > 80 GeV                                           0.000532
# dPhi(MET,leading jet) > 1.5                                       0.000532
# dPhi(MET,all jets) > 0.75                                         0.000523
# BDT v2 Loose WP                                                   0.000327
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-100  \
# Preselections                                                     0.002571
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000516
# No b-tagged jets                                                  0.000444
# Leading jet |eta| < 2.4                                           0.000433
# Leading jet pT > 80 GeV                                           0.000433
# dPhi(MET,leading jet) > 1.5                                       0.000433
# dPhi(MET,all jets) > 0.75                                         0.000427
# BDT v2 Loose WP                                                   0.000295
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  \
# Preselections                                                     0.001752
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000323
# No b-tagged jets                                                  0.000279
# Leading jet |eta| < 2.4                                           0.000269
# Leading jet pT > 80 GeV                                           0.000269
# dPhi(MET,leading jet) > 1.5                                       0.000269
# dPhi(MET,all jets) > 0.75                                         0.000267
# BDT v2 Loose WP                                                   0.000165
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-100  \
# Preselections                                                     0.001522
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000263
# No b-tagged jets                                                  0.000235
# Leading jet |eta| < 2.4                                           0.000225
# Leading jet pT > 80 GeV                                           0.000225
# dPhi(MET,leading jet) > 1.5                                       0.000225
# dPhi(MET,all jets) > 0.75                                         0.000224
# BDT v2 Loose WP                                                   0.000151
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-100  \
# Preselections                                                     0.001148
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000200
# No b-tagged jets                                                  0.000177
# Leading jet |eta| < 2.4                                           0.000172
# Leading jet pT > 80 GeV                                           0.000172
# dPhi(MET,leading jet) > 1.5                                       0.000172
# dPhi(MET,all jets) > 0.75                                         0.000170
# BDT v2 Loose WP                                                   0.000105
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-100  \
# Preselections                                                     0.000807
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000137
# No b-tagged jets                                                  0.000117
# Leading jet |eta| < 2.4                                           0.000116
# Leading jet pT > 80 GeV                                           0.000116
# dPhi(MET,leading jet) > 1.5                                       0.000116
# dPhi(MET,all jets) > 0.75                                         0.000115
# BDT v2 Loose WP                                                   0.000070
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-100
# Preselections                                                     0.000555
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.000111
# No b-tagged jets                                                  0.000096
# Leading jet |eta| < 2.4                                           0.000089
# Leading jet pT > 80 GeV                                           0.000089
# dPhi(MET,leading jet) > 1.5                                       0.000089
# dPhi(MET,all jets) > 0.75                                         0.000089
# BDT v2 Loose WP                                                   0.000057

# %%
sig_counts_reco = {c: [ ct_s_reco[samp][c] for samp in sig_columns_reco ] for c in cuts}

# %%
sig_cts_reco_df = pd.DataFrame.from_dict(sig_counts_reco).transpose()
sig_cts_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_cts_reco_df.index = cut

# %%
sig_cts_reco_df
# Out:
#                                      sig_2018_Mchi-5p5_dMchi-1p0_ctau-100  \
# Preselections                                                    0.827147
# 0 < n(jet) < 3 & n(good vertex) > 0                              0.170568
# No b-tagged jets                                                 0.144298
# Leading jet |eta| < 2.4                                          0.137740
# Leading jet pT > 80 GeV                                          0.137740
# dPhi(MET,leading jet) > 1.5                                      0.137740
# dPhi(MET,all jets) > 0.75                                        0.131161
# BDT v2 Loose WP                                                  0.091868
#
#                                      sig_2018_Mchi-5p25_dMchi-0p5_ctau-100  \
# Preselections                                                    18.447519
# 0 < n(jet) < 3 & n(good vertex) > 0                               4.621960
# No b-tagged jets                                                  3.997833
# Leading jet |eta| < 2.4                                           3.789926
# Leading jet pT > 80 GeV                                           3.789926
# dPhi(MET,leading jet) > 1.5                                       3.789926
# dPhi(MET,all jets) > 0.75                                         3.665276
# BDT v2 Loose WP                                                   1.790401
#
#                                      sig_2018_Mchi-55p0_dMchi-10p0_ctau-100  \
# Preselections                                                      0.292147
# 0 < n(jet) < 3 & n(good vertex) > 0                                0.059656
# No b-tagged jets                                                   0.052033
# Leading jet |eta| < 2.4                                            0.050466
# Leading jet pT > 80 GeV                                            0.050466
# dPhi(MET,leading jet) > 1.5                                        0.050466
# dPhi(MET,all jets) > 0.75                                          0.049881
# BDT v2 Loose WP                                                    0.030125
#
#                                      sig_2018_Mchi-52p5_dMchi-5p0_ctau-100  \
# Preselections                                                     6.996573
# 0 < n(jet) < 3 & n(good vertex) > 0                               1.445372
# No b-tagged jets                                                  1.242540
# Leading jet |eta| < 2.4                                           1.203100
# Leading jet pT > 80 GeV                                           1.203100
# dPhi(MET,leading jet) > 1.5                                       1.203100
# dPhi(MET,all jets) > 0.75                                         1.180574
# BDT v2 Loose WP                                                   0.786222
#
#                                      sig_2018_Mchi-33p0_dMchi-6p0_ctau-100  \
# Preselections                                                   226.543326
# 0 < n(jet) < 3 & n(good vertex) > 0                              39.597849
# No b-tagged jets                                                 34.186905
# Leading jet |eta| < 2.4                                          33.942837
# Leading jet pT > 80 GeV                                          33.942837
# dPhi(MET,leading jet) > 1.5                                      33.942837
# dPhi(MET,all jets) > 0.75                                        33.697929
# BDT v2 Loose WP                                                  20.913904
#
#                                      sig_2018_Mchi-44p0_dMchi-8p0_ctau-100  \
# Preselections                                                     0.656124
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.123910
# No b-tagged jets                                                  0.106166
# Leading jet |eta| < 2.4                                           0.101412
# Leading jet pT > 80 GeV                                           0.101412
# dPhi(MET,leading jet) > 1.5                                       0.101412
# dPhi(MET,all jets) > 0.75                                         0.099828
# BDT v2 Loose WP                                                   0.062436
#
#                                      sig_2018_Mchi-42p0_dMchi-4p0_ctau-100  \
# Preselections                                                    15.842030
# 0 < n(jet) < 3 & n(good vertex) > 0                               3.178924
# No b-tagged jets                                                  2.736123
# Leading jet |eta| < 2.4                                           2.669171
# Leading jet pT > 80 GeV                                           2.669171
# dPhi(MET,leading jet) > 1.5                                       2.669171
# dPhi(MET,all jets) > 0.75                                         2.629015
# BDT v2 Loose WP                                                   1.817663
#
#                                      sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  \
# Preselections                                                  3197.567008
# 0 < n(jet) < 3 & n(good vertex) > 0                             589.243103
# No b-tagged jets                                                508.479077
# Leading jet |eta| < 2.4                                         491.290695
# Leading jet pT > 80 GeV                                         491.290695
# dPhi(MET,leading jet) > 1.5                                     491.290695
# dPhi(MET,all jets) > 0.75                                       487.870376
# BDT v2 Loose WP                                                 300.621085
#
#                                      sig_2018_Mchi-22p0_dMchi-4p0_ctau-100  \
# Preselections                                                     0.904543
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.156517
# No b-tagged jets                                                  0.139785
# Leading jet |eta| < 2.4                                           0.133874
# Leading jet pT > 80 GeV                                           0.133874
# dPhi(MET,leading jet) > 1.5                                       0.133874
# dPhi(MET,all jets) > 0.75                                         0.132890
# BDT v2 Loose WP                                                   0.089574
#
#                                      sig_2018_Mchi-21p0_dMchi-2p0_ctau-100  \
# Preselections                                                    21.643236
# 0 < n(jet) < 3 & n(good vertex) > 0                               3.775849
# No b-tagged jets                                                  3.335222
# Leading jet |eta| < 2.4                                           3.237193
# Leading jet pT > 80 GeV                                           3.237193
# dPhi(MET,leading jet) > 1.5                                       3.237193
# dPhi(MET,all jets) > 0.75                                         3.212631
# BDT v2 Loose WP                                                   1.986437
#
#                                      sig_2018_Mchi-11p0_dMchi-2p0_ctau-100  \
# Preselections                                                     0.768680
# 0 < n(jet) < 3 & n(good vertex) > 0                               0.130093
# No b-tagged jets                                                  0.111867
# Leading jet |eta| < 2.4                                           0.110572
# Leading jet pT > 80 GeV                                           0.110572
# dPhi(MET,leading jet) > 1.5                                       0.110572
# dPhi(MET,all jets) > 0.75                                         0.109275
# BDT v2 Loose WP                                                   0.066348
#
#                                      sig_2018_Mchi-10p5_dMchi-1p0_ctau-100
# Preselections                                                    16.484894
# 0 < n(jet) < 3 & n(good vertex) > 0                               3.281567
# No b-tagged jets                                                  2.837542
# Leading jet |eta| < 2.4                                           2.644603
# Leading jet pT > 80 GeV                                           2.644603
# dPhi(MET,leading jet) > 1.5                                       2.644603
# dPhi(MET,all jets) > 0.75                                         2.644603
# BDT v2 Loose WP                                                   1.679269

# %%
sig_match_reco_df = pd.DataFrame.from_dict(sig_match_reco).transpose()
sig_match_reco_df.columns = sig_columns_reco

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

sig_match_reco_df.index = cut

# %%
sig_match_reco_df.transpose()
# Out:
#                                         Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100             1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100            1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100             1.0
#
#                                         0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                               0.692768
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                              0.648542
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                             0.695102
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                              0.727200
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                              0.701924
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                              0.700802
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                              0.721535
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                              0.676338
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                              0.748479
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                              0.649434
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                              0.620059
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                              0.717690
#
#                                         No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100            0.773201
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100           0.635350
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100          0.706778
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100           0.748368
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100           0.690777
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100           0.719380
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100           0.732885
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100           0.672208
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100           0.732424
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100           0.639836
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100           0.593068
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100           0.700719
#
#                                         Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.762403
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.637269
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.713199
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.742469
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.695744
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.712489
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.731210
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.667731
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.735335
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.651602
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.588302
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.700748
#
#                                         Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.762403
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.637269
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.713199
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.742469
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.695744
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.712489
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.731210
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.667731
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.735335
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.651602
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.588302
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.700748
#
#                                         dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                       0.762403
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                      0.637269
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                     0.713199
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                      0.742469
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                      0.695744
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                      0.712489
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                      0.731210
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                      0.667731
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                      0.735335
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                      0.651602
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                      0.588302
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                      0.700748
#
#                                         dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                     0.750484
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                    0.636290
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                   0.721573
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                    0.749489
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                    0.693533
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                    0.714271
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                    0.737306
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                    0.672413
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                    0.733376
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                    0.656584
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                    0.595285
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                    0.700748
#
#                                         BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100           1.000000
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          0.976814
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100         0.973993
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100          0.974888
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100          0.952999
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100          0.989837
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100          0.985222
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100          0.965695
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100          0.988999
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          0.975199
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100          0.980436
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          0.988481

# %%
sig_match_df.transpose()
# Out:
#                                         Preselections  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100              1.0
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100             1.0
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100            1.0
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100             1.0
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100             1.0
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100             1.0
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100             1.0
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100             1.0
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100             1.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100             1.0
#
#                                         0 < n(jet) < 3 & n(good vertex) > 0  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                               0.094778
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                              0.082836
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                             0.281222
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                              0.242447
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                              0.225522
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                              0.252725
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                              0.224672
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                              0.182426
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                              0.213699
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                              0.140124
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                              0.140934
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                              0.122626
#
#                                         No b-tagged jets  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100            0.103057
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100           0.082989
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100          0.292453
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100           0.251210
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100           0.227500
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100           0.271336
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100           0.229426
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100           0.179953
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100           0.217179
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100           0.138395
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100           0.137480
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100           0.122783
#
#                                         Leading jet |eta| < 2.4  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.121234
#
#                                         Leading jet pT > 80 GeV  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                   0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                  0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                 0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                  0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                  0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                  0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                  0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                  0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                  0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                  0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                  0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                  0.121234
#
#                                         dPhi(MET,leading jet) > 1.5  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                       0.103253
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                      0.083810
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                     0.298292
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                      0.248896
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                      0.234155
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                      0.268495
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                      0.231098
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                      0.180549
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                      0.217925
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                      0.144374
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                      0.141273
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                      0.121234
#
#                                         dPhi(MET,all jets) > 0.75  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100                     0.102060
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100                    0.084089
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100                   0.311935
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100                    0.252486
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100                    0.241132
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100                    0.273995
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100                    0.236464
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100                    0.185987
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100                    0.227127
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100                    0.149381
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100                    0.146230
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100                    0.123734
#
#                                         BDT v2 Loose WP
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100           0.933654
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100          0.913109
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-100         0.955395
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100          0.957745
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-100          0.910162
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-100          0.942012
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100          0.960489
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100          0.899046
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-100          0.918445
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100          0.929322
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-100          0.909016
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100          0.859860

# %% [markdown]
# ### Cutflow Dataframe -- background

# %%
cuts = list(bkg_histos['W+jets']['cutflow']['bkg_2018_WJetsLNu_HT2500toInf'])

# %%
tot_bkg_cts = {} 
tot_bkg_effs = {} 
total_bkg_counts = {}

# %%
for b in bkg_histos.keys():
    
    total_bkg_counts[b] = 0
    for k in bkg_histos[b]['cutflow'].keys():
        total_bkg_counts[b] += bkg_histos[b]['cutflow_cts'][k]['all'] / bkg_histos[b]['cutflow'][k]['all']

# %%
for b in bkg_histos.keys():
    cfd = bkg_histos[b]['cutflow_cts']
    effd = bkg_histos[b]['cutflow']

    cts_dict = {k:0 for k in cuts}
    
    for k in cfd.keys():
        for c in cuts:
            cts_dict[c] += cfd[k][c]

    tot_bkg_cts[b] = cts_dict # subprocess summed
    tot_bkg_effs[b] = {c:cts_dict[c]/total_bkg_counts[b] for c in cuts}

# %%
bkg_summed_cts = {c:sum([tot_bkg_cts[b][c] for b in tot_bkg_cts.keys()]) for c in cuts}

# %%
bkg_summed_eff = {c: bkg_summed_cts[c] / sum(total_bkg_counts.values()) for c in cuts}

# %%
bkg_columns = list(bkg_histos.keys())
bkg_columns.append('total')

tot_bkg_effs['total'] = bkg_summed_eff
tot_bkg_cts['total'] = bkg_summed_cts

# %%
bkg_efficiency = {c: [ tot_bkg_effs[samp][c] for samp in bkg_columns ] for c in cuts}
bkg_counts = {c: [ tot_bkg_cts[samp][c] for samp in bkg_columns ] for c in cuts}

# %%
bkg_eff_df = pd.DataFrame.from_dict(bkg_efficiency).transpose()
bkg_eff_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_eff_df.index = cut

# %%
bkg_eff_df
# Out:
#                                               QCD       Top            DY  \
# Preselections                        1.765167e-06  0.000129  1.126054e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  8.736155e-08  0.000013  5.215843e-07
# No b-tagged jets                     6.157029e-08  0.000008  4.841556e-07
# Leading jet |eta| < 2.4              6.120635e-08  0.000007  4.841556e-07
# Leading jet pT > 80 GeV              6.120635e-08  0.000007  4.841556e-07
# dPhi(MET,leading jet) > 1.5          6.117856e-08  0.000007  4.841556e-07
# dPhi(MET,all jets) > 0.75            2.933839e-08  0.000007  3.539610e-07
# BDT v2 Loose WP                      0.000000e+00  0.000000  0.000000e+00
#
#                                           Diboson  Triboson        W+jets  \
# Preselections                        6.373026e-04  0.001933  2.309964e-03
# 0 < n(jet) < 3 & n(good vertex) > 0  4.435487e-05  0.000158  1.729308e-04
# No b-tagged jets                     3.273392e-05  0.000104  1.387287e-04
# Leading jet |eta| < 2.4              3.073427e-05  0.000092  1.315265e-04
# Leading jet pT > 80 GeV              3.043376e-05  0.000091  1.312650e-04
# dPhi(MET,leading jet) > 1.5          3.029834e-05  0.000091  1.312209e-04
# dPhi(MET,all jets) > 0.75            2.727575e-05  0.000076  1.139098e-04
# BDT v2 Loose WP                      4.192895e-08  0.000000  4.809060e-08
#
#                                            Z+jets         total
# Preselections                        6.645339e-03  1.878092e-05
# 0 < n(jet) < 3 & n(good vertex) > 0  3.983155e-04  1.258685e-06
# No b-tagged jets                     3.251023e-04  1.005441e-06
# Leading jet |eta| < 2.4              3.095805e-04  9.577009e-07
# Leading jet pT > 80 GeV              3.090021e-04  9.559090e-07
# dPhi(MET,leading jet) > 1.5          3.089645e-04  9.556166e-07
# dPhi(MET,all jets) > 0.75            2.923517e-04  8.272960e-07
# BDT v2 Loose WP                      8.572746e-08  2.979847e-10

# %%
bkg_cts_df = pd.DataFrame.from_dict(bkg_counts).transpose()
bkg_cts_df.columns = bkg_columns

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))

bkg_cts_df.index = cut

# %%
bkg_cts_df
# Out:
#                                               QCD          Top            DY  \
# Preselections                        38039.826987  5667.491120  14495.724273
# 0 < n(jet) < 3 & n(good vertex) > 0   1882.665324   559.218223    671.436619
# No b-tagged jets                      1326.856559   349.755962    623.254666
# Leading jet |eta| < 2.4               1319.013605   314.033934    623.254666
# Leading jet pT > 80 GeV               1319.013605   312.992040    623.254666
# dPhi(MET,leading jet) > 1.5           1318.414646   312.954947    623.254666
# dPhi(MET,all jets) > 0.75              632.250399   294.001347    455.654738
# BDT v2 Loose WP                          0.000000     0.000000      0.000000
#
#                                          Diboson   Triboson         W+jets  \
# Preselections                        4424.202428  52.996922  227212.601036
# 0 < n(jet) < 3 & n(good vertex) > 0   307.914836   4.324318   17009.814573
# No b-tagged jets                      227.241343   2.854129   13645.628528
# Leading jet |eta| < 2.4               213.359570   2.510261   12937.207075
# Leading jet pT > 80 GeV               211.273431   2.506022   12911.488177
# dPhi(MET,leading jet) > 1.5           210.333328   2.501784   12907.145737
# dPhi(MET,all jets) > 0.75             189.350279   2.086892   11204.390252
# BDT v2 Loose WP                         0.291074   0.000000       4.730287
#
#                                             Z+jets          total
# Preselections                        142220.153499  432112.996264
# 0 < n(jet) < 3 & n(good vertex) > 0    8524.545695   28959.919588
# No b-tagged jets                       6957.674053   23133.265240
# Leading jet |eta| < 2.4                6625.483327   22034.862439
# Leading jet pT > 80 GeV                6613.106470   21993.634411
# dPhi(MET,leading jet) > 1.5            6612.301368   21986.906477
# dPhi(MET,all jets) > 0.75              6256.761468   19034.495374
# BDT v2 Loose WP                           1.834695       6.856057

# %%
# bkg efficiencies summed over sub-samples

plt.figure(figsize=(8,6))
plt.title("Background Efficiencies: BDTv2, ctau-100 SR")

for b in bkg_histos.keys():
    cfbs = tot_bkg_effs[b]
    effs = [cfbs[c] for c in cuts]
    plt.plot(np.arange(len(effs)),effs,label=b)
    #plt.ylim([1e-12,1])

plt.yscale('log')
plt.ylabel("Efficiency")
plt.legend(loc='upper right',ncol=2)
plt.grid()

labels = [cutNames[c] for c in cuts]
# Replace "No cuts" with "Preselections" and "Baseline Selection" with "0 < n(jet) < 3 & n(good vertex) > 0"
cut = list(map(lambda x: x.replace('Baseline Selection', '0 < n(jet) < 3 & n(good vertex) > 0'), labels))
cut = list(map(lambda x: x.replace('No cuts', 'Preselections'), cut))
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cut, rotation = 45, ha = 'right')

plt.ylim([1e-8, 5e-2])
plt.show()

#os.makedirs("plots/cutflows/")
#plt.savefig(f"plots/cutflows/bkg_combined_efficiencies.png")

# %% [markdown]
# ### Bkg Yield

# %%
sqrtB = np.sqrt(bkg_cts_df.iloc[-1].loc['total'])

print('Total background after last SR cut: {:.2f}'.format(bkg_cts_df['total'].iloc[-1]))
print('sqrt(B) = {:.2f}'.format(sqrtB))
# Out:
# Total background after last SR cut: 6.86
# sqrt(B) = 2.62

# %%
sqrtBs['100'] = sqrtB

# %% [markdown]
# ### Signal Yield and Vtx Gen Matching Fraction

# %%
s_df = sig_cts_df.iloc[-1]
s_match_df = sig_match_df.iloc[-1]

# when only looking at the events where gen ee are reconstructed (dR(gen,reco)<0.1)
s_reco_df = sig_cts_reco_df.iloc[-1]
s_match_reco_df = sig_match_reco_df.iloc[-1]

# %%
columns_ctau = {'1': {'0p1': [], '0p2': []}, '10': {'0p1': [], '0p2': []}, '100': {'0p1': [], '0p2': []}}

for name in sig_columns:
    
    mchi = ptools.signalPoint(name)['mchi']
    dmchi = ptools.signalPoint(name)['dmchi']
    delta = ptools.signalPoint(name)['delta']

    if 'ctau-10' not in name:
        if delta == 0.1:
            columns_ctau['1']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['1']['0p2'].append(name)
    elif 'ctau-100' not in name:
        if delta == 0.1:
            columns_ctau['10']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['10']['0p2'].append(name)
    else:
        if delta == 0.1:
            columns_ctau['100']['0p1'].append(name)
        elif delta == 0.2:
            columns_ctau['100']['0p2'].append(name)

ct = '100'
delta = '0p1'
print(columns_ctau[ct][delta])
# Out:
# ['sig_2018_Mchi-5p25_dMchi-0p5_ctau-100', 'sig_2018_Mchi-52p5_dMchi-5p0_ctau-100', 'sig_2018_Mchi-42p0_dMchi-4p0_ctau-100', 'sig_2018_Mchi-31p5_dMchi-3p0_ctau-100', 'sig_2018_Mchi-21p0_dMchi-2p0_ctau-100', 'sig_2018_Mchi-10p5_dMchi-1p0_ctau-100']

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['100']:
        signal_df[delta][ctau] = s_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_df[delta][ctau].rename(index = {signal_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_df[delta][ctau] = s_match_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_df[delta][ctau].rename(index = {signal_match_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield for delta = 0.1, ctau = 100')
signal_df['0p1']['100'].transpose()
# Out:
# Signal yield for delta = 0.1, ctau = 100
#                                             100mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100    1.930462
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100    2.084500
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  322.907075
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100    1.864469
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100    0.800294
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100    1.915313

# %%
print('Vertex purity for delta = 0.1, ctau = 100')
signal_match_df['0p1']['100'].transpose()
# Out:
# Vertex purity for delta = 0.1, ctau = 100
#                                           100mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100  0.859860
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100  0.929322
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  0.899046
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100  0.960489
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100  0.957745
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100  0.913109

# %%
deltas = ['0p1','0p2']

for delta in deltas:
    for ctau in ['100']:
        signal_reco_df[delta][ctau] = s_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_reco_df[delta][ctau].rename(index = {signal_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

        signal_match_reco_df[delta][ctau] = s_match_reco_df.loc[columns_ctau[ctau][delta]].to_frame()[::-1].transpose()
        signal_match_reco_df[delta][ctau].rename(index = {signal_match_reco_df[delta][ctau].index[0]: f"{ctau}mm"}, inplace = True)

# %%
print('Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 100')
signal_reco_df['0p1']['100'].transpose()
# Out:
# Signal yield when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 100
#                                             100mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100    1.679269
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100    1.986437
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  300.621085
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100    1.817663
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100    0.786222
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100    1.790401

# %%
print('Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 100')
signal_match_reco_df['0p1']['100'].transpose()
# Out:
# Vertex purity when only looking at events where gen ee are reconstructed; for delta = 0.1, ctau = 100
#                                           100mm
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-100  0.988481
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-100  0.975199
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-100  0.965695
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-100  0.985222
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-100  0.974888
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100  0.976814

# %%
deltas = [0.1,0.2]

ct = 100

fig,axes = plt.subplots(1,len(deltas),figsize=(6*len(deltas),6))

for i, delta in enumerate(deltas):
    plt.sca(axes[i])
    plot_efficiency_signal_varying_M1( df_sig = si, dict_eff = cf_s, cuts = cuts, cutNames = cutNames, 
                                       delta = delta, ct = ct)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Signal Yield for all ctaus

# %%
ctaus = ['1','10','100']

# %%
delta = '0p1'

for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_df[delta][ctau].columns]
    signal_df[delta][ctau].columns = m1s

    signal_df[delta][ctau] = signal_df[delta][ctau].sort_index(axis=1)

frames = [signal_df[delta]['1'], signal_df[delta]['10'], signal_df[delta]['100']]
delta_0p1_df = pd.concat(frames)

# %%
print('delta = 0p1, signal yield after last cut in SR')
delta_0p1_df
# Out:
# delta = 0p1, signal yield after last cut in SR
#                 5            10           20           30          40  \
# 1mm    2787.316093  1839.613547  1589.161260  1794.503944  990.728036
# 10mm     84.007888    88.454491    96.233563  1171.794549   67.818152
# 100mm     1.915313     1.930462     2.084500   322.907075    1.864469
#
#                50
# 1mm    412.044822
# 10mm    27.287742
# 100mm    0.800294

# %%
for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_reco_df[delta][ctau].columns]
    signal_reco_df[delta][ctau].columns = m1s

    signal_reco_df[delta][ctau] = signal_reco_df[delta][ctau].sort_index(axis=1)

frames = [signal_reco_df[delta]['1'], signal_reco_df[delta]['10'], signal_reco_df[delta]['100']]
delta_0p1_reco_df = pd.concat(frames)

# %%
print('delta = 0p1, signal yield for events where gen ee are reconstructed, after last cut in SR')
delta_0p1_reco_df
# Out:
# delta = 0p1, signal yield for events where gen ee are reconstructed, after last cut in SR
#                 5            10           20           30          40  \
# 1mm    2787.316093  1807.605719  1571.503625  1777.665582  982.756605
# 10mm     80.348722    86.209302    93.430809  1166.521911   66.908321
# 100mm     1.790401     1.679269     1.986437   300.621085    1.817663
#
#                50
# 1mm    408.001326
# 10mm    27.009639
# 100mm    0.786222

# %%
delta = '0p2'

for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_df[delta][ctau].columns]
    signal_df[delta][ctau].columns = m1s

    signal_df[delta][ctau] = signal_df[delta][ctau].sort_index(axis=1)

frames = [signal_df[delta]['1'], signal_df[delta]['10'], signal_df[delta]['100']]
delta_0p2_df = pd.concat(frames)

# %%
print('delta = 0p2, signal yield after last cut in SR')
delta_0p2_df
# Out:
# delta = 0p2, signal yield after last cut in SR
#                5          10         20           30         40         50
# 1mm    128.365134  79.588482  72.072975  4178.235083  38.762997  17.007244
# 10mm     4.543953   3.330175   4.041440   797.807828   2.603764   1.234690
# 100mm    0.098396   0.071560   0.096455    21.898237   0.065606   0.030711

# %%
delta = '0p2'

for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_reco_df[delta][ctau].columns]
    signal_reco_df[delta][ctau].columns = m1s

    signal_reco_df[delta][ctau] = signal_reco_df[delta][ctau].sort_index(axis=1)

frames = [signal_reco_df[delta]['1'], signal_reco_df[delta]['10'], signal_reco_df[delta]['100']]
delta_0p2_reco_df = pd.concat(frames)

# %%
print('delta = 0p2, signal yield for events where gen ee are reconstructed, after last cut in SR')
delta_0p2_reco_df
# Out:
# delta = 0p2, signal yield for events where gen ee are reconstructed, after last cut in SR
#                5          10         20           30         40         50
# 1mm    127.074408  79.375994  71.933028  4124.890517  38.387746  16.736664
# 10mm     4.410148   3.296574   3.961948   795.806789   2.582899   1.224196
# 100mm    0.091868   0.066348   0.089574    20.913904   0.062436   0.030125

# %% [markdown]
# ## Display S/B

# %%
pd.set_option("display.precision", 3)

# %%
delta = '0p1'

frames = [delta_0p1_df.iloc[0].to_frame().transpose()/sqrtBs['1'], \
          delta_0p1_df.iloc[1].to_frame().transpose()/sqrtBs['10'], \
          delta_0p1_df.iloc[2].to_frame().transpose()/sqrtBs['100']]

delta_0p1_SoverB_df = pd.concat(frames)

delta_0p1_SoverB_df = delta_0p1_SoverB_df.sort_index(axis=1)

# %%
print('delta = 0.1, S/sqrt(B)')

delta_0p1_SoverB_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p1_SoverB_df
# Out:
# delta = 0.1, S/sqrt(B)
#          5 GeV   10 GeV   20 GeV   30 GeV   40 GeV  50 GeV
# 1mm    493.296  325.573  281.248  317.589  175.338  72.923
# 10mm    28.923   30.454   33.132  403.432   23.349   9.395
# 100mm    0.731    0.737    0.796  123.322    0.712   0.306

# %%
delta = '0p1'

frames = [delta_0p1_reco_df.iloc[0].to_frame().transpose()/sqrtBs['1'], \
          delta_0p1_reco_df.iloc[1].to_frame().transpose()/sqrtBs['10'], \
          delta_0p1_reco_df.iloc[2].to_frame().transpose()/sqrtBs['100']]

delta_0p1_SoverB_reco_df = pd.concat(frames)

delta_0p1_SoverB_reco_df = delta_0p1_SoverB_reco_df.sort_index(axis=1)

print('delta = 0.1, S/sqrt(B), only counting the signal events where gen ee are reconstructed')

delta_0p1_SoverB_reco_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p1_SoverB_reco_df
# Out:
# delta = 0.1, S/sqrt(B), only counting the signal events where gen ee are reconstructed
#          5 GeV   10 GeV   20 GeV   30 GeV   40 GeV  50 GeV
# 1mm    493.296  319.908  278.123  314.609  173.927  72.208
# 10mm    27.663   29.681   32.167  401.617   23.036   9.299
# 100mm    0.684    0.641    0.759  114.811    0.694   0.300

# %%
delta = '0p2'

frames = [delta_0p2_df.iloc[0].to_frame().transpose()/sqrtBs['1'], \
          delta_0p2_df.iloc[1].to_frame().transpose()/sqrtBs['10'], \
          delta_0p2_df.iloc[2].to_frame().transpose()/sqrtBs['100']]

delta_0p2_SoverB_df = pd.concat(frames)

delta_0p2_SoverB_df = delta_0p2_SoverB_df.sort_index(axis=1)

# %%
print('delta = 0.2, S/sqrt(B)')

delta_0p2_SoverB_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p2_SoverB_df
# Out:
# delta = 0.2, S/sqrt(B)
#         5 GeV  10 GeV  20 GeV   30 GeV  40 GeV  50 GeV
# 1mm    22.718  14.085  12.755  739.459   6.860   3.010
# 10mm    1.564   1.147   1.391  274.674   0.896   0.425
# 100mm   0.038   0.027   0.037    8.363   0.025   0.012

# %%
delta = '0p2'

frames = [delta_0p2_reco_df.iloc[0].to_frame().transpose()/sqrtBs['1'], \
          delta_0p2_reco_df.iloc[1].to_frame().transpose()/sqrtBs['10'], \
          delta_0p2_reco_df.iloc[2].to_frame().transpose()/sqrtBs['100']]

delta_0p2_SoverB_reco_df = pd.concat(frames)

delta_0p2_SoverB_reco_df = delta_0p2_SoverB_reco_df.sort_index(axis=1)

print('delta = 0.2, S/sqrt(B), only counting the signal events where gen ee are reconstructed')

delta_0p2_SoverB_reco_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p2_SoverB_reco_df
# Out:
# delta = 0.2, S/sqrt(B), only counting the signal events where gen ee are reconstructed
#         5 GeV  10 GeV  20 GeV   30 GeV  40 GeV  50 GeV
# 1mm    22.489  14.048  12.731  730.018   6.794   2.962
# 10mm    1.518   1.135   1.364  273.985   0.889   0.421
# 100mm   0.035   0.025   0.034    7.987   0.024   0.012

# %%
ctaus = [1,10,100]

# %%
f, axes = plt.subplots(1, 3, figsize=(15, 4))

for idx, ctau in enumerate(ctaus):
    ctau = int(ctau)
    
    y_arr_1 = delta_0p1_SoverB_df.iloc[idx].to_list()
    y_arr_2 = delta_0p2_SoverB_df.iloc[idx].to_list()

    x_arr = sorted(m1s)
    
    axes[idx].plot(x_arr, y_arr_1, '-o', label=f'Delta = 0.1')
    axes[idx].plot(x_arr, y_arr_2, '-o', label=f'Delta = 0.2')

    axes[idx].legend()
    
    axes[idx].set_xlabel('M1 [GeV]')
    axes[idx].set_ylabel('S/sqrt(B)')
    
    axes[idx].grid()
    
    axes[idx].set_title(f'ctau = {ctau}mm')

# %% [markdown]
# ## Vtx purity (fraction of events whose selected vertex is gen matched) for all ctaus

# %%
ctaus = ['1','10','100']

# %%
delta = '0p1'

for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_match_df[delta][ctau].columns]
    signal_match_df[delta][ctau].columns = m1s

    signal_match_df[delta][ctau] = signal_match_df[delta][ctau].sort_index(axis=1)

frames = [signal_match_df[delta]['1'], signal_match_df[delta]['10'], signal_match_df[delta]['100']]
delta_0p1_match_df = pd.concat(frames)

# %%
print('BDTv2 SR')
print('delta = 0.1, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(all)]')

delta_0p1_match_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p1_match_df
# Out:
# BDTv2 SR
# delta = 0.1, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(all)]
#        5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 1mm    0.975   0.951   0.967   0.968   0.971   0.975
# 10mm   0.884   0.959   0.942   0.975   0.973   0.978
# 100mm  0.913   0.860   0.929   0.899   0.960   0.958

# %%
for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_match_reco_df[delta][ctau].columns]
    signal_match_reco_df[delta][ctau].columns = m1s

    signal_match_reco_df[delta][ctau] = signal_match_reco_df[delta][ctau].sort_index(axis=1)

frames = [signal_match_reco_df[delta]['1'], signal_match_reco_df[delta]['10'], signal_match_reco_df[delta]['100']]
delta_0p1_match_reco_df = pd.concat(frames)

# %%
print('BDTv2 SR')
print('delta = 0.1, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(having gen ee reconstructed)]')
delta_0p1_match_reco_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p1_match_reco_df
# Out:
# BDTv2 SR
# delta = 0.1, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(having gen ee reconstructed)]
#        5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 1mm    0.975   0.968   0.978   0.977   0.979   0.985
# 10mm   0.924   0.984   0.970   0.980   0.986   0.988
# 100mm  0.977   0.988   0.975   0.966   0.985   0.975

# %%
delta = '0p2'

for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_match_df[delta][ctau].columns]
    signal_match_df[delta][ctau].columns = m1s

    signal_match_df[delta][ctau] = signal_match_df[delta][ctau].sort_index(axis=1)

frames = [signal_match_df[delta]['1'], signal_match_df[delta]['10'], signal_match_df[delta]['100']]
delta_0p2_match_df = pd.concat(frames)

# %%
print('BDTv2 SR')
print('delta = 0.2, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(all)]')

delta_0p2_match_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p2_match_df
# Out:
# BDTv2 SR
# delta = 0.2, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(all)]
#        5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 1mm    0.980   0.971   0.973   0.970   0.981   0.984
# 10mm   0.941   0.970   0.966   0.987   0.976   0.987
# 100mm  0.934   0.909   0.918   0.910   0.942   0.955

# %%
for idx, ctau in enumerate(ctaus):
    m1s = [int(ptools.signalPoint(i)['m1']) for i in signal_match_reco_df[delta][ctau].columns]
    signal_match_reco_df[delta][ctau].columns = m1s

    signal_match_reco_df[delta][ctau] = signal_match_reco_df[delta][ctau].sort_index(axis=1)

frames = [signal_match_reco_df[delta]['1'], signal_match_reco_df[delta]['10'], signal_match_reco_df[delta]['100']]
delta_0p2_match_reco_df = pd.concat(frames)

# %%
print('BDTv2 SR')
print('delta = 0.2, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(having gen ee reconstructed)]')
delta_0p2_match_reco_df.columns = [f'{m1} GeV' for m1 in sorted(m1s)]

delta_0p2_match_reco_df
# Out:
# BDTv2 SR
# delta = 0.2, vertex purity = [nEvents(best vertex matches the true vertex)] / [nEvents(having gen ee reconstructed)]
#        5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 1mm     0.99   0.973   0.975   0.983   0.990   1.000
# 10mm    0.97   0.980   0.986   0.990   0.984   0.996
# 100mm   1.00   0.980   0.989   0.953   0.990   0.974

# %%
f, axes = plt.subplots(1, 3, figsize=(15, 4))

for idx, ctau in enumerate(ctaus):
    ctau = int(ctau)
    
    y_arr_1 = delta_0p1_match_df.iloc[idx].to_list()
    y_arr_2 = delta_0p2_match_df.iloc[idx].to_list()

    x_arr = sorted(m1s)
    
    axes[idx].plot(x_arr, y_arr_1, '-o', label=f'Delta = 0.1')
    axes[idx].plot(x_arr, y_arr_2, '-o', label=f'Delta = 0.2')

    axes[idx].legend()
    
    axes[idx].set_xlabel('M1 [GeV]')
    axes[idx].set_ylabel('S/sqrt(B)')
    
    axes[idx].grid()
    
    axes[idx].set_title(f'ctau = {ctau}mm')

# %%
f, axes = plt.subplots(1, 3, figsize=(15, 4))

for idx, ctau in enumerate(ctaus):
    ctau = int(ctau)
    
    y_arr_1 = delta_0p1_match_reco_df.iloc[idx].to_list()
    y_arr_2 = delta_0p2_match_reco_df.iloc[idx].to_list()

    x_arr = sorted(m1s)
    
    axes[idx].plot(x_arr, y_arr_1, '-o', label=f'Delta = 0.1')
    axes[idx].plot(x_arr, y_arr_2, '-o', label=f'Delta = 0.2')

    axes[idx].legend()
    
    axes[idx].set_xlabel('M1 [GeV]')
    axes[idx].set_ylabel('S/sqrt(B)')
    
    axes[idx].grid()
    
    axes[idx].set_title(f'{ctau}mm (events where gen ee are reconstructed)')

# %%
# export
delta_0p1_SoverB_df.to_csv('../BDTv2-based-SR_SoverB_delta_0p1.csv')
delta_0p2_SoverB_df.to_csv('../BDTv2-based-SR_SoverB_delta_0p2.csv') 

# export
delta_0p1_SoverB_reco_df.to_csv('../BDTv2-based-SR_SoverB_delta_0p1_hasGenEEreconstructed.csv')
delta_0p2_SoverB_reco_df.to_csv('../BDTv2-based-SR_SoverB_delta_0p2_hasGenEEreconstructed.csv')

# %%
# export
delta_0p1_match_df.to_csv('../BDTv2-based-SR_Purity_delta_0p1.csv') 
delta_0p2_match_df.to_csv('../BDTv2-based-SR_Purity_delta_0p2.csv') 

delta_0p1_match_reco_df.to_csv('../BDTv2-based-SR_Purity_delta_0p1_hasGenEEreconstructed.csv') 
delta_0p2_match_reco_df.to_csv('../BDTv2-based-SR_Purity_delta_0p2_hasGenEEreconstructed.csv')

# %%
bYields = {}

for bkg in sqrtBs.keys():
    bYields[bkg] = sqrtBs[bkg]**2

pd.DataFrame.from_dict(bYields, orient='index')
# Out:
#           0
# 1    31.927
# 10    8.437
# 100   6.856

# %% [markdown]
# ## Compare S/B with Other SR

# %%
s_over_b = {'Cut': {}, 'BDTv2': {}}

for typ in s_over_b.keys():
    for delta in ['0p1','0p2']:
        with open(f'../{typ}-based-SR_SoverB_delta_{delta}.csv') as x:
            ncols = len(x.readline().split(','))
        
        s_over_b[typ][delta] = pd.read_csv(f'../{typ}-based-SR_SoverB_delta_{delta}.csv', usecols=range(1,ncols))

# %%
s_over_b['Cut']['0p1']
# Out:
#      5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 0  133.384  89.330  81.494  87.321  48.133  19.279
# 1    8.430   7.869   7.547  87.802   5.045   1.873
# 2    0.164   0.145   0.155  23.922   0.140   0.060

# %%
s_over_b['BDTv2']['0p1']
# Out:
#      5 GeV   10 GeV   20 GeV   30 GeV   40 GeV  50 GeV
# 0  493.296  325.573  281.248  317.589  175.338  72.923
# 1   28.923   30.454   33.132  403.432   23.349   9.395
# 2    0.731    0.737    0.796  123.322    0.712   0.306

# %%
s_over_b['BDTv2']['0p1']/s_over_b['Cut']['0p1']
# Out:
#    5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 0  3.698   3.645   3.451   3.637   3.643   3.783
# 1  3.431   3.870   4.390   4.595   4.628   5.017
# 2  4.467   5.079   5.134   5.155   5.090   5.076

# %%
s_over_b['BDTv2']['0p2']/s_over_b['Cut']['0p2']
# Out:
#    5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 0  3.432   3.511   3.547   3.982   3.914   3.725
# 1  4.149   4.863   4.733   4.829   5.477   5.774
# 2  4.791   4.913   5.276   4.677   5.346   6.264

# %%
ratio = {'BDTv2': {}}

for typ in ratio.keys():
    for delta in ['0p1','0p2']:
        ratio[typ][delta] = s_over_b[typ][delta]/s_over_b['Cut'][delta]

# %%
# ctau-1, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p1'].iloc[0].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p1'].iloc[0].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDT')
plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 1mm')

# %%
# ctau-1, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p1'].iloc[1].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p1'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDTv2')
plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 10mm')

# %%
# ctau-100, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p1'].iloc[2].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p1'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDTv2')
plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 100mm')

# %%
# ctau-1, delta 0.2

#x_arr1 = [5,10,20,30,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p2'].iloc[0].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p2'].iloc[0].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDTv2')
plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 1mm')

# %%
# ctau-1, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p2'].iloc[1].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p2'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDTv2')
plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 10mm')

# %%
# ctau-100, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
#y_arr1 = ratio['BDTv1']['0p2'].iloc[2].dropna().to_list()
y_arr2 = ratio['BDTv2']['0p2'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1')
#plt.plot(x_arr2, y_arr2, 'o-', label='BDTv2')

plt.plot(x_arr2, y_arr2, 'o-')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
#plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 100mm')

# %%
# ctau-1

x_arr1 = [5,10,20,30,40,50]
y_arr1 = ratio['BDTv2']['0p1'].iloc[0].dropna().to_list()

plt.plot(x_arr1, y_arr1, 'o-', label='delta = 0.1')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

x_arr2 = [5,10,20,30,40,50]
y_arr2 = ratio['BDTv2']['0p2'].iloc[0].dropna().to_list()

plt.plot(x_arr2, y_arr2, 'o-', label='delta = 0.2')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
plt.legend()

plt.grid()

plt.title('ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'ctau = 1mm')

# %%
# ctau-10

x_arr1 = [5,10,20,30,40,50]
y_arr1 = ratio['BDTv2']['0p1'].iloc[1].dropna().to_list()

plt.plot(x_arr1, y_arr1, 'o-', label='delta = 0.1')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

x_arr2 = [5,10,20,30,40,50]
y_arr2 = ratio['BDTv2']['0p2'].iloc[1].dropna().to_list()

plt.plot(x_arr2, y_arr2, 'o-', label='delta = 0.2')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
plt.legend()

plt.grid()

plt.title('ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'ctau = 10mm')

# %%
# ctau-100

x_arr1 = [5,10,20,30,40,50]
y_arr1 = ratio['BDTv2']['0p1'].iloc[2].dropna().to_list()

plt.plot(x_arr1, y_arr1, 'o-', label='delta = 0.1')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

x_arr2 = [5,10,20,30,40,50]
y_arr2 = ratio['BDTv2']['0p2'].iloc[2].dropna().to_list()

plt.plot(x_arr2, y_arr2, 'o-', label='delta = 0.2')

plt.xlabel('m1 [GeV]')
plt.ylabel('S/B ratio: BDT (S/B) / Cut-based (S/B)')

plt.ylim([1,6])
plt.legend()

plt.grid()

plt.title('ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'ctau = 100mm')

# %% [markdown]
# ## Compare Vertex Purity with other SR

# %%
purity = {'Cut': {}, 'BDTv2': {}}

for typ in s_over_b.keys():
    for delta in ['0p1','0p2']:
        with open(f'../{typ}-based-SR_Purity_delta_{delta}.csv') as x:
            ncols = len(x.readline().split(','))
        
        purity[typ][delta] = pd.read_csv(f'../{typ}-based-SR_Purity_delta_{delta}.csv', usecols=range(1,ncols))

# %%
purity['Cut']['0p1']
# Out:
#    5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 0  0.966   0.934   0.967   0.961   0.949   0.956
# 1  0.901   0.941   0.947   0.969   0.977   0.970
# 2  0.870   0.864   0.932   0.877   0.955   0.916

# %%
# ctau-1, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[0].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[0].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[0].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 1mm')

# %%
# ctau-10, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[1].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[1].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 10mm')

# %%
# ctau-100, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[2].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[2].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 100mm')

# %%
# ctau-1, delta 0.2

#x_arr1 = [5,10,20,30,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = (purity['BDTv1']['0p2'].iloc[0])[purity['BDTv1']['0p2'].iloc[0] != 0].to_list()
y_arr2 = (purity['BDTv2']['0p2'].iloc[0])[purity['BDTv2']['0p2'].iloc[0] != 0].to_list()
y_arr3 = (purity['Cut']['0p2'].iloc[0])[purity['Cut']['0p2'].iloc[0] != 0].to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 1mm')

# %%
# ctau-10, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p2'].iloc[1].dropna().to_list()
y_arr2 = purity['BDTv2']['0p2'].iloc[1].dropna().to_list()
y_arr3 = purity['Cut']['0p2'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 10mm')

# %%
# ctau-100, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p2'].iloc[2].dropna().to_list()
y_arr2 = purity['BDTv2']['0p2'].iloc[2].dropna().to_list()
y_arr3 = purity['Cut']['0p2'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 100mm')

# %% [markdown]
# ## Compare vertex purity with other SR: only counting the ones where the gen ee are reconstructed

# %%
purity = {'Cut': {}, 'BDTv2': {}}

for typ in s_over_b.keys():
    for delta in ['0p1','0p2']:
        with open(f'../{typ}-based-SR_Purity_delta_{delta}_hasGenEEreconstructed.csv') as x:
            ncols = len(x.readline().split(','))
        
        purity[typ][delta] = pd.read_csv(f'../{typ}-based-SR_Purity_delta_{delta}_hasGenEEreconstructed.csv', usecols=range(1,ncols))

# %%
purity['Cut']['0p1']
# Out:
#    5 GeV  10 GeV  20 GeV  30 GeV  40 GeV  50 GeV
# 0  0.966   0.958   0.967    0.97   0.965   0.972
# 1  0.948   0.960   0.973    0.99   0.992   0.985
# 2  0.930   0.974   0.972    0.96   0.987   0.958

# %%
# ctau-1, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[0].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[0].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[0].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 1mm')

# %%
# ctau-10, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[1].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[1].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 10mm')

# %%
# ctau-100, delta 0.1

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p1'].iloc[2].dropna().to_list()
y_arr2 = purity['BDTv2']['0p1'].iloc[2].dropna().to_list()
y_arr3 = purity['Cut']['0p1'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.1, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.1, Ctau = 100mm')

# %%
# ctau-1, delta 0.2

#x_arr1 = [5,10,20,30,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = (purity['BDTv1']['0p2'].iloc[0])[purity['BDTv1']['0p2'].iloc[0] != 0].to_list()
y_arr2 = (purity['BDTv2']['0p2'].iloc[0])[purity['BDTv2']['0p2'].iloc[0] != 0].to_list()
y_arr3 = (purity['Cut']['0p2'].iloc[0])[purity['Cut']['0p2'].iloc[0] != 0].to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 1mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 1mm')

# %%
# ctau-10, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p2'].iloc[1].dropna().to_list()
y_arr2 = purity['BDTv2']['0p2'].iloc[1].dropna().to_list()
y_arr3 = purity['Cut']['0p2'].iloc[1].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 10mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 10mm')

# %%
# ctau-100, delta 0.2

#x_arr1 = [5,10,20,30,40,50]
x_arr2 = [5,10,20,30,40,50]
x_arr3 = [5,10,20,30,40,50]

#y_arr1 = purity['BDTv1']['0p2'].iloc[2].dropna().to_list()
y_arr2 = purity['BDTv2']['0p2'].iloc[2].dropna().to_list()
y_arr3 = purity['Cut']['0p2'].iloc[2].dropna().to_list()

#plt.plot(x_arr1, y_arr1, 'o-', label='BDTv1 SR')
plt.plot(x_arr2, y_arr2, 'o-', label='BDT SR')
plt.plot(x_arr3, y_arr3, 'o-', label='Cut-based SR')

plt.xlabel('m1 [GeV]')
plt.ylabel('Vertex purity')

plt.ylim([0.7,1.0])
plt.legend()

plt.grid()

plt.title('Delta = 0.2, Ctau = 100mm')
# Out:
# Text(0.5, 1.0, 'Delta = 0.2, Ctau = 100mm')
