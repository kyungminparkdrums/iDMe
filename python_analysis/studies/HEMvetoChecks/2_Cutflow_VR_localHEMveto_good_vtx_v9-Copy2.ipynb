# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = 'VR_localHEMveto_good_vtx_v9'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
# sig_histo / bkg_histo is a dictionary of variables
print(bkg_histo.keys())
# Out:
# dict_keys(['lead_jet_phi_vs_lead_jet_eta', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched'])

# %% [markdown]
# ## Background

# %%
# efficiency
pd.options.display.float_format = '{:,.8f}'.format

bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow')
bkg_eff_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M50         0.00039399          0.00000407
# DY-M4to50      0.00002646          0.00000032
# ZGamma         0.00032470          0.00000322
# Multiboson     0.00065914          0.00000364
# WJets          0.00101329          0.00000459
# TTX            0.00136440          0.00002250
# SingleTop      0.00023564          0.00000184
# ZJets          0.00242166          0.00001128
# TTbar          0.00044365          0.00000599
# QCD            0.00000248          0.00000003
# Total          0.00001468          0.00000010
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M50                              0.00000377
# DY-M4to50                           0.00000031
# ZGamma                              0.00000321
# Multiboson                          0.00000338
# WJets                               0.00000433
# TTX                                 0.00002262
# SingleTop                           0.00000169
# ZJets                               0.00001061
# TTbar                               0.00000555
# QCD                                 0.00000001
# Total                               0.00000008
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M50                                             0.00000373
# DY-M4to50                                          0.00000031
# ZGamma                                             0.00000321
# Multiboson                                         0.00000338
# WJets                                              0.00000430
# TTX                                                0.00002209
# SingleTop                                          0.00000169
# ZJets                                              0.00001055
# TTbar                                              0.00000552
# QCD                                                0.00000001
# Total                                              0.00000008
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M50             0.00000353        0.00000180               0.00000171
# DY-M4to50          0.00000030        0.00000017               0.00000016
# ZGamma             0.00000305        0.00000146               0.00000113
# Multiboson         0.00000315        0.00000154               0.00000140
# WJets              0.00000405        0.00000223               0.00000211
# TTX                0.00002083        0.00000531               0.00000476
# SingleTop          0.00000159        0.00000064               0.00000059
# ZJets              0.00001002        0.00000586               0.00000548
# TTbar              0.00000528        0.00000189               0.00000177
# QCD                0.00000001        0.00000000               0.00000000
# Total              0.00000007        0.00000003               0.00000003
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M50                   0.00000171                   0.00000170
# DY-M4to50                0.00000016                   0.00000016
# ZGamma                   0.00000113                   0.00000113
# Multiboson               0.00000136                   0.00000133
# WJets                    0.00000209                   0.00000208
# TTX                      0.00000473                   0.00000468
# SingleTop                0.00000059                   0.00000059
# ZJets                    0.00000544                   0.00000538
# TTbar                    0.00000174                   0.00000173
# QCD                      0.00000000                   0.00000000
# Total                    0.00000003                   0.00000003
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M50                     0.00000109            0.00000044
# DY-M4to50                  0.00000009            0.00000002
# ZGamma                     0.00000082            0.00000020
# Multiboson                 0.00000088            0.00000034
# WJets                      0.00000129            0.00000051
# TTX                       -0.00000050            0.00000040
# SingleTop                  0.00000034            0.00000015
# ZJets                      0.00000363            0.00000165
# TTbar                      0.00000109            0.00000042
# QCD                        0.00000000            0.00000000
# Total                      0.00000002            0.00000001

# %%
# Save as csv
outdir = f'./csv/{suffix}/Cutflow/Efficiency/'
outname = f'Background_Efficiency'

df_to_save = bkg_eff_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto_good_vtx_v9/Cutflow/Efficiency//Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_cts_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M50           4,354.47               44.96
# DY-M4to50          376.94                4.61
# ZGamma           1,665.25               16.50
# Multiboson       4,593.86               25.36
# WJets          177,451.75              804.65
# TTX                423.57                6.98
# SingleTop        3,665.01               28.67
# ZJets           51,827.18              241.43
# TTbar           22,073.23              298.27
# QCD             53,319.99              655.39
# Total          319,751.23            2,126.82
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M50                                   41.61
# DY-M4to50                                 4.46
# ZGamma                                   16.49
# Multiboson                               23.56
# WJets                                   757.80
# TTX                                       7.02
# SingleTop                                26.32
# ZJets                                   227.14
# TTbar                                   276.20
# QCD                                     301.96
# Total                                 1,682.56
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M50                                                  41.25
# DY-M4to50                                                4.45
# ZGamma                                                  16.49
# Multiboson                                              23.56
# WJets                                                  753.60
# TTX                                                      6.86
# SingleTop                                               26.23
# ZJets                                                  225.69
# TTbar                                                  274.62
# QCD                                                    301.73
# Total                                                1,674.46
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M50                  38.99             19.93                    18.92
# DY-M4to50                4.30              2.36                     2.35
# ZGamma                  15.65              7.47                     5.78
# Multiboson              21.94             10.71                     9.77
# WJets                  710.05            390.38                   368.94
# TTX                      6.47              1.65                     1.48
# SingleTop               24.76              9.88                     9.22
# ZJets                  214.50            125.45                   117.33
# TTbar                  262.53             93.85                    88.06
# QCD                    286.92             72.79                    72.79
# Total                1,586.10            734.47                   694.64
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M50                        18.91                        18.80
# DY-M4to50                      2.35                         2.32
# ZGamma                         5.78                         5.78
# Multiboson                     9.46                         9.24
# WJets                        366.34                       363.72
# TTX                            1.47                         1.45
# SingleTop                      9.22                         9.15
# ZJets                        116.37                       115.23
# TTbar                         86.80                        86.25
# QCD                           72.79                        71.47
# Total                        689.48                       683.41
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M50                          12.06                  4.92
# DY-M4to50                        1.26                  0.27
# ZGamma                           4.20                  1.00
# Multiboson                       6.11                  2.35
# WJets                          225.67                 88.52
# TTX                             -0.15                  0.13
# SingleTop                        5.28                  2.30
# ZJets                           77.74                 35.38
# TTbar                           54.21                 21.01
# QCD                              0.00                  0.00
# Total                          386.37                155.88

# %%
# Save to csv
outdir = f'./csv/{suffix}/Cutflow/EventCount_Weighted/'
outname = f'Background_EventCount_Weighted'

df_to_save = bkg_cts_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto_good_vtx_v9/Cutflow/EventCount_Weighted//Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M50             272468                3241
# DY-M4to50           25923                 322
# ZGamma               6511                  77
# Multiboson          24553                 155
# WJets             1171204                5836
# TTX                141391                1942
# SingleTop           46314                 296
# ZJets              729756                4411
# TTbar              519733                6947
# QCD                 31603                 132
# Total             2969456               23359
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M50                                    3039
# DY-M4to50                                  302
# ZGamma                                      74
# Multiboson                                 144
# WJets                                     5485
# TTX                                       1801
# SingleTop                                  278
# ZJets                                     4151
# TTbar                                     6433
# QCD                                        127
# Total                                    21834
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M50                                                   3009
# DY-M4to50                                                 301
# ZGamma                                                     74
# Multiboson                                                144
# WJets                                                    5447
# TTX                                                      1788
# SingleTop                                                 275
# ZJets                                                    4122
# TTbar                                                    6395
# QCD                                                       126
# Total                                                   21681
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M50                   2872              1170                     1149
# DY-M4to50                 285               155                      154
# ZGamma                     70                39                       34
# Multiboson                136                72                       68
# WJets                    5153              2386                     2319
# TTX                      1717               517                      492
# SingleTop                 264               101                       89
# ZJets                    3921              2253                     2166
# TTbar                    6115              2168                     2028
# QCD                       119                31                       31
# Total                   20652              8892                     8530
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M50                         1148                         1114
# DY-M4to50                       154                          149
# ZGamma                           34                           34
# Multiboson                       67                           65
# WJets                          2314                         2243
# TTX                             479                          464
# SingleTop                        89                           87
# ZJets                          2161                         2121
# TTbar                          1995                         1981
# QCD                              31                           28
# Total                          8472                         8286
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M50                            568                   235
# DY-M4to50                          77                    30
# ZGamma                             16                     3
# Multiboson                         41                    19
# WJets                            1100                   470
# TTX                               296                   115
# SingleTop                          45                    17
# ZJets                            1220                   549
# TTbar                            1241                   483
# QCD                                 0                     0
# Total                            4604                  1921

# %%
outdir = f'./csv/{suffix}/Cutflow/EventCount_Raw/'
outname = f'Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto_good_vtx_v9/Cutflow/EventCount_Raw//Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 155.88

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['Vtx CosCollinear < 0']).transpose(), pd.DataFrame(bkg_cts_raw_df['Vtx CosCollinear < 0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  DY-M50  DY-M4to50  ZGamma  Multiboson  WJets    TTX  \
# Weighted Counts    4.92       0.27    1.00        2.35  88.52   0.13
# Raw Counts       235.00      30.00    3.00       19.00 470.00 115.00
#
#                  SingleTop  ZJets  TTbar  QCD    Total
# Weighted Counts       2.30  35.38  21.01 0.00   155.88
# Raw Counts           17.00 549.00 483.00 0.00 1,921.00

# %% [markdown]
# ## Data

# %%
pd.options.display.float_format = '{:,.1f}'.format
data_cts_df = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
data_cts_df
# Out:
#                                       Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_MET_Run2018D      364,387.0             2,506.0
# data_2018_Data_MET_UL18_MET_Run2018C       82,311.0               552.0
# data_2018_Data_MET_UL18_MET_Run2018B       63,815.0               362.0
# data_2018_Data_MET_UL18_MET_Run2018A      124,602.0               741.0
# Total                                     635,115.0             4,161.0
#
#                                       HEM Jet Veto (eta upper bound bug)  \
# data_2018_Data_MET_UL18_MET_Run2018D                             2,096.0
# data_2018_Data_MET_UL18_MET_Run2018C                               476.0
# data_2018_Data_MET_UL18_MET_Run2018B                               330.0
# data_2018_Data_MET_UL18_MET_Run2018A                               687.0
# Total                                                            3,589.0
#
#                                       HEM Jet Veto (additionally veto missing eta region)  \
# data_2018_Data_MET_UL18_MET_Run2018D                                            2,079.0
# data_2018_Data_MET_UL18_MET_Run2018C                                              475.0
# data_2018_Data_MET_UL18_MET_Run2018B                                              326.0
# data_2018_Data_MET_UL18_MET_Run2018A                                              681.0
# Total                                                                           3,561.0
#
#                                       HEM electron Veto  No b-tagged jets  \
# data_2018_Data_MET_UL18_MET_Run2018D            1,712.0             667.0
# data_2018_Data_MET_UL18_MET_Run2018C              402.0             149.0
# data_2018_Data_MET_UL18_MET_Run2018B              309.0             124.0
# data_2018_Data_MET_UL18_MET_Run2018A              648.0             229.0
# Total                                           3,071.0           1,169.0
#
#                                       Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_MET_Run2018D                    573.0
# data_2018_Data_MET_UL18_MET_Run2018C                    124.0
# data_2018_Data_MET_UL18_MET_Run2018B                    103.0
# data_2018_Data_MET_UL18_MET_Run2018A                    187.0
# Total                                                   987.0
#
#                                       Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_MET_Run2018D                    568.0
# data_2018_Data_MET_UL18_MET_Run2018C                    123.0
# data_2018_Data_MET_UL18_MET_Run2018B                    102.0
# data_2018_Data_MET_UL18_MET_Run2018A                    186.0
# Total                                                   979.0
#
#                                       dPhi(MET,leading jet) > 1.5  \
# data_2018_Data_MET_UL18_MET_Run2018D                        562.0
# data_2018_Data_MET_UL18_MET_Run2018C                        120.0
# data_2018_Data_MET_UL18_MET_Run2018B                        100.0
# data_2018_Data_MET_UL18_MET_Run2018A                        182.0
# Total                                                       964.0
#
#                                       dPhi(MET,all jets) > 0.75  \
# data_2018_Data_MET_UL18_MET_Run2018D                      311.0
# data_2018_Data_MET_UL18_MET_Run2018C                       69.0
# data_2018_Data_MET_UL18_MET_Run2018B                       61.0
# data_2018_Data_MET_UL18_MET_Run2018A                      104.0
# Total                                                     545.0
#
#                                       Vtx CosCollinear < 0
# data_2018_Data_MET_UL18_MET_Run2018D                 132.0
# data_2018_Data_MET_UL18_MET_Run2018C                  40.0
# data_2018_Data_MET_UL18_MET_Run2018B                  31.0
# data_2018_Data_MET_UL18_MET_Run2018A                  54.0
# Total                                                257.0

# %%
pd.options.display.float_format = '{:,.1f}'.format

data_composition = pd.DataFrame(data_cts_df['Vtx CosCollinear < 0']).transpose()

data_composition = data_composition.rename(index={'Vtx CosCollinear < 0': 'Data Yield'})
data_composition = data_composition.rename(columns={'data_2018_Data_MET_UL18_MET_Run2018C': 'Run2018C', \
                                                   'data_2018_Data_MET_UL18_MET_Run2018B': 'Run2018B', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018A': 'Run2018A', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018D': 'Run2018D'
                                                   })

data_composition = data_composition.reindex(sorted(data_composition.columns), axis=1)

data_composition
# Out:
#             Run2018A  Run2018B  Run2018C  Run2018D  Total
# Data Yield      54.0      31.0      40.0     132.0  257.0

# %%
# Data/background MC
data_yield = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
mc_yield = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']

data_yield / mc_yield
# Out:
# Preselections                                         2.0
# n(good vertex) > 0                                    2.0
# HEM Jet Veto (eta upper bound bug)                    2.1
# HEM Jet Veto (additionally veto missing eta region)   2.1
# HEM electron Veto                                     1.9
# No b-tagged jets                                      1.6
# Leading jet |eta| < 2.4                               1.4
# Leading jet pT > 80 GeV                               1.4
# dPhi(MET,leading jet) > 1.5                           1.4
# dPhi(MET,all jets) > 0.75                             1.4
# Vtx CosCollinear < 0                                  1.6
# Name: Total, dtype: float64

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         635,115.0
# n(good vertex) > 0                                      4,161.0
# HEM Jet Veto (eta upper bound bug)                      3,589.0
# HEM Jet Veto (additionally veto missing eta region)     3,561.0
# HEM electron Veto                                       3,071.0
# No b-tagged jets                                        1,169.0
# Leading jet |eta| < 2.4                                   987.0
# Leading jet pT > 80 GeV                                   979.0
# dPhi(MET,leading jet) > 1.5                               964.0
# dPhi(MET,all jets) > 0.75                                 545.0
# Vtx CosCollinear < 0                                      257.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         319,751.2
# n(good vertex) > 0                                      2,126.8
# HEM Jet Veto (eta upper bound bug)                      1,682.6
# HEM Jet Veto (additionally veto missing eta region)     1,674.5
# HEM electron Veto                                       1,586.1
# No b-tagged jets                                          734.5
# Leading jet |eta| < 2.4                                   694.6
# Leading jet pT > 80 GeV                                   689.5
# dPhi(MET,leading jet) > 1.5                               683.4
# dPhi(MET,all jets) > 0.75                                 386.4
# Vtx CosCollinear < 0                                      155.9
# Name: Total, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(7,7))

mplhep.cms.label('', data=True, year=2018)

data_cutflow = np.array(utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total'].to_list())
bkg_cutflow = np.array(utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total'].to_list())

plt.plot(data_cutflow, '-o', label='Data')
plt.plot(bkg_cutflow, '-o', label='Background MC (Total)')

plt.legend()

ratio_length = (ax.get_position().y1 - ax.get_position().y0) / 3
ax_ratio = fig.add_axes([ax.get_position().x0, ax.get_position().y0 - ratio_length * 1.2, \
                         ax.get_position().x1 - ax.get_position().x0, ratio_length]) 

ax.get_shared_x_axes().join(ax, ax_ratio)
ax.xaxis.set_ticklabels([])

ax_ratio.set_xlabel(ax.get_xlabel())
ax.set_xlabel('')
ax_ratio.set_ylabel('Data/MC')
ax_ratio.set_ylim([0,2.5])

ratio = data_cutflow / bkg_cutflow
    
ax_ratio.plot(ratio, 'o', color='black')
    
ax_ratio.axhline(y=1, color='black', linestyle='--', linewidth=0.8)

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

plt.xticks(ticks = np.arange(len(data_cutflow)), labels = cuts, rotation = 45, ha = 'right')

ax.set_ylabel('Events')
ax.set_yscale('log')
# Out:
# /tmp/ipykernel_2763285/1904301384.py:17: MatplotlibDeprecationWarning: The join function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.get_shared_x_axes().join(ax, ax_ratio)

# %% [markdown]
# ### Plot the efficiency

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/VR_localHEMveto_good_vtx_v9/cutflow//Cutflow_background.png

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         635,115.0
# n(good vertex) > 0                                      4,161.0
# HEM Jet Veto (eta upper bound bug)                      3,589.0
# HEM Jet Veto (additionally veto missing eta region)     3,561.0
# HEM electron Veto                                       3,071.0
# No b-tagged jets                                        1,169.0
# Leading jet |eta| < 2.4                                   987.0
# Leading jet pT > 80 GeV                                   979.0
# dPhi(MET,leading jet) > 1.5                               964.0
# dPhi(MET,all jets) > 0.75                                 545.0
# Vtx CosCollinear < 0                                      257.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M50            4,354.5                45.0
# DY-M4to50           376.9                 4.6
# ZGamma            1,665.3                16.5
# Multiboson        4,593.9                25.4
# WJets           177,451.8               804.6
# TTX                 423.6                 7.0
# SingleTop         3,665.0                28.7
# ZJets            51,827.2               241.4
# TTbar            22,073.2               298.3
# QCD              53,320.0               655.4
# Total           319,751.2             2,126.8
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M50                                    41.6
# DY-M4to50                                  4.5
# ZGamma                                    16.5
# Multiboson                                23.6
# WJets                                    757.8
# TTX                                        7.0
# SingleTop                                 26.3
# ZJets                                    227.1
# TTbar                                    276.2
# QCD                                      302.0
# Total                                  1,682.6
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M50                                                   41.3
# DY-M4to50                                                 4.5
# ZGamma                                                   16.5
# Multiboson                                               23.6
# WJets                                                   753.6
# TTX                                                       6.9
# SingleTop                                                26.2
# ZJets                                                   225.7
# TTbar                                                   274.6
# QCD                                                     301.7
# Total                                                 1,674.5
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M50                   39.0              19.9                     18.9
# DY-M4to50                 4.3               2.4                      2.3
# ZGamma                   15.6               7.5                      5.8
# Multiboson               21.9              10.7                      9.8
# WJets                   710.1             390.4                    368.9
# TTX                       6.5               1.6                      1.5
# SingleTop                24.8               9.9                      9.2
# ZJets                   214.5             125.4                    117.3
# TTbar                   262.5              93.9                     88.1
# QCD                     286.9              72.8                     72.8
# Total                 1,586.1             734.5                    694.6
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M50                         18.9                         18.8
# DY-M4to50                       2.3                          2.3
# ZGamma                          5.8                          5.8
# Multiboson                      9.5                          9.2
# WJets                         366.3                        363.7
# TTX                             1.5                          1.5
# SingleTop                       9.2                          9.1
# ZJets                         116.4                        115.2
# TTbar                          86.8                         86.2
# QCD                            72.8                         71.5
# Total                         689.5                        683.4
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M50                           12.1                   4.9
# DY-M4to50                         1.3                   0.3
# ZGamma                            4.2                   1.0
# Multiboson                        6.1                   2.4
# WJets                           225.7                  88.5
# TTX                              -0.2                   0.1
# SingleTop                         5.3                   2.3
# ZJets                            77.7                  35.4
# TTbar                            54.2                  21.0
# QCD                               0.0                   0.0
# Total                           386.4                 155.9

# %%
cmap = ["#3f90da", "#ffa90e", "#bd1f01", "#94a4a2", "#832db6", "#a96b59", "#e76300", "#b9ac70", "#717581", "#92dadd"] # cms-recommended
bkg_cmap = {
    "QCD": cmap[0],
    "WJets": cmap[1],
    "ZJets": cmap[2],
    "DY-M4to50": cmap[3],
    "DY-M50": cmap[4],
    "TTbar": cmap[5],
    "SingleTop": cmap[6],
    "Multiboson": cmap[7],
    "ZGamma": cmap[8],
    "TTX": cmap[9]
}

df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
processes = df.index.values.tolist()

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

# Color map for each process
for process in processes:
    if 'Total' in process:
        plt.plot(cuts, df.loc[process], label=process, color='black')
    else:
        plt.plot(cuts, df.loc[process], label=process, color = bkg_cmap[process])

# plot data
df_data = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
plt.plot(cuts, df_data.loc['Total'], label='Data: Run2018[A-D]', color = 'blue', marker='o', linestyle='--')

if plot_dict_bkg_eff['doLog']:
    plt.yscale('log')

if plot_dict_bkg_eff['ylim'] != None:
    plt.ylim(plot_dict_bkg_eff['ylim'][0], plot_dict_bkg_eff['ylim'][1])
    
plt.grid()
    
plt.ylabel(plot_dict_bkg_eff['ylabel'])
plt.title(plot_dict_bkg_eff['title'])
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cuts, rotation = 45, ha = 'right')
    
plt.legend(loc='upper right')
    
if plot_dict_bkg_eff['doSave']:
    os.makedirs(plot_dict_bkg_eff['outDir'], exist_ok=True)
    plt.tight_layout()
    plt.savefig(f"{plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    print(f"Saved: {plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    
plt.show()
# Out:
# Saved: ./plots/VR_localHEMveto_good_vtx_v9/cutflow//Cutflow_background.png
