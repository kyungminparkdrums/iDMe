# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'
suffix = 'VR_localHEMveto'

# %%
# Signal
#sig_histo = util.load(f'{prefix}/signal{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %%
# Data
data_histo = util.load(f'{prefix}/data_{suffix}.coffea')[0]

# %%
# sig_histo / bkg_histo is a dictionary of variables
print(bkg_histo.keys())
# Out:
# dict_keys(['sel_e1_pt', 'sel_e1_eta', 'sel_e1_phi', 'sel_e1_dxy', 'sel_e1_dxySignif', 'sel_e1_vxy1', 'sel_e1_vz', 'sel_e2_pt', 'sel_e2_eta', 'sel_e2_phi', 'sel_e2_dxy', 'sel_e2_dxySignif', 'sel_e2_vxy1', 'sel_e2_vz', 'sel_vtx_dR', 'sel_vtx_mindxy', 'sel_vtx_vxy1', 'sel_vtx_vxy10', 'sel_vtx_vxy100', 'sel_vtx_leadpT', 'sel_vtx_METdPhi', 'sel_vtx_mindRj', 'sel_vtx_chi2', 'sel_vtx_mass', 'sel_vtx_mindPhiJ', 'sel_vtx_sign', 'sel_vtx_pt', 'sel_vtx_eta', 'sel_vtx_phi', 'sel_vtx_type', 'sel_vtx_minEleDrJ', 'sel_vtx_minEleDPhiJ', 'sel_vtx_mass_low', 'sel_vtx_mindxy_low', 'sel_vtx_sign_etaProd', 'sel_vtx_CosThetaColl', 'sel_vtx_LxyCosThetaColl', 'sel_vtx_LxyCosThetaCollZoom', 'sel_vtx_LxyCosThetaCollZoomZoom', 'sel_vtx_eleDphi', 'sel_vtx_maxMiniRelIso', 'sel_vtx_maxMiniRelIsoCorr', 'sel_vtx_mass_refit', 'sel_vtx_mass_low_refit', 'sel_vtx_pt_refit', 'sel_vtx_eta_refit', 'sel_vtx_phi_refit', 'sel_vtx_dR_refit', 'sel_vtx_mass_refit_vs_sel_vtx_mass', 'sel_vtx_mass_low_refit_vs_sel_vtx_mass_low', 'sel_vtx_pt_refit_vs_sel_vtx_pt', 'sel_vtx_eta_refit_vs_sel_vtx_eta', 'sel_vtx_phi_refit_vs_sel_vtx_phi', 'sel_vtx_dR_refit_vs_sel_vtx_dR', 'sel_vtx_mass_vs_vxy', 'sel_vtx_mass_refit_vs_vxy', 'sel_e1_phi_vs_METphi', 'sel_e1_phi_vs_sel_e1_eta', 'sel_e1_phi_vs_sel_e1_pt', 'sel_e2_phi_vs_METphi', 'sel_e2_phi_vs_sel_e2_eta', 'sel_e2_phi_vs_sel_e2_pt', 'sel_vtx_phi_vs_sel_vtx_eta', 'sel_vtx_phi_vs_sel_vtx_pt', 'sel_vtx_phi_vs_sel_vtx_dR', 'sel_vtx_phi_vs_sel_vtx_pt800', 'sel_vtx_phi_refit_zoom_vs_sel_vtx_phi_zoom', 'sel_e1_phi_zoom_vs_sel_e1_eta', 'sel_e2_phi_zoom_vs_sel_e2_eta', 'sel_vtx_phi_vs_METphi', 'sel_vtx_phi_vs_lead_jet_phi', 'sel_vtx_phi_refit_vs_METphi', 'sel_vtx_phi_refit_vs_lead_jet_phi', 'METphi_vs_lead_jet_phi', 'sel_vtx_phi_refit_over_phi', 'sel_vtx_vx_vs_vy', 'PVx_vs_PVy', 'PFMET', 'PFMET1000', 'PFMETphi', 'jetMETdPhi', 'minJetMETdPhi', 'nJets', 'lead_jet_pt', 'lead_jet_eta', 'lead_jet_phi', 'jetMETratio', 'lead_jet_phi_vs_lead_jet_eta', 'PVx', 'PVy', 'cutDesc', 'cutflow', 'cutflow_cts', 'cutflow_nevts', 'cutflow_vtx_matched'])

# %% [markdown]
# ## Background

# %%
# efficiency
pd.options.display.float_format = '{:,.8f}'.format

bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow')
bkg_eff_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M4to50      0.00002646          0.00000032
# DY-M50         0.00039399          0.00000412
# SingleTop      0.00023564          0.00000196
# TTbar          0.00044365          0.00000622
# ZJets          0.00242166          0.00001459
# Multiboson     0.00065914          0.00000399
# QCD            0.00000248          0.00000003
# TTX            0.00136440          0.00001833
# ZGamma         0.00032470          0.00000257
# WJets          0.00101329          0.00000519
# Total          0.00001468          0.00000011
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M4to50                           0.00000030
# DY-M50                              0.00000380
# SingleTop                           0.00000179
# TTbar                               0.00000577
# ZJets                               0.00001373
# Multiboson                          0.00000359
# QCD                                 0.00000002
# TTX                                 0.00001893
# ZGamma                              0.00000273
# WJets                               0.00000488
# Total                               0.00000009
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M4to50                                          0.00000030
# DY-M50                                             0.00000376
# SingleTop                                          0.00000178
# TTbar                                              0.00000573
# ZJets                                              0.00001365
# Multiboson                                         0.00000359
# QCD                                                0.00000002
# TTX                                                0.00001840
# ZGamma                                             0.00000273
# WJets                                              0.00000485
# Total                                              0.00000009
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M4to50          0.00000029        0.00000015               0.00000015
# DY-M50             0.00000356        0.00000178               0.00000169
# SingleTop          0.00000168        0.00000061               0.00000057
# TTbar              0.00000549        0.00000194               0.00000181
# ZJets              0.00001309        0.00000761               0.00000713
# Multiboson         0.00000336        0.00000170               0.00000154
# QCD                0.00000002        0.00000001               0.00000001
# TTX                0.00001712        0.00000490               0.00000482
# ZGamma             0.00000253        0.00000155               0.00000138
# WJets              0.00000459        0.00000249               0.00000237
# Total              0.00000008        0.00000004               0.00000004
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M4to50                0.00000015                   0.00000015
# DY-M50                   0.00000168                   0.00000168
# SingleTop                0.00000057                   0.00000056
# TTbar                    0.00000178                   0.00000177
# ZJets                    0.00000704                   0.00000697
# Multiboson               0.00000150                   0.00000147
# QCD                      0.00000001                   0.00000000
# TTX                      0.00000480                   0.00000473
# ZGamma                   0.00000138                   0.00000138
# WJets                    0.00000235                   0.00000233
# Total                    0.00000004                   0.00000004
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M4to50                  0.00000007            0.00000002
# DY-M50                     0.00000107            0.00000041
# SingleTop                  0.00000030            0.00000012
# TTbar                      0.00000111            0.00000041
# ZJets                      0.00000477            0.00000160
# Multiboson                 0.00000102            0.00000029
# QCD                        0.00000000            0.00000000
# TTX                       -0.00000046            0.00000129
# ZGamma                     0.00000098            0.00000020
# WJets                      0.00000146            0.00000047
# Total                      0.00000002            0.00000001

# %%
# Save as csv
outdir = f'./csv/{suffix}/Cutflow/Efficiency/'
outname = f'Background_Efficiency'

df_to_save = bkg_eff_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto/Cutflow/Efficiency//Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_cts_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M4to50          376.94                4.51
# DY-M50           4,354.47               45.49
# SingleTop        3,665.01               30.54
# TTbar           22,073.23              309.44
# ZJets           51,827.18              312.30
# Multiboson       4,593.86               27.83
# QCD             53,319.99              713.31
# TTX                423.57                5.69
# ZGamma           1,665.25               13.18
# WJets          177,451.75              909.77
# Total          319,751.23            2,372.06
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M4to50                                 4.34
# DY-M50                                   41.95
# SingleTop                                27.85
# TTbar                                   286.93
# ZJets                                   293.85
# Multiboson                               25.02
# QCD                                     354.91
# TTX                                       5.88
# ZGamma                                   14.00
# WJets                                   855.16
# Total                                 1,909.88
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M4to50                                                4.34
# DY-M50                                                  41.58
# SingleTop                                               27.67
# TTbar                                                  285.30
# ZJets                                                  292.03
# Multiboson                                              25.02
# QCD                                                    354.68
# TTX                                                      5.71
# ZGamma                                                  14.00
# WJets                                                  849.77
# Total                                                1,900.09
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M4to50                4.17              2.20                     2.18
# DY-M50                  39.30             19.62                    18.63
# SingleTop               26.12              9.51                     8.86
# TTbar                  273.32             96.40                    90.00
# ZJets                  280.20            162.87                   152.70
# Multiboson              23.40             11.87                    10.77
# QCD                    340.42            109.44                   109.44
# TTX                      5.31              1.52                     1.50
# ZGamma                  12.99              7.93                     7.06
# WJets                  804.25            436.79                   414.72
# Total                1,809.48            858.14                   815.83
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M4to50                      2.18                         2.16
# DY-M50                        18.61                        18.51
# SingleTop                      8.86                         8.78
# TTbar                         88.68                        88.13
# ZJets                        150.60                       149.23
# Multiboson                    10.45                        10.23
# QCD                          109.44                       102.07
# TTX                            1.49                         1.47
# ZGamma                         7.06                         7.06
# WJets                        412.12                       408.18
# Total                        809.49                       795.81
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M4to50                        1.06                  0.23
# DY-M50                          11.83                  4.57
# SingleTop                        4.61                  1.80
# TTbar                           55.25                 20.20
# ZJets                          102.00                 34.32
# Multiboson                       7.11                  2.04
# QCD                              0.00                  0.00
# TTX                             -0.14                  0.40
# ZGamma                           5.02                  1.00
# WJets                          256.37                 82.76
# Total                          443.11                147.32

# %%
# Save to csv
outdir = f'./csv/{suffix}/Cutflow/EventCount_Weighted/'
outname = f'Background_EventCount_Weighted'

df_to_save = bkg_cts_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto/Cutflow/EventCount_Weighted//Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M4to50           25923                 343
# DY-M50             272468                3265
# SingleTop           46314                 324
# TTbar              519733                7192
# ZJets              729756                5715
# Multiboson          24553                 165
# QCD                 31603                 167
# TTX                141391                1937
# ZGamma               6511                  70
# WJets             1171204                6465
# Total             2969456               25643
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M4to50                                  320
# DY-M50                                    3054
# SingleTop                                  302
# TTbar                                     6665
# ZJets                                     5381
# Multiboson                                 150
# QCD                                        160
# TTX                                       1800
# ZGamma                                      68
# WJets                                     6075
# Total                                    23975
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M4to50                                                 319
# DY-M50                                                   3022
# SingleTop                                                 297
# TTbar                                                    6626
# ZJets                                                    5346
# Multiboson                                                150
# QCD                                                       159
# TTX                                                      1787
# ZGamma                                                     68
# WJets                                                    6030
# Total                                                   23804
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M4to50                 302               161                      160
# DY-M50                   2885              1152                     1132
# SingleTop                 284               103                       91
# TTbar                    6349              2223                     2069
# ZJets                    5134              2928                     2821
# Multiboson                142                77                       72
# QCD                       153                42                       42
# TTX                      1715               513                      492
# ZGamma                     65                35                       31
# WJets                    5734              2608                     2537
# Total                   22763              9842                     9447
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M4to50                       160                          155
# DY-M50                         1131                         1100
# SingleTop                        91                           89
# TTbar                          2035                         2021
# ZJets                          2812                         2763
# Multiboson                       71                           69
# QCD                              42                           35
# TTX                             479                          464
# ZGamma                           31                           31
# WJets                          2532                         2452
# Total                          9384                         9179
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M4to50                          74                    26
# DY-M50                            551                   222
# SingleTop                          44                    15
# TTbar                            1260                   464
# ZJets                            1589                   530
# Multiboson                         47                    18
# QCD                                 0                     0
# TTX                               296                   110
# ZGamma                             17                     3
# WJets                            1189                   434
# Total                            5067                  1822

# %%
outdir = f'./csv/{suffix}/Cutflow/EventCount_Raw/'
outname = f'Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/VR_localHEMveto/Cutflow/EventCount_Raw//Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 147.32

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['Vtx CosCollinear < 0']).transpose(), pd.DataFrame(bkg_cts_raw_df['Vtx CosCollinear < 0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  DY-M4to50  DY-M50  SingleTop  TTbar  ZJets  Multiboson  QCD  \
# Weighted Counts       0.23    4.57       1.80  20.20  34.32        2.04 0.00
# Raw Counts           26.00  222.00      15.00 464.00 530.00       18.00 0.00
#
#                    TTX  ZGamma  WJets    Total
# Weighted Counts   0.40    1.00  82.76   147.32
# Raw Counts      110.00    3.00 434.00 1,822.00

# %% [markdown]
# ## Data

# %%
pd.options.display.float_format = '{:,.1f}'.format
data_cts_df = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
data_cts_df
# Out:
#                                       Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_MET_Run2018D      364,387.0             2,850.0
# data_2018_Data_MET_UL18_MET_Run2018C       82,311.0               656.0
# data_2018_Data_MET_UL18_MET_Run2018B       63,815.0               425.0
# data_2018_Data_MET_UL18_MET_Run2018A      124,602.0               865.0
# Total                                     635,115.0             4,796.0
#
#                                       HEM Jet Veto (eta upper bound bug)  \
# data_2018_Data_MET_UL18_MET_Run2018D                             2,366.0
# data_2018_Data_MET_UL18_MET_Run2018C                               561.0
# data_2018_Data_MET_UL18_MET_Run2018B                               390.0
# data_2018_Data_MET_UL18_MET_Run2018A                               802.0
# Total                                                            4,119.0
#
#                                       HEM Jet Veto (additionally veto missing eta region)  \
# data_2018_Data_MET_UL18_MET_Run2018D                                            2,346.0
# data_2018_Data_MET_UL18_MET_Run2018C                                              560.0
# data_2018_Data_MET_UL18_MET_Run2018B                                              385.0
# data_2018_Data_MET_UL18_MET_Run2018A                                              796.0
# Total                                                                           4,087.0
#
#                                       HEM electron Veto  No b-tagged jets  \
# data_2018_Data_MET_UL18_MET_Run2018D            1,985.0             751.0
# data_2018_Data_MET_UL18_MET_Run2018C              485.0             169.0
# data_2018_Data_MET_UL18_MET_Run2018B              367.0             142.0
# data_2018_Data_MET_UL18_MET_Run2018A              762.0             260.0
# Total                                           3,599.0           1,322.0
#
#                                       Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_MET_Run2018D                    639.0
# data_2018_Data_MET_UL18_MET_Run2018C                    142.0
# data_2018_Data_MET_UL18_MET_Run2018B                    117.0
# data_2018_Data_MET_UL18_MET_Run2018A                    216.0
# Total                                                 1,114.0
#
#                                       Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_MET_Run2018D                    634.0
# data_2018_Data_MET_UL18_MET_Run2018C                    142.0
# data_2018_Data_MET_UL18_MET_Run2018B                    116.0
# data_2018_Data_MET_UL18_MET_Run2018A                    214.0
# Total                                                 1,106.0
#
#                                       dPhi(MET,leading jet) > 1.5  \
# data_2018_Data_MET_UL18_MET_Run2018D                        626.0
# data_2018_Data_MET_UL18_MET_Run2018C                        139.0
# data_2018_Data_MET_UL18_MET_Run2018B                        114.0
# data_2018_Data_MET_UL18_MET_Run2018A                        210.0
# Total                                                     1,089.0
#
#                                       dPhi(MET,all jets) > 0.75  \
# data_2018_Data_MET_UL18_MET_Run2018D                      323.0
# data_2018_Data_MET_UL18_MET_Run2018C                       80.0
# data_2018_Data_MET_UL18_MET_Run2018B                       66.0
# data_2018_Data_MET_UL18_MET_Run2018A                      113.0
# Total                                                     582.0
#
#                                       Vtx CosCollinear < 0
# data_2018_Data_MET_UL18_MET_Run2018D                 124.0
# data_2018_Data_MET_UL18_MET_Run2018C                  42.0
# data_2018_Data_MET_UL18_MET_Run2018B                  29.0
# data_2018_Data_MET_UL18_MET_Run2018A                  52.0
# Total                                                247.0

# %%
pd.options.display.float_format = '{:,.1f}'.format

data_composition = pd.DataFrame(data_cts_df['Vtx CosCollinear < 0']).transpose()

data_composition = data_composition.rename(index={'Vtx CosCollinear < 0': 'Data Yield'})
data_composition = data_composition.rename(columns={'data_2018_Data_MET_UL18_MET_Run2018C': 'Run2018C', \
                                                   'data_2018_Data_MET_UL18_MET_Run2018B': 'Run2018B', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018A': 'Run2018A', \
                                                    'data_2018_Data_MET_UL18_MET_Run2018D': 'Run2018D'
                                                   })

data_composition = data_composition.reindex(sorted(data_composition.columns), axis=1)

data_composition
# Out:
#             Run2018A  Run2018B  Run2018C  Run2018D  Total
# Data Yield      52.0      29.0      42.0     124.0  247.0

# %%
# Data/background MC
data_yield = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
mc_yield = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']

data_yield / mc_yield
# Out:
# Preselections                                         2.0
# n(good vertex) > 0                                    2.0
# HEM Jet Veto (eta upper bound bug)                    2.2
# HEM Jet Veto (additionally veto missing eta region)   2.2
# HEM electron Veto                                     2.0
# No b-tagged jets                                      1.5
# Leading jet |eta| < 2.4                               1.4
# Leading jet pT > 80 GeV                               1.4
# dPhi(MET,leading jet) > 1.5                           1.4
# dPhi(MET,all jets) > 0.75                             1.3
# Vtx CosCollinear < 0                                  1.7
# Name: Total, dtype: float64

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         635,115.0
# n(good vertex) > 0                                      4,796.0
# HEM Jet Veto (eta upper bound bug)                      4,119.0
# HEM Jet Veto (additionally veto missing eta region)     4,087.0
# HEM electron Veto                                       3,599.0
# No b-tagged jets                                        1,322.0
# Leading jet |eta| < 2.4                                 1,114.0
# Leading jet pT > 80 GeV                                 1,106.0
# dPhi(MET,leading jet) > 1.5                             1,089.0
# dPhi(MET,all jets) > 0.75                                 582.0
# Vtx CosCollinear < 0                                      247.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         319,751.2
# n(good vertex) > 0                                      2,372.1
# HEM Jet Veto (eta upper bound bug)                      1,909.9
# HEM Jet Veto (additionally veto missing eta region)     1,900.1
# HEM electron Veto                                       1,809.5
# No b-tagged jets                                          858.1
# Leading jet |eta| < 2.4                                   815.8
# Leading jet pT > 80 GeV                                   809.5
# dPhi(MET,leading jet) > 1.5                               795.8
# dPhi(MET,all jets) > 0.75                                 443.1
# Vtx CosCollinear < 0                                      147.3
# Name: Total, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(7,7))

mplhep.cms.label('', data=True, year=2018)

data_cutflow = np.array(utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total'].to_list())
bkg_cutflow = np.array(utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts').loc['Total'].to_list())

plt.plot(data_cutflow, '-o', label='Data')
plt.plot(bkg_cutflow, '-o', label='Background MC (Total)')

plt.legend()

ratio_length = (ax.get_position().y1 - ax.get_position().y0) / 3
ax_ratio = fig.add_axes([ax.get_position().x0, ax.get_position().y0 - ratio_length * 1.2, \
                         ax.get_position().x1 - ax.get_position().x0, ratio_length]) 

ax.get_shared_x_axes().join(ax, ax_ratio)
ax.xaxis.set_ticklabels([])

ax_ratio.set_xlabel(ax.get_xlabel())
ax.set_xlabel('')
ax_ratio.set_ylabel('Data/MC')
ax_ratio.set_ylim([0,2.5])

ratio = data_cutflow / bkg_cutflow
    
ax_ratio.plot(ratio, 'o', color='black')
    
ax_ratio.axhline(y=1, color='black', linestyle='--', linewidth=0.8)

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

plt.xticks(ticks = np.arange(len(data_cutflow)), labels = cuts, rotation = 45, ha = 'right')

ax.set_ylabel('Events')
ax.set_yscale('log')
# Out:
# /tmp/ipykernel_2654426/1904301384.py:17: MatplotlibDeprecationWarning: The join function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.get_shared_x_axes().join(ax, ax_ratio)

# %% [markdown]
# ### Plot the efficiency

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/VR_localHEMveto/cutflow//Cutflow_background.png

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts').loc['Total']
# Out:
# Preselections                                         635,115.0
# n(good vertex) > 0                                      4,796.0
# HEM Jet Veto (eta upper bound bug)                      4,119.0
# HEM Jet Veto (additionally veto missing eta region)     4,087.0
# HEM electron Veto                                       3,599.0
# No b-tagged jets                                        1,322.0
# Leading jet |eta| < 2.4                                 1,114.0
# Leading jet pT > 80 GeV                                 1,106.0
# dPhi(MET,leading jet) > 1.5                             1,089.0
# dPhi(MET,all jets) > 0.75                                 582.0
# Vtx CosCollinear < 0                                      247.0
# Name: Total, dtype: float64

# %%
utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
# Out:
#             Preselections  n(good vertex) > 0  \
# DY-M4to50           376.9                 4.5
# DY-M50            4,354.5                45.5
# SingleTop         3,665.0                30.5
# TTbar            22,073.2               309.4
# ZJets            51,827.2               312.3
# Multiboson        4,593.9                27.8
# QCD              53,320.0               713.3
# TTX                 423.6                 5.7
# ZGamma            1,665.3                13.2
# WJets           177,451.8               909.8
# Total           319,751.2             2,372.1
#
#             HEM Jet Veto (eta upper bound bug)  \
# DY-M4to50                                  4.3
# DY-M50                                    42.0
# SingleTop                                 27.8
# TTbar                                    286.9
# ZJets                                    293.8
# Multiboson                                25.0
# QCD                                      354.9
# TTX                                        5.9
# ZGamma                                    14.0
# WJets                                    855.2
# Total                                  1,909.9
#
#             HEM Jet Veto (additionally veto missing eta region)  \
# DY-M4to50                                                 4.3
# DY-M50                                                   41.6
# SingleTop                                                27.7
# TTbar                                                   285.3
# ZJets                                                   292.0
# Multiboson                                               25.0
# QCD                                                     354.7
# TTX                                                       5.7
# ZGamma                                                   14.0
# WJets                                                   849.8
# Total                                                 1,900.1
#
#             HEM electron Veto  No b-tagged jets  Leading jet |eta| < 2.4  \
# DY-M4to50                 4.2               2.2                      2.2
# DY-M50                   39.3              19.6                     18.6
# SingleTop                26.1               9.5                      8.9
# TTbar                   273.3              96.4                     90.0
# ZJets                   280.2             162.9                    152.7
# Multiboson               23.4              11.9                     10.8
# QCD                     340.4             109.4                    109.4
# TTX                       5.3               1.5                      1.5
# ZGamma                   13.0               7.9                      7.1
# WJets                   804.2             436.8                    414.7
# Total                 1,809.5             858.1                    815.8
#
#             Leading jet pT > 80 GeV  dPhi(MET,leading jet) > 1.5  \
# DY-M4to50                       2.2                          2.2
# DY-M50                         18.6                         18.5
# SingleTop                       8.9                          8.8
# TTbar                          88.7                         88.1
# ZJets                         150.6                        149.2
# Multiboson                     10.5                         10.2
# QCD                           109.4                        102.1
# TTX                             1.5                          1.5
# ZGamma                          7.1                          7.1
# WJets                         412.1                        408.2
# Total                         809.5                        795.8
#
#             dPhi(MET,all jets) > 0.75  Vtx CosCollinear < 0
# DY-M4to50                         1.1                   0.2
# DY-M50                           11.8                   4.6
# SingleTop                         4.6                   1.8
# TTbar                            55.2                  20.2
# ZJets                           102.0                  34.3
# Multiboson                        7.1                   2.0
# QCD                               0.0                   0.0
# TTX                              -0.1                   0.4
# ZGamma                            5.0                   1.0
# WJets                           256.4                  82.8
# Total                           443.1                 147.3

# %%
cmap = ["#3f90da", "#ffa90e", "#bd1f01", "#94a4a2", "#832db6", "#a96b59", "#e76300", "#b9ac70", "#717581", "#92dadd"] # cms-recommended
bkg_cmap = {
    "QCD": cmap[0],
    "WJets": cmap[1],
    "ZJets": cmap[2],
    "DY-M4to50": cmap[3],
    "DY-M50": cmap[4],
    "TTbar": cmap[5],
    "SingleTop": cmap[6],
    "Multiboson": cmap[7],
    "ZGamma": cmap[8],
    "TTX": cmap[9]
}

df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
processes = df.index.values.tolist()

cuts = utils.get_bkg_list_of_cuts(bkg_histo)
cuts[1] = 'N(Jets) > 2 && n(good vertex) > 0'
cuts[5] = 'b-jet Veto Loose WP'

# Color map for each process
for process in processes:
    if 'Total' in process:
        plt.plot(cuts, df.loc[process], label=process, color='black')
    else:
        plt.plot(cuts, df.loc[process], label=process, color = bkg_cmap[process])

# plot data
df_data = utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
plt.plot(cuts, df_data.loc['Total'], label='Data: Run2018[A-D]', color = 'blue', marker='o', linestyle='--')

if plot_dict_bkg_eff['doLog']:
    plt.yscale('log')

if plot_dict_bkg_eff['ylim'] != None:
    plt.ylim(plot_dict_bkg_eff['ylim'][0], plot_dict_bkg_eff['ylim'][1])
    
plt.grid()
    
plt.ylabel(plot_dict_bkg_eff['ylabel'])
plt.title(plot_dict_bkg_eff['title'])
    
plt.xticks(ticks = np.arange(len(cuts)), labels = cuts, rotation = 45, ha = 'right')
    
plt.legend(loc='upper right')
    
if plot_dict_bkg_eff['doSave']:
    os.makedirs(plot_dict_bkg_eff['outDir'], exist_ok=True)
    plt.tight_layout()
    plt.savefig(f"{plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    print(f"Saved: {plot_dict_bkg_eff['outDir']}/{plot_dict_bkg_eff['outName']}")
    
plt.show()
# Out:
# Saved: ./plots/VR_localHEMveto/cutflow//Cutflow_background.png
