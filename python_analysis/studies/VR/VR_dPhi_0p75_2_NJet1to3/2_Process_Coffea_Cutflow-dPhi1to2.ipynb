# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'
suffix = '_dPhi-1to2'

# %%
bkg_histo = util.load(f'{prefix}/background_VR{suffix}.coffea')[0]

# %%
data_histo = util.load(f'{prefix}/data_VR{suffix}.coffea')[0]

# %%
sig_histo = util.load(f'{prefix}/signal_VR{suffix}.coffea')[0]

# %%
utils.get_signal_list_of_cuts(sig_histo)
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  '1.0 < dPhi(MET,leading jet) < 2.0']

# %% [markdown]
# ### Efficiency

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100            0.17                0.06
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100             4.58                1.45
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10             3.48                1.74
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             44.39               16.54
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100            0.22                0.08
# ...                                                ...                 ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10          1,639.62              473.21
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1          22,398.72            5,648.46
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1           933.55              307.53
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100           3.61                1.20
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           73.17               34.11
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100               0.05
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                1.24
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                1.50
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                14.20
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100               0.07
# ...                                                   ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10               410.83
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              4,784.10
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1              259.40
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100              1.03
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10              29.29
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      0.05
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       1.22
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       1.46
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       13.81
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.06
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      399.08
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     4,676.14
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     252.65
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     1.00
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                     28.50
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      0.05
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       1.22
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       1.46
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       13.80
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.06
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                      399.08
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     4,676.14
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     252.65
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     1.00
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                     28.49
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                0.00
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                 0.00
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                 0.00
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                  0.00
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                0.00
# ...                                                                    ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                                  0.00
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                   0.00
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                 0.00
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                               0.00
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                0.00
#
# [62 rows x 6 columns]

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100            1.00                0.96
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100             1.00                0.96
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10             1.00                0.97
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1              1.00                0.97
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100            1.00                0.96
# ...                                                ...                 ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10              1.00                0.96
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1               1.00                0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1             1.00                0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100           1.00                0.96
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10            1.00                0.98
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100               0.96
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                0.96
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                0.97
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                 0.97
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100               0.97
# ...                                                   ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                 0.96
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100              0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10               0.98
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      0.96
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       0.96
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       0.97
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        0.97
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.97
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                        0.96
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                         0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                      0.98
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      0.96
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       0.96
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       0.97
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        0.97
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.97
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                        0.96
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                         0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     0.97
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                      0.98
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                 NaN
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                   NaN
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                 NaN
# ...                                                                    ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-10                                   NaN
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                    NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                  NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                 NaN
#
# [62 rows x 6 columns]

# %%
df_bkg = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
df_bkg
# Out:
#             Preselections  n(good vertex) > 0  No b-tagged jets  \
# DY               3,986.52               37.16             33.78
# WJets          170,013.29              933.60            703.97
# Top             16,299.76              113.37             71.46
# QCD             46,635.03              124.35             18.94
# ZJets           49,771.90              497.08            393.35
# Multiboson       4,489.25               27.65             16.86
# Total          291,195.76            1,733.21          1,238.36
#
#             Leading jet |eta| < 2.4  Leading jet pT > 80 GeV  \
# DY                            30.41                    30.41
# WJets                        674.36                   671.90
# Top                           66.05                    62.90
# QCD                           18.94                    18.94
# ZJets                        374.87                   372.49
# Multiboson                    15.03                    14.33
# Total                      1,179.65                 1,170.95
#
#             1.0 < dPhi(MET,leading jet) < 2.0
# DY                                       0.00
# WJets                                    2.28
# Top                                      0.00
# QCD                                      0.00
# ZJets                                    1.57
# Multiboson                               0.00
# Total                                    3.86

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose(), pd.DataFrame(bkg_cts_raw_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                   DY  WJets  Top  QCD  ZJets  Multiboson  Total
# Weighted Counts 0.00   2.28 0.00 0.00   1.57        0.00   3.86
# Raw Counts      0.00  33.00 0.00 0.00  49.00        0.00  82.00

# %%
pd.options.display.float_format = '{:,.1f}'.format

utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

ptools.plot_bkg_efficiency(bkg_histo, df, doLog = True, ylabel = 'Events', title = 'dPhi(j0, MET) VR: Background')

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:273: RuntimeWarning: divide by zero encountered in scalar divide
#   self.flat_scale(1 / np.sum(np.diff(self.edges) * self.values))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:244: RuntimeWarning: invalid value encountered in multiply
#   self.values *= scale
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:245: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_lo *= scale
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:246: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_hi *= scale

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
