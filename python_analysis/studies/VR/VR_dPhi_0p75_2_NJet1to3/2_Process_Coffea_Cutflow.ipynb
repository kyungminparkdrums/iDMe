# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'
suffix = '_dPhi'

# %%
bkg_histo = util.load(f'{prefix}/background_VR{suffix}.coffea')[0]

# %%
data_histo = util.load(f'{prefix}/data_VR{suffix}.coffea')[0]

# %%
sig_histo = util.load(f'{prefix}/signal_VR{suffix}.coffea')[0]

# %%
utils.get_signal_list_of_cuts(sig_histo)
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  '0.75 < dPhi(MET,leading jet) < 2.0']

# %% [markdown]
# ### Efficiency

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100        0.171096            0.059416
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100         4.581923            1.452994
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10         3.476254            1.740089
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.394714           16.543214
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100        0.221679            0.076160
# ...                                                ...                 ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       22398.718783         5648.464431
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.229723           12.762213
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       933.552910          307.530361
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100       3.613831            1.196793
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10       73.165001           34.114558
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           0.050973
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            1.244061
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            1.495184
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1            14.196744
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.065860
# ...                                                   ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1           4784.104301
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1           10.932443
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1          259.404304
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          1.029999
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10          29.293974
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.049288
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   1.217726
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   1.459105
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   13.810829
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.064047
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  4676.138000
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  10.627727
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 252.649296
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.001976
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                 28.498668
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.049274
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   1.217726
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   1.458806
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   13.798381
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.064047
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                  4676.138000
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  10.617352
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 252.649296
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.001757
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                 28.490567
#
#                                          0.75 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                  0.0
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                   0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                   0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                    0.0
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                  0.0
# ...                                                                     ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                     0.0
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                   0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                   0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                 0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                  0.0
#
# [62 rows x 6 columns]

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100             1.0            0.963286
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100              1.0            0.959164
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10              1.0            0.973158
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1               1.0            0.971596
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100             1.0            0.963760
# ...                                                ...                 ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                1.0            0.966724
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1              1.0            0.971587
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1              1.0            0.970482
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100            1.0            0.963415
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10             1.0            0.975499
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           0.963871
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.959009
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.973267
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.972490
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.965596
# ...                                                   ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              0.967577
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            0.973466
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            0.969877
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          0.965783
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.975058
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.964070
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.959765
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.973324
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.972171
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.966554
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     0.966828
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.973095
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   0.972415
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.965479
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.975214
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.964060
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.959765
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.973421
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.972146
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.966554
# ...                                                          ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     0.966828
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.973069
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   0.972415
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.965471
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.975301
#
#                                          0.75 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                  NaN
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                   NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                   NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                    NaN
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                  NaN
# ...                                                                     ...
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                     NaN
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                   NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                   NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                 NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                  NaN
#
# [62 rows x 6 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format

df_bkg = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
df_bkg
# Out:
#             Preselections  n(good vertex) > 0  No b-tagged jets  \
# DY               3,986.52               37.16             33.78
# QCD             46,635.03              124.35             18.94
# ZJets           49,771.90              497.08            393.35
# Top             16,299.76              113.37             71.46
# WJets          170,013.29              933.60            703.97
# Multiboson       4,489.25               27.65             16.86
# Total          291,195.76            1,733.21          1,238.36
#
#             Leading jet |eta| < 2.4  Leading jet pT > 80 GeV  \
# DY                            30.41                    30.41
# QCD                           18.94                    18.94
# ZJets                        374.87                   372.49
# Top                           66.05                    62.90
# WJets                        674.36                   671.90
# Multiboson                    15.03                    14.33
# Total                      1,179.65                 1,170.95
#
#             0.75 < dPhi(MET,leading jet) < 2.0
# DY                                        0.00
# QCD                                       0.00
# ZJets                                     1.60
# Top                                       0.00
# WJets                                     2.28
# Multiboson                                0.00
# Total                                     3.88

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['0.75 < dPhi(MET,leading jet) < 2.0']).transpose(), pd.DataFrame(bkg_cts_raw_df['0.75 < dPhi(MET,leading jet) < 2.0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                   DY  QCD  ZJets  Top  WJets  Multiboson  Total
# Weighted Counts 0.00 0.00   1.60 0.00   2.28        0.00   3.88
# Raw Counts      0.00 0.00  50.00 0.00  33.00        0.00  83.00

# %%
utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
# Out:
#                                   Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_Run2018D     307,259.00            2,496.00
# data_2018_Data_MET_UL18_Run2018B      61,151.00              506.00
# data_2018_Data_MET_UL18_Run2018C      69,359.00              623.00
# data_2018_Data_MET_UL18_Run2018A     118,155.00            1,020.00
#
#                                   No b-tagged jets  Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_Run2018D          1,356.00                   957.00
# data_2018_Data_MET_UL18_Run2018B            262.00                   164.00
# data_2018_Data_MET_UL18_Run2018C            340.00                   225.00
# data_2018_Data_MET_UL18_Run2018A            481.00                   294.00
#
#                                   Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_Run2018D                   948.00
# data_2018_Data_MET_UL18_Run2018B                   161.00
# data_2018_Data_MET_UL18_Run2018C                   223.00
# data_2018_Data_MET_UL18_Run2018A                   290.00
#
#                                   0.75 < dPhi(MET,leading jet) < 2.0
# data_2018_Data_MET_UL18_Run2018D                                3.00
# data_2018_Data_MET_UL18_Run2018B                                1.00
# data_2018_Data_MET_UL18_Run2018C                                2.00
# data_2018_Data_MET_UL18_Run2018A                                2.00

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

ptools.plot_bkg_efficiency(bkg_histo, df, doLog = True, ylabel = 'Events', title = 'dPhi(j0, MET) VR: Background')

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [1]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [1]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [10]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [10]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [100]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [100]

title = f'dPhi(j0, MET) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
