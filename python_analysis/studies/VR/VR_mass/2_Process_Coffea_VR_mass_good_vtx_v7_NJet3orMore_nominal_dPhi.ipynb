# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'
suffix = '_NJet3orMore_good_vtx_v7'

# %%
bkg_histo = util.load(f'{prefix}/background_VR{suffix}.coffea')[0]

# %%
data_histo = util.load(f'{prefix}/data_VR{suffix}.coffea')[0]

# %%
sig_histo = util.load(f'{prefix}/signal_VR{suffix}.coffea')[0]

# %%
utils.get_signal_list_of_cuts(sig_histo)
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  'dPhi(MET,leading jet) > 2.0',
#  'm(e,e) > 20']

# %% [markdown]
# ### Efficiency

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100         4.551906            0.017664
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100        0.169919            0.000524
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10         3.457686            0.023955
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.169096            0.253701
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100        0.220442            0.000906
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.024574            0.182300
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       22229.424481          112.759192
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.485665            4.432743
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100       3.593473            0.012042
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10       72.714810            0.436794
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.007673
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           0.000198
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.008838
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.105849
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.000412
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            0.072530
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             51.630029
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.477324
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          0.005475
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.172570
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.006337
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008688
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.101183
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000329
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.070447
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    46.945031
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.167175
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.006337
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008688
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.101183
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000329
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.070447
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    46.945031
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.164472
#
#                                          dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       0.006337
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      0.000184
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       0.008688
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        0.101183
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.000329
# ...                                                              ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                       0.070447
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                        46.945031
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                      0.164472
#
#                                          m(e,e) > 20
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100       0.000333
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100      0.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10       0.000150
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1        0.000000
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100      0.000000
# ...                                              ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       0.000000
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1         0.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       0.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     0.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10      0.000000
#
# [62 rows x 7 columns]

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100              1.0            0.924491
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100             1.0            0.945895
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10              1.0            0.943747
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1               1.0            0.950849
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100             1.0            0.863585
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1              1.0            0.943097
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                1.0            0.916325
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1              1.0            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100            1.0            0.963669
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10             1.0            0.969139
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.913099
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.949197
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.970554
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.799969
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            0.971386
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.968750
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.894775
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.948324
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.984576
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.750024
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.970539
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.967741
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.894775
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.948324
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.984576
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.750024
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.970539
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.983644
#
#                                          dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                       0.894775
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                      1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                       0.948324
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                        0.984576
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                      0.750024
# ...                                                              ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                       0.970539
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                         1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                       1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                      0.983644
#
#                                          m(e,e) > 20
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             NaN
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           NaN
# ...                                              ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            NaN
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           NaN
#
# [62 rows x 7 columns]

# %%
df_bkg = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
df_bkg
# Out:
#             Preselections  n(good vertex) > 0  No b-tagged jets  \
# ZGamma        1441.216675           11.035546          5.953043
# Top          16261.614716          205.287264         80.175157
# Multiboson    4362.918747           24.658398         12.195887
# QCD          46821.466983          350.243661        106.565089
# WJets       169626.376667          856.491571        468.338741
# ZJets        49609.778111          292.596769        170.104354
# DY            3992.005007           52.297009         27.891738
# Total       292115.376907         1792.610218        871.224010
#
#             Leading jet |eta| < 2.4  Leading jet pT > 80 GeV  \
# ZGamma                     5.085681                 5.085681
# Top                       76.570633                76.570633
# Multiboson                11.139229                10.640670
# QCD                      106.565089               106.565089
# WJets                    444.557495               442.933614
# ZJets                    159.938012               157.977269
# DY                        27.891738                27.891738
# Total                    831.747877               827.664694
#
#             dPhi(MET,leading jet) > 2.0  m(e,e) > 20
# ZGamma                         4.259759     0.082881
# Top                           76.496546    12.507544
# Multiboson                    10.140884     1.549722
# QCD                           99.137858     0.234273
# WJets                        429.417632    68.920900
# ZJets                        152.726343     6.930410
# DY                            27.891738    10.459402
# Total                        800.070760   100.685131

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['m(e,e) > 20']).transpose(), pd.DataFrame(bkg_cts_raw_df['m(e,e) > 20']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  ZGamma   Top  Multiboson  QCD  WJets  ZJets    DY  Total
# Weighted Counts    0.08 12.51        1.55 0.23  68.92   6.93 10.46 100.69
# Raw Counts         6.00 17.00       12.00 1.00 452.00 121.00  3.00 612.00

# %%
pd.options.display.float_format = '{:,.1f}'.format

utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
# Out:
#                                   Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_Run2018D      307,259.0             2,366.0
# data_2018_Data_MET_UL18_Run2018B       61,151.0               390.0
# data_2018_Data_MET_UL18_Run2018C       69,359.0               561.0
# data_2018_Data_MET_UL18_Run2018A      118,155.0               788.0
#
#                                   No b-tagged jets  Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_Run2018D             911.0                    791.0
# data_2018_Data_MET_UL18_Run2018B             156.0                    130.0
# data_2018_Data_MET_UL18_Run2018C             211.0                    181.0
# data_2018_Data_MET_UL18_Run2018A             267.0                    221.0
#
#                                   Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_Run2018D                    786.0
# data_2018_Data_MET_UL18_Run2018B                    128.0
# data_2018_Data_MET_UL18_Run2018C                    181.0
# data_2018_Data_MET_UL18_Run2018A                    219.0
#
#                                   dPhi(MET,leading jet) > 2.0  m(e,e) > 20
# data_2018_Data_MET_UL18_Run2018D                        764.0        150.0
# data_2018_Data_MET_UL18_Run2018B                        124.0         20.0
# data_2018_Data_MET_UL18_Run2018C                        175.0         44.0
# data_2018_Data_MET_UL18_Run2018A                        210.0         29.0

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

ptools.plot_bkg_efficiency(bkg_histo, df, doLog = True, ylabel = 'Events', title = 'Mass VR: Background')

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [1]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [1]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [10]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [10]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [100]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [100]

title = f'Mass VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 23
#       9 style_dict = {
#      10     'rebin': 1j,
#      11     'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
#    (...)
#      19     'flow': None,     # overflow
#      20 }
#      22 # bkg
# ---> 23 ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)
#      25 # signal points
#      26 m1s = [20]
#
# TypeError: plot_bkg_1d() got multiple values for argument 'isLegacy'

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After ISR Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After ISR Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [5, 10, 20, 30, 70, 90, 100]
deltas = [0.1]
ctaus = [1]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After Inverted Mass Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [5, 10, 20, 30, 70, 90, 100]
deltas = [0.2]
ctaus = [1]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After Inverted Mass Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [5, 10, 20, 30, 70, 90, 100]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After mass Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [5, 10, 20, 30, 70, 90, 100]
deltas = [0.1]
ctaus = [100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After mass Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)


plt.title('After mass Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 10j,
    'xlim': [20, 100],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


# signal points
m1s = [5, 10, 20, 30, 70, 90, 100]
deltas = [0.1]
ctaus = [1]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)


plt.title('After Inverted Mass Cut')
plt.legend()
plt.show()

# %% [markdown]
# ### Data and MC

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 20j,
    'xlim': [20, 50],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [0, 20],
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/1 GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_mass.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [1.5, 3],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [0,50],
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_dPhi_MET_leadingjet.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'MET_pt',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': [200, 300],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events/3 GeV',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_MET.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_NJet.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'nElectron',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': 'n(Electron)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': 'Events',   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_nElectron.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_vxy_zoom.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 5j,
    'xlim': [0,10],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_vxy.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_minDxy',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,1],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': 'min(|dxy(e1)|,|dxy(e2)|)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_minDxy.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxySignif',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 2j,
    'xlim': [0,120],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [1e-2, 5e+1],
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_vxy_signif.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()
#fig, ax = plt.subplots(1, 1, figsize=(5, 5))

# Plot settings
plot_dict = {
    'variable': 'cos_collinear',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [1e-2, 5e+3],
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_collinear.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_type',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [1e-2, 5e+3],
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_type.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_chi2',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': [0,9],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_chi2.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_dR',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': [0,30],
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_dR.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_sign_eta',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_eta_product_sign.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_METdPhi',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': 'dPhi(MET, vtx)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_dPhi_MET_vtx.png')

plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_pt',
    'cut': 'cut9',
}

style_dict = {
    'fig': fig,
    'ax': ax,
    'rebin': 3j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'ylim': None,
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
    'year': 2018
}

# bkg
ptools.plot_bkg_1d(bkg_histo, plot_dict, style_dict, isLegacy = False)

ptools.plot_data_1d(data_histo, plot_dict, style_dict)

plt.title('After Inverted Mass Cut')

plt.savefig('VR_mass20_vtx_pt.png')

plt.show()
