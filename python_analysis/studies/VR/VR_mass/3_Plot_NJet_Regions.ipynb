# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'

# %%
bkg_histo = util.load(f'{prefix}background_VR_noNJetCut_good_vtx_v7.coffea')[0]

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False)
'''
# signal points
m1s = [10, 90]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)
'''
plt.title('After Jet pT Cut: NJet [1,2] for All Backgrounds')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False)
'''
# signal points
m1s = [10, 90]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)
'''
plt.title('After Jet pT Cut: NJet [3,4] for All Backgrounds')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(fig, ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

'''
# signal points
m1s = [10, 90]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)
'''
plt.title('After Jet pT Cut: NJet [1,2] for W/ZJets')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])
'''
# signal points
m1s = [10, 90]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)
'''
plt.title('After Jet pT Cut: NJet [3,4] for W/ZJets')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': '|dPhi(leading jet, MET)|',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# signal points
m1 = 10
delta = 0.2
ctau = 1

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

fig, ax = plt.subplots()

# signal points
m1 = 50
delta = 0.1
ctau = 10

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

fig, ax = plt.subplots()

# signal points
m1 = 90
delta = 0.1
ctau = 100

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'MET_pt',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 3j,
    'xlim': [180, 400],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'MET',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# signal points
m1 = 10
delta = 0.2
ctau = 1

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

fig, ax = plt.subplots()

# signal points
m1 = 50
delta = 0.1
ctau = 10

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

fig, ax = plt.subplots()

# signal points
m1 = 90
delta = 0.1
ctau = 100

style_dict['label'] = 'NJet [1,2]'
ptools.plot_signal_1D(ax, sig_histo_lowNJet, m1, delta, ctau, plot_dict, style_dict)

style_dict['label'] = 'NJet [3,4]'
ptools.plot_signal_1D(ax, sig_histo_highNJet, m1, delta, ctau, plot_dict, style_dict)

plt.title(f'After Jet pT Cut: Signal m1 = {m1} GeV, delta = {delta}, ctau = {ctau}mm')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'n(Jets)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nGoodVtx',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'n(Good Vtx)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nElectron',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'n(Electron)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxy',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_minDxy',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 2j,
    'xlim': [0,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_vxySignif',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'cos_collinear',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 20j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_type',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_chi2',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,7],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_dR',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_sign_eta',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_METdPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 2j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'dPhi(MET, vtx)',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_pt',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 2j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': 'Vertex pT',   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'sel_vtx_mass',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 10j,
    'xlim': [0,25],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
style_dict['label'] = 'NJet [1,2]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_lowNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])

style_dict['label'] = 'NJet [3,4]'
ptools.plot_bkg_1d_stacked(ax, bkg_histo_highNJet, plot_dict, style_dict, isLegacy = False, processes=['WJets','ZJets'])


plt.title('After Jet pT Cut: W/ZJets')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
