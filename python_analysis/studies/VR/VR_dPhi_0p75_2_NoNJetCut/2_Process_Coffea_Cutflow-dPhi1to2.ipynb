# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'
suffix = '_dPhi-1to2_NJet3to4'

# %%
bkg_histo = util.load(f'{prefix}/background_VR{suffix}.coffea')[0]

# %%
data_histo = util.load(f'{prefix}/data_VR{suffix}.coffea')[0]

# %%
sig_histo = util.load(f'{prefix}/signal_VR{suffix}.coffea')[0]

# %%
utils.get_signal_list_of_cuts(sig_histo)
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  '1.0 < dPhi(MET,leading jet) < 2.0']

# %% [markdown]
# ### Efficiency

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100        0.171096            0.000496
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100         4.581923            0.015995
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10         3.476254            0.022606
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.394714            0.177395
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100        0.221679            0.000783
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.229723            0.126400
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       22398.718783           98.642425
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       933.552910            3.376123
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100       3.613831            0.012042
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10       73.165001            0.399041
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           0.000198
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.006673
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.008239
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.082490
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.000371
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            0.051790
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             42.224691
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.477324
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          0.005475
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.153719
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.005336
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008090
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.079381
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000288
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.051790
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    37.539692
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.148323
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.005336
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008090
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.079381
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000288
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   0.051790
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    37.539692
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.145621
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                 0.0
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                  0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                  0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                   0.0
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                 0.0
# ...                                                                    ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                  0.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                    0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                  0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                 0.0
#
# [62 rows x 6 columns]

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100             1.0            0.942796
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100              1.0            0.958292
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10              1.0            0.966878
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1               1.0            0.964890
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100             1.0            0.947380
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1              1.0            0.967147
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                1.0            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1              1.0            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100            1.0            0.963669
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10             1.0            0.979742
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.950024
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.981081
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.888854
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1            1.000000
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.982417
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.937511
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.980340
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.857139
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   1.000000
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.981777
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.937511
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   1.000000
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.980340
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.857139
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                   1.000000
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  1.000000
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                 NaN
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                   NaN
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                 NaN
# ...                                                                    ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                                  NaN
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                    NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                  NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                 NaN
#
# [62 rows x 6 columns]

# %%
df_bkg = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
df_bkg
# Out:
#             Preselections  n(good vertex) > 0  No b-tagged jets  \
# ZGamma           0.045482            0.000102          0.000025
# QCD          46635.033957          158.399462         55.043823
# DY            3986.522297           16.892044         10.135226
# WJets       170013.294072          359.321738        201.021545
# ZJets        49771.904314          152.749765         92.570621
# Multiboson    4489.247271           11.410078          5.638927
# Top          16299.756491           74.135889         33.306002
# Total       291195.803884          772.909077        397.716170
#
#             Leading jet |eta| < 2.4  Leading jet pT > 80 GeV  \
# ZGamma                     0.000011                 0.000011
# QCD                       55.043823                55.043823
# DY                        10.135226                10.135226
# WJets                    190.654577               190.304988
# ZJets                     86.984753                85.456190
# Multiboson                 5.080829                 4.789866
# Top                       32.614447                32.614447
# Total                    380.513666               378.344551
#
#             1.0 < dPhi(MET,leading jet) < 2.0
# ZGamma                               0.000000
# QCD                                  0.000000
# DY                                   0.000000
# WJets                                2.816332
# ZJets                                1.537267
# Multiboson                           0.222017
# Top                                  0.000000
# Total                                4.575616

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose(), pd.DataFrame(bkg_cts_raw_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                  ZGamma  QCD   DY  WJets  ZJets  Multiboson  Top  Total
# Weighted Counts    0.00 0.00 0.00   2.82   1.54        0.22 0.00   4.58
# Raw Counts         0.00 0.00 0.00  40.00  52.00        2.00 0.00  94.00

# %%
pd.options.display.float_format = '{:,.1f}'.format

utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
# Out:
#                                   Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_Run2018D      307,259.0               864.0
# data_2018_Data_MET_UL18_Run2018B       61,151.0               151.0
# data_2018_Data_MET_UL18_Run2018C       69,359.0               221.0
# data_2018_Data_MET_UL18_Run2018A      118,155.0               338.0
#
#                                   No b-tagged jets  Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_Run2018D             347.0                    291.0
# data_2018_Data_MET_UL18_Run2018B              54.0                     45.0
# data_2018_Data_MET_UL18_Run2018C              86.0                     71.0
# data_2018_Data_MET_UL18_Run2018A             117.0                     93.0
#
#                                   Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_Run2018D                    288.0
# data_2018_Data_MET_UL18_Run2018B                     44.0
# data_2018_Data_MET_UL18_Run2018C                     71.0
# data_2018_Data_MET_UL18_Run2018A                     91.0
#
#                                   1.0 < dPhi(MET,leading jet) < 2.0
# data_2018_Data_MET_UL18_Run2018D                                3.0
# data_2018_Data_MET_UL18_Run2018B                                1.0
# data_2018_Data_MET_UL18_Run2018C                                3.0
# data_2018_Data_MET_UL18_Run2018A                                2.0

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

ptools.plot_bkg_efficiency(bkg_histo, df, doLog = True, ylabel = 'Events', title = 'dPhi(j0, MET) VR: Background')

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
