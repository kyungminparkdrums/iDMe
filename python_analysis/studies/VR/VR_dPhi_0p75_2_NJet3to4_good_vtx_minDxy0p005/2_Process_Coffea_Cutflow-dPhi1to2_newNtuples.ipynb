# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import sys
sys.path.append("../../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import plotTools as ptools
import utils
import importlib
import coffea.util as util
import time
import json
import os
import glob
import pandas as pd
import mplhep as hep

# %% [markdown]
# ### Import coffea files

# %%
prefix = './coffea/'
suffix = '_dPhi-1to2_good_vtx_minDxy_0p005'

# %%
bkg_histo = util.load(f'{prefix}/background_VR{suffix}_newNtuples.coffea')[0]

# %%
data_histo = util.load(f'{prefix}/data_VR{suffix}.coffea')[0]

# %%
sig_histo = util.load(f'{prefix}/signal_VR{suffix}_newNtuples.coffea')[0]

# %%
utils.get_signal_list_of_cuts(sig_histo)
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'No b-tagged jets',
#  'Leading jet |eta| < 2.4',
#  'Leading jet pT > 80 GeV',
#  '1.0 < dPhi(MET,leading jet) < 2.0']

# %% [markdown]
# ### Efficiency

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100        0.169919            0.000496
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100         4.551906            0.017330
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10         3.457686            0.023505
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.169096            0.244365
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100        0.220442            0.000906
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10        2.737597            0.016166
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       22229.424481          108.047744
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.485665            4.220569
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100       3.593473            0.012042
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10       72.714810            0.428693
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           0.000198
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.007340
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.008688
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.102739
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.000412
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10           0.006984
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1             51.630029
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.477324
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          0.005475
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.169877
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.006004
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008539
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.098074
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000329
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                  0.006582
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    46.945031
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.164482
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  0.000184
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.006004
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.008539
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.098074
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.000329
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                  0.006582
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                    46.945031
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.265150
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 0.004819
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.161779
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                 0.0
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                  0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                  0.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                   0.0
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                 0.0
# ...                                                                    ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                                 0.0
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                    0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                  0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                0.0
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                 0.0
#
# [62 rows x 6 columns]

# %%
df_signal = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')
df_signal
# Out:
#                                          Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100             1.0            0.942796
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100              1.0            0.942273
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10              1.0            0.949049
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1               1.0            0.955363
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100             1.0            0.863585
# ...                                                ...                 ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10             1.0            0.950655
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                1.0            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1              1.0            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100            1.0            0.963669
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10             1.0            0.974869
#
#                                          No b-tagged jets  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100           1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100            0.954566
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10            0.965571
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1             0.969662
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100           0.799969
# ...                                                   ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10           0.942961
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1              1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1            1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100          1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10           0.968254
#
#                                          Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.944455
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.964970
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.984087
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.750024
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                  0.939478
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.967213
#
#                                          Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                  1.000000
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                   0.944455
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                   0.964970
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                    0.984087
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                  0.750024
# ...                                                          ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                  0.939478
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                 1.000000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                  0.983372
#
#                                          1.0 < dPhi(MET,leading jet) < 2.0
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-100                                 NaN
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-100                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-10                                  NaN
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                                   NaN
# sig_2018_Mchi-88p0_dMchi-16p0_ctau-100                                 NaN
# ...                                                                    ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10                                 NaN
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                                    NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                                  NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100                                NaN
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10                                 NaN
#
# [62 rows x 6 columns]

# %%
df_bkg = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
df_bkg
# Out:
#             Preselections  n(good vertex) > 0  No b-tagged jets  \
# DY            3992.005007           34.864673         17.432336
# ZJets        49609.778111          245.651203        147.885935
# ZGamma        1441.216675            9.204126          5.016084
# Top          16261.614716          115.415242         52.993821
# WJets       169626.376667          613.073561        355.456463
# QCD          46821.466983          234.081717         75.780889
# Multiboson    4362.918747           17.089268          8.963972
# Total       292115.376907         1269.379790        663.529501
#
#             Leading jet |eta| < 2.4  Leading jet pT > 80 GeV  \
# DY                        17.432336                17.432336
# ZJets                    138.295408               136.730792
# ZGamma                     4.162535                 4.162535
# Top                       49.470672                49.470672
# WJets                    336.548998               335.410820
# QCD                       75.780889                75.780889
# Multiboson                 8.405874                 7.907315
# Total                    630.096712               626.895359
#
#             1.0 < dPhi(MET,leading jet) < 2.0
# DY                                   0.000000
# ZJets                                2.912143
# ZGamma                               0.000000
# Top                                  0.000000
# WJets                                6.175185
# QCD                                  0.000000
# Multiboson                           0.487222
# Total                                9.574550

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose(), pd.DataFrame(bkg_cts_raw_df['1.0 < dPhi(MET,leading jet) < 2.0']).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                   DY  ZJets  ZGamma  Top  WJets  QCD  Multiboson  Total
# Weighted Counts 0.00   2.91    0.00 0.00   6.18 0.00        0.49   9.57
# Raw Counts      0.00  90.00    0.00 0.00  66.00 0.00        4.00 160.00

# %%
pd.options.display.float_format = '{:,.1f}'.format

utils.get_data_cutflow_dict(data_histo, 'cutflow_cts')
# Out:
#                                   Preselections  n(good vertex) > 0  \
# data_2018_Data_MET_UL18_Run2018D      307,259.0             1,671.0
# data_2018_Data_MET_UL18_Run2018B       61,151.0               283.0
# data_2018_Data_MET_UL18_Run2018C       69,359.0               388.0
# data_2018_Data_MET_UL18_Run2018A      118,155.0               591.0
#
#                                   No b-tagged jets  Leading jet |eta| < 2.4  \
# data_2018_Data_MET_UL18_Run2018D             663.0                    563.0
# data_2018_Data_MET_UL18_Run2018B             116.0                     96.0
# data_2018_Data_MET_UL18_Run2018C             137.0                    112.0
# data_2018_Data_MET_UL18_Run2018A             211.0                    170.0
#
#                                   Leading jet pT > 80 GeV  \
# data_2018_Data_MET_UL18_Run2018D                    560.0
# data_2018_Data_MET_UL18_Run2018B                     94.0
# data_2018_Data_MET_UL18_Run2018C                    112.0
# data_2018_Data_MET_UL18_Run2018A                    168.0
#
#                                   1.0 < dPhi(MET,leading jet) < 2.0
# data_2018_Data_MET_UL18_Run2018D                                7.0
# data_2018_Data_MET_UL18_Run2018B                                1.0
# data_2018_Data_MET_UL18_Run2018C                                3.0
# data_2018_Data_MET_UL18_Run2018A                                4.0

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

ptools.plot_bkg_efficiency(bkg_histo, df, doLog = True, ylabel = 'Events', title = 'dPhi(j0, MET) VR: Background')

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [1]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [10]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.1]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

m1s = [5, 10, 20, 30, 40, 50, 70, 80, 90, 100]
deltas = [0.2]
ctaus = [100]

title = f'Cos(collinear) VR: delta = {deltas[0]}, ctau = {ctaus[0]}mm'
ptools.plot_signal_efficiency(sig_histo, df, m1s, deltas, ctaus, doLog = True, ylabel = 'Events', title = title)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut7',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

# signal points
m1s = [20]
deltas = [0.1]
ctaus = [10]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After ISR Cut')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [0,6],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)


plt.title('After ISR Cut')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy = False)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'lead_jet_met_dPhi',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': [1,2],     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets', 'Multiboson'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut8',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': False,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': 'Run2018[A-D]',    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# bkg
ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, processes = ['WJets', 'ZJets', 'Multiboson'], isLegacy = False)

ptools.plot_data_1d(ax, data_histo, plot_dict, style_dict)

plt.title('After VR ISR Cuts')
plt.legend()
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
