# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os, sys
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
from pathlib import Path
import mplhep

sys.path.append("../../analysisTools/")
import utils
import plotTools as ptools

# %% [markdown]
# # Plot 1D

# %%
prefix = './coffea/'
suffix = '_NJet_NoCut'

# %%
sig_histo = util.load(f'{prefix}/signal{suffix}.coffea')[0]
bkg_histo = util.load(f'{prefix}/background{suffix}.coffea')[0]

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'bdt_score',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# signal points
m1s = [5, 100]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('ISR Cut')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 31
#      29     for delta in deltas:
#      30         for ctau in ctaus:
# ---> 31             ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)
#      33 plt.title('ISR Cut')
#      34 plt.legend()
#
# File /uscms_data/d3/kyungmip/CMSSW_10_6_26/src/iDMe/python_analysis/studies/NJet/../../analysisTools/plotTools.py:296, in plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)
#     293     label = style_dict['label']
#     295 # get histogram from coffea output
# --> 296 histo = sig_histo[plot_dict['variable']][{"samp":samp, "cut": plot_dict['cut']}]
#     298 # rebinning
#     299 histo = histo[::style_dict['rebin']]
#
# KeyError: 'bdt_score'

# %%
fig, ax = plt.subplots()

# bkg
utils.plot_bkg_1d(ax, bkg_histos, plot_dict, style_dict)

plt.title('Before BDT Cut')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 4
#       1 fig, ax = plt.subplots()
#       3 # bkg
# ----> 4 utils.plot_bkg_1d(ax, bkg_histos, plot_dict, style_dict)
#       6 plt.title('Before BDT Cut')
#
# AttributeError: module 'utils' has no attribute 'plot_bkg_1d'

# %%
fig, ax = plt.subplots()

# Plot settings
plot_dict = {
    'variable': 'bdt_score',
    'cut': 'cut10',
}

style_dict = {
    'rebin': 10j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': True, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# signal points
m1s = [5, 100]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            utils.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title('True Vertex; After BDT Cut')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 31
#      29     for delta in deltas:
#      30         for ctau in ctaus:
# ---> 31             utils.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)
#      33 plt.title('True Vertex; After BDT Cut')
#      34 plt.legend()
#
# AttributeError: module 'utils' has no attribute 'plot_signal_1D'

# %%
fig, ax = plt.subplots()

# bkg
utils.plot_bkg_1d(ax, bkg_histos, plot_dict, style_dict)

plt.title('After BDT Cut')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 4
#       1 fig, ax = plt.subplots()
#       3 # bkg
# ----> 4 utils.plot_bkg_1d(ax, bkg_histos, plot_dict, style_dict)
#       6 plt.title('After BDT Cut')
#
# AttributeError: module 'utils' has no attribute 'plot_bkg_1d'

# %% [markdown]
# ### nJets

# %%
fig, ax = plt.subplots()

title = 'Preselection' 

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut4',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# signal points
m1s = [5, 10, 90, 100]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title(title)
plt.legend()
plt.show()


# BKG
fig, ax = plt.subplots()

ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy=False)

plt.title(title)
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))

# %%
fig, ax = plt.subplots()

title = 'ISR Cuts' 

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# signal points
m1s = [5, 10, 90, 100]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title(title)
plt.legend()
plt.show()


# BKG
fig, ax = plt.subplots()

ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy=False)

plt.title(title)
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)

# %%
fig, ax = plt.subplots()

title = 'BDT Cut' 

# Plot settings
plot_dict = {
    'variable': 'nJets',
    'cut': 'cut9',
}

style_dict = {
    'rebin': 1j,
    'xlim': None,     # if None, the default will show up; otherwise give as a list, i.e. [0, 10]
    'doLogy': False, 
    'doLogx': False,
    'doDensity': True,
    'doYerr': False, 
    'xlabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Electron dxy'
    'ylabel': None,   # if None, the default will show up; otherwise give as a string, i.e. 'Efficiency'
    'label': None,    # if None, the default will show up; otherwise give as a string, i.e. 'Highest ctau signal samples'
    'flow': None,     # overflow
}

# signal points
m1s = [5, 10, 90, 100]
deltas = [0.1]
ctaus = [1, 100]

# Plot for variables signal points
for m1 in m1s:
    for delta in deltas:
        for ctau in ctaus:
            ptools.plot_signal_1D(ax, sig_histo, m1, delta, ctau, plot_dict, style_dict)

plt.title(title)
plt.legend()
plt.show()


# BKG
fig, ax = plt.subplots()

ptools.plot_bkg_1d(ax, bkg_histo, plot_dict, style_dict, isLegacy=False)

plt.title(title)
plt.show()
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/mplhep/utils.py:199: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   return np.abs(method_fcn(self.values, variances) - self.values)

# %% [markdown]
# ### SoverB Scan from Histogram

# %%
sig_samples = utils.get_signal_point_dict(sig_histo)
sig_samples = list(sig_samples.name)
sig_samples
# Out:
# ['sig_2018_Mchi-99p0_dMchi-18p0_ctau-100',
#  'sig_2018_Mchi-94p5_dMchi-9p0_ctau-100',
#  'sig_2018_Mchi-99p0_dMchi-18p0_ctau-10',
#  'sig_2018_Mchi-99p0_dMchi-18p0_ctau-1',
#  'sig_2018_Mchi-88p0_dMchi-16p0_ctau-100',
#  'sig_2018_Mchi-88p0_dMchi-16p0_ctau-10',
#  'sig_2018_Mchi-94p5_dMchi-9p0_ctau-10',
#  'sig_2018_Mchi-84p0_dMchi-8p0_ctau-100',
#  'sig_2018_Mchi-94p5_dMchi-9p0_ctau-1',
#  'sig_2018_Mchi-84p0_dMchi-8p0_ctau-10',
#  'sig_2018_Mchi-77p0_dMchi-14p0_ctau-100',
#  'sig_2018_Mchi-84p0_dMchi-8p0_ctau-1',
#  'sig_2018_Mchi-77p0_dMchi-14p0_ctau-10',
#  'sig_2018_Mchi-77p0_dMchi-14p0_ctau-1',
#  'sig_2018_Mchi-73p5_dMchi-7p0_ctau-100',
#  'sig_2018_Mchi-73p5_dMchi-7p0_ctau-10',
#  'sig_2018_Mchi-73p5_dMchi-7p0_ctau-1',
#  'sig_2018_Mchi-63p0_dMchi-6p0_ctau-100',
#  'sig_2018_Mchi-63p0_dMchi-6p0_ctau-10',
#  'sig_2018_Mchi-5p5_dMchi-1p0_ctau-100',
#  'sig_2018_Mchi-5p5_dMchi-1p0_ctau-10',
#  'sig_2018_Mchi-5p5_dMchi-1p0_ctau-1',
#  'sig_2018_Mchi-63p0_dMchi-6p0_ctau-1',
# ...

# %%
def s_over_b(cut, hname = 'nJets', rebin = 1j):
    s_over_b = {}
    s = {}
    
    processes = list(set(utils.get_bkg_point_dict(bkg_histo).loc[:, 'Process']))
    subprocess = {process: [] for process in processes} # initialize the dictionary of bkg processes
        
    availSubCat = list(bkg_histo[hname].axes['samp']) # get the list of subprocesses available for the histogram
    for samp in availSubCat:
        process = utils.get_bkg_point_dict(bkg_histo).loc[samp][0]            
        if process in processes:
            subprocess[process].append(samp) # fill out the bkg process list with the available subprocesses
        #print(subprocess[process])
            
    # Get histogram for each process
    bkg={}
    bkg[hname] = {process:bkg_histo[hname][{"samp":subprocess[process]}][{"samp": sum}] for process in processes}
        
    # sort the histograms by the entries and stack
    for process in processes:
        entries = {process: bkg[hname][process].sum().value for process in processes}
        
    sorted_entries = dict(sorted(entries.items(), key=lambda x:x[1], reverse = False))
    
    # histogram
    bkg_stack = {}
        
    # add histos to stack after rebinning and range setting
    for process in sorted_entries.keys():
        bkg[hname][process] = bkg[hname][process][cut, ::rebin]
        
        bkg_stack[process] = bkg[hname][process]
        #print(bkg[hname][process])

    bkgs = [bkg_stack[process] for process in bkg_stack.keys()]
    #print(bkgs)
    bkg_total = sum(bkgs)
    #print(bkg_total[0:3])
    
    # Count b
    b = []

    bins = bkg[hname][process].axes.edges[0][1:]

    for idx, bin_edge in enumerate(bins):
        #print(idx)
        if idx == 0:
            continue
        else:
            integral = bkg_total[0:idx].sum().value
            #print(integral)
            #b.append(bkg_total.sum(flow=True).value - integral) # apply cut of: var > cutvalue
            b.append(integral) # apply cut of: var < cutvalue
    
    b = np.array(b)
    #print(b)
    
    
    for point in sig_samples:
        # sig
        sig_hist = sig_histo[hname][{"samp":point,"cut":cut}][0:hist.overflow][::rebin]
        #print(sig_hist)
        bins = sig_hist.axes[0].edges[1:]
        
        s[point] = []
        for idx, bin_edge in enumerate(bins):
            if idx == 0:
                continue
            else:
                integral = sig_hist[0:idx].sum().value
                #s[point].append(sig_hist.sum(flow=True).value - integral) # apply cut of: var > cutvalue
                s[point].append(integral) # apply cut of: var < cutvalue

        s[point] = np.array(s[point])
        
        s_over_b[point] = list(s[point]/np.sqrt(b))

    return s_over_b
        #if 'sig_2018_Mchi-5p25_dMchi-0p5_ctau-1' in point:
        #    print(point)
        #    print(s[point])

# %%
s_over_b('cut4')
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
# {'sig_2018_Mchi-99p0_dMchi-18p0_ctau-100': [nan,
#   0.0022278064373933482,
#   0.001653126533710157,
#   0.001427181818939256,
#   0.001315033232043837,
#   0.0012771171875972879,
#   0.00126657307125638],
#  'sig_2018_Mchi-94p5_dMchi-9p0_ctau-100': [nan,
#   0.05452193074253828,
#   0.04029745543450601,
#   0.03490099359135056,
#   0.032142376691967824,
#   0.03120073225104305,
#   0.030943133219433854],
#  'sig_2018_Mchi-99p0_dMchi-18p0_ctau-10': [nan,
#   0.06498745932618058,
#   0.04820920183175507,
#   0.04179703294521196,
#   0.038529740931589736,
#   0.0374073935400758,
# ...

# %%
s_over_b('cut9')
# Out:
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
# {'sig_2018_Mchi-99p0_dMchi-18p0_ctau-100': [nan,
#   0.0020866789608865017,
#   0.0016698442871300161,
#   0.0015357701203512896,
#   0.0014992705380267278,
#   0.0014895177155794998,
#   0.001488280829892753],
#  'sig_2018_Mchi-94p5_dMchi-9p0_ctau-100': [nan,
#   0.05187360584196561,
#   0.04121179985520767,
#   0.037888883663161115,
#   0.036966988067746134,
#   0.03672651614364093,
#   0.03669601868686885],
#  'sig_2018_Mchi-99p0_dMchi-18p0_ctau-10': [nan,
#   0.061795188752153604,
#   0.049327872970237746,
#   0.045454382243853654,
#   0.04436679255146806,
#   0.044078184565562485,
#   0.04404158233182153],
#  'sig_2018_Mchi-99p0_dMchi-18p0_ctau-1': [nan,
#   0.586062882620746,
#   0.4668185643624246,
#   0.4299836438294613,
#   0.4195214715767518,
#   0.4168399412746353,
#   0.41649380013671244],
# ...

# %%
def dict_to_sorted_df(dict, m1=None, delta=None, ctau=None, to_list = False):
    df = pd.DataFrame.from_dict(dict, orient='index')
    df.pop(0)
    
    m1_list = []
    delta_list = []
    ctau_list = []
    
    for point in df.index.values:
        sig_dict = ptools.signalPoint(point)
        m1_list.append(sig_dict['m1'])
        delta_list.append(sig_dict['delta'])
        ctau_list.append(sig_dict['ctau'])
    
    df['m1'] = m1_list
    df['delta'] = delta_list
    df['ctau'] = ctau_list
    
    df = df.sort_values(by=['m1']) # sort by m1

    if (m1 != None) and (delta != None) and (ctau != None):
        df = df[ (df.m1 == m1) & (df.ctau == ctau) & (df.delta == delta) ]

        if to_list:
            df.pop('m1')
            df.pop('delta')
            df.pop('ctau')
            
            df = list(df.iloc[0])
    
    return df

# %%
dict_to_sorted_df(s_over_b('cut4'), 50, 0.1, 10, to_list = True)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
# [5.399349887938308,
#  4.007594282281868,
#  3.4554424791602503,
#  3.182093628441509,
#  3.088870877540426,
#  3.0633685867474383]

# %%
dict_to_sorted_df(s_over_b('cut9'), 50, 0.1, 10, to_list = True)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
# [5.072736101556574,
#  4.066740426918698,
#  3.7354180944356323,
#  3.6445295499509647,
#  3.620821720908229,
#  3.6178150144326966]

# %%
dict_to_sorted_df(s_over_b('cut10'), 50, 0.1, 10, to_list = True)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
# [24.527531087234895,
#  21.32201694120407,
#  19.797825104142742,
#  18.788318152418963,
#  18.788318152418963,
#  18.788318152418963]

# %%
m1s = [5, 10, 20, 40, 50, 90, 100]
ctaus = [1, 10, 100]
deltas = [0.1, 0.2]

# %%
from matplotlib.lines import Line2D

df = s_over_b('cut9')

for delta in deltas:
    fig,axes = plt.subplots(1,3,figsize=(18,4))
    
    massColors = {m1s[i]:f"C{i}" for i in range(len(m1s))}
    lines = [Line2D([0], [0], label=f"$M_1 = {m}$ GeV", color=massColors[m]) for m in sorted(list(massColors.keys()))]
    
    for idx, ctau in enumerate(ctaus):
        for m1 in m1s:
            point = f'm1_{m1}_delta_{delta}_ctau_{ctau}'

            y = dict_to_sorted_df(df, m1, delta, ctau, to_list = True)
            axes[idx].plot([i+1 for i in range(len(y))], y, color=massColors[m1])

            axes[idx].grid()
            
        axes[idx].set_title(f'delta = {delta}, ctau = {ctau} mm')
        axes[idx].set_xlabel('NJet Cut Value')
        axes[idx].set_ylabel('Significance; S/sqrt(B)')

        #axes[idx].set_xlim([0.5,1]) 
    
    legend_ax = fig.add_axes([0, 0, 0.05, 1])  # Adjust the values as needed
    legend_ax.axis('off')
    legend_ax.legend(handles=lines,loc='center',frameon=False)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))

# %%
from matplotlib.lines import Line2D

df = s_over_b('cut10')

for delta in deltas:
    fig,axes = plt.subplots(1,3,figsize=(18,4))
    
    massColors = {m1s[i]:f"C{i}" for i in range(len(m1s))}
    lines = [Line2D([0], [0], label=f"$M_1 = {m}$ GeV (Full data)", color=massColors[m]) for m in sorted(list(massColors.keys()))]
    
    for idx, ctau in enumerate(ctaus):
        for m1 in m1s:
            point = f'm1_{m1}_delta_{delta}_ctau_{ctau}'

            y = dict_to_sorted_df(df, m1, delta, ctau, to_list = True)
            axes[idx].plot([i+1 for i in range(len(y))], y, label='Training + Test Set', color=massColors[m1])

            axes[idx].grid()
            
        axes[idx].set_title(f'delta = {delta}, ctau = {ctau} mm')
        axes[idx].set_xlabel('NJet Cut Value')
        axes[idx].set_ylabel('Significance; S/sqrt(B)')

        #axes[idx].set_xlim([0.5,1]) 
    
    legend_ax = fig.add_axes([0, 0, 0.05, 1])  # Adjust the values as needed
    legend_ax.axis('off')
    legend_ax.legend(handles=lines,loc='center',frameon=False)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))

# %%
from matplotlib.lines import Line2D

df = s_over_b('cut4')

for delta in deltas:
    fig,axes = plt.subplots(1,3,figsize=(18,4))
    
    massColors = {m1s[i]:f"C{i}" for i in range(len(m1s))}
    lines = [Line2D([0], [0], label=f"$M_1 = {m}$ GeV (Full data)", color=massColors[m]) for m in sorted(list(massColors.keys()))]
    
    for idx, ctau in enumerate(ctaus):
        for m1 in m1s:
            point = f'm1_{m1}_delta_{delta}_ctau_{ctau}'

            y = dict_to_sorted_df(df, m1, delta, ctau, to_list = True)
            axes[idx].plot([i+1 for i in range(len(y))], y, label='Training + Test Set', color=massColors[m1])

            axes[idx].grid()
            
        axes[idx].set_title(f'delta = {delta}, ctau = {ctau} mm')
        axes[idx].set_xlabel('NJet Cut Value')
        axes[idx].set_ylabel('Significance; S/sqrt(B)')

        #axes[idx].set_xlim([0.5,1]) 
    
    legend_ax = fig.add_axes([0, 0, 0.05, 1])  # Adjust the values as needed
    legend_ax.axis('off')
    legend_ax.legend(handles=lines,loc='center',frameon=False)
# Out:
# /uscms/home/kyungmip/nobackup/miniconda3/envs/coffea/lib/python3.8/site-packages/hist/basehist.py:324: UserWarning: List indexing selection is experimental. Removed bins are not placed in overflow.
#   return super().__getitem__(self._index_transform(index))
# /tmp/ipykernel_1676827/210267673.py:76: RuntimeWarning: invalid value encountered in divide
#   s_over_b[point] = list(s[point]/np.sqrt(b))
