# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

import sys
sys.path.append("../../analysisTools/")
from analysisTools import Analyzer
from analysisTools import loadSchema
import analysisTools as tools
import analysisSubroutines as routines
import importlib
import coffea.util as util

import time
import json
import os
import glob

# %% [markdown]
# ## Run coffea on skimmed ntuples

# %%
cuts_config = "./configs/cut_configs/SR_uptoISRcut.py"
histos_config = "./configs/histo_configs/collinearity.py"

# %%
# BDT 
model_config = "./configs/models/BDT_inclusive_10Vars.json"

# %%
outdir = "./coffea/skimmed/"
os.makedirs(outdir, exist_ok=True)

# %% [markdown]
# ### Signal

# %%
sample_config = "./configs/sample_configs/skimmed_signal_v9_miniAOD_2018_aEM_noNJetCut.json"
#sample_config = "./configs/sample_configs/signal_v9_miniAOD_2018_aEM.json"

# %%
outname = 'SR_uptoISRcut_good_vtx_v7'

# %%
#analyzer = Analyzer(sample_config, histos_config, cuts_config, model_config) # If using BDT in cuts
analyzer = Analyzer(sample_config, histos_config, cuts_config) # If not using BDT in cuts

t1 = time.time()
out = analyzer.process(execr='futures')
t2 = time.time()

print("Runtime: {:.2f} minutes".format((t2-t1)/60))

util.save(out,f"{outdir}/signal_{outname}.coffea")

del out, analyzer
# Out:
# Output()
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-99p0_dMchi-18p0_ct-10/', 'Mchi': 99.0, 'dMchi': 18.0, 'ctau': 10, 'name': 'sig_Mchi-99.0_dMchi-18.0_ct-10', 'sum_wgt': 0.00044341007014736533, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1.2832037219699999, 'nFiles': 1, 'num_events': 512836, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-99p0_dMchi-18p0_ct-100/', 'Mchi': 99.0, 'dMchi': 18.0, 'ctau': 100, 'name': 'sig_Mchi-99.0_dMchi-18.0_ct-100', 'sum_wgt': 0.0004687276668846607, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.128330742145, 'nFiles': 1, 'num_events': 542086, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-94p5_dMchi-9p0_ct-100/', 'Mchi': 94.5, 'dMchi': 9.0, 'ctau': 100, 'name': 'sig_Mchi-94.5_dMchi-9.0_ct-100', 'sum_wgt': 2.3209549908642657e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 4.11064372769, 'nFiles': 1, 'num_events': 737991, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
#
#
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-99p0_dMchi-18p0_ct-1/', 'Mchi': 99.0, 'dMchi': 18.0, 'ctau': 1, 'name': 'sig_Mchi-99.0_dMchi-18.0_ct-1', 'sum_wgt': 0.0004265395109541714, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 12.826816255499999, 'nFiles': 1, 'num_events': 493206, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [7689, 7648, 8884, 493, 340, 3910, 6038, ... 4994, 1926, 5746, 7113, 5167, 2520]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-94p5_dMchi-9p0_ct-10/', 'Mchi': 94.5, 'dMchi': 9.0, 'ctau': 10, 'name': 'sig_Mchi-94.5_dMchi-9.0_ct-10', 'sum_wgt': 2.6445684852660634e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 40.9764776876, 'nFiles': 1, 'num_events': 841003, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# good_vtx definition v7
# Cos(collinear) [-1, -0.95] event #:  [6199, 1006, 2151, 4191, 9183, 3941, 1154, ... 6519, 1395, 3816, 5174, 2988, 658]
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1486, 5270, 3731, 9955, 1885, 7924, 4387, ... 1749, 4182, 1021, 516, 7086, 8407]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-94p5_dMchi-9p0_ct-1/', 'Mchi': 94.5, 'dMchi': 9.0, 'ctau': 1, 'name': 'sig_Mchi-94.5_dMchi-9.0_ct-1', 'sum_wgt': 2.3571923520648852e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 398.137418596, 'nFiles': 1, 'num_events': 749623, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-88p0_dMchi-16p0_ct-100/', 'Mchi': 88.0, 'dMchi': 16.0, 'ctau': 100, 'name': 'sig_Mchi-88.0_dMchi-16.0_ct-100', 'sum_wgt': 0.0002505784505046904, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.19137276241300002, 'nFiles': 1, 'num_events': 277978, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [7503, 6286, 8847, 9162, 1299, 8641, 2026, ... 8136, 272, 4240, 4540, 7954, 9957]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-88p0_dMchi-16p0_ct-10/', 'Mchi': 88.0, 'dMchi': 16.0, 'ctau': 10, 'name': 'sig_Mchi-88.0_dMchi-16.0_ct-10', 'sum_wgt': 0.0001302966702496633, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1.91354162465, 'nFiles': 1, 'num_events': 144738, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [9318, 4213, 4370, 702, 5207, 2749, 7724, ... 7954, 3872, 7051, 5758, 7162, 397]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-84p0_dMchi-8p0_ct-100/', 'Mchi': 84.0, 'dMchi': 8.0, 'ctau': 100, 'name': 'sig_Mchi-84.0_dMchi-8.0_ct-100', 'sum_wgt': 9.782585948414635e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 6.1271435452, 'nFiles': 1, 'num_events': 298436, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
#  [7511, 7091, 9236, 2779, 6042, 7144, 2811, ... 113, 6620, 791, 1235, 4655, 8552]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-84p0_dMchi-8p0_ct-10/', 'Mchi': 84.0, 'dMchi': 8.0, 'ctau': 10, 'name': 'sig_Mchi-84.0_dMchi-8.0_ct-10', 'sum_wgt': 9.682895324658602e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 61.0867567404, 'nFiles': 1, 'num_events': 295504, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [5332, 8637, 332, 5418, 1727]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-84p0_dMchi-8p0_ct-1/', 'Mchi': 84.0, 'dMchi': 8.0, 'ctau': 1, 'name': 'sig_Mchi-84.0_dMchi-8.0_ct-1', 'sum_wgt': 9.783178029465489e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 589.9830979010001, 'nFiles': 1, 'num_events': 298547, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [2775, 3224, 9495, 6946, 1418, 1926, 579, ... 7445, 8068, 350, 1809, 4615, 5430]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-77p0_dMchi-14p0_ct-100/', 'Mchi': 77.0, 'dMchi': 14.0, 'ctau': 100, 'name': 'sig_Mchi-77.0_dMchi-14.0_ct-100', 'sum_wgt': 0.0002670204557944089, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.29820944303400004, 'nFiles': 1, 'num_events': 284183, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [5178, 7941, 4010, 6204, 5063, 8175, 2012, ... 8440, 9715, 6626, 8250, 7282, 8304]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-77p0_dMchi-14p0_ct-10/', 'Mchi': 77.0, 'dMchi': 14.0, 'ctau': 10, 'name': 'sig_Mchi-77.0_dMchi-14.0_ct-10', 'sum_wgt': 0.0002207420620834455, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 2.98173543457, 'nFiles': 1, 'num_events': 234947, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [6746, 2015, 2278, 3964, 322, 2300, 8966, 4544, 3662]
# NJet [0,2]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-77p0_dMchi-14p0_ct-1/', 'Mchi': 77.0, 'dMchi': 14.0, 'ctau': 1, 'name': 'sig_Mchi-77.0_dMchi-14.0_ct-1', 'sum_wgt': 0.0002684956416487694, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 29.7850547482, 'nFiles': 1, 'num_events': 285650, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [7454, 2634, 1, 6421, 6523, 7051, 6413, ... 6469, 3830, 9224, 601, 8005, 4392, 3606]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-73p5_dMchi-7p0_ct-100/', 'Mchi': 73.5, 'dMchi': 7.0, 'ctau': 100, 'name': 'sig_Mchi-73.5_dMchi-7.0_ct-100', 'sum_wgt': 1.0477501746208873e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 9.5470955076, 'nFiles': 1, 'num_events': 306564, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:
# [4398, 6784, 2005, 9058, 8464, 353, 9244, ... 1847, 1212, 6039, 7308, 383, 155, 5794]{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-73p5_dMchi-7p0_ct-10/', 'Mchi': 73.5, 'dMchi': 7.0, 'ctau': 10, 'name': 'sig_Mchi-73.5_dMchi-7.0_ct-10', 'sum_wgt': 1.0151796232094057e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 95.082989975, 'nFiles': 1, 'num_events': 297097, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [456, 8028, 6747, 702, 8653, 748, 1953, ... 3804, 5644, 8301, 2707, 7404, 68, 7758]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-73p5_dMchi-7p0_ct-1/', 'Mchi': 73.5, 'dMchi': 7.0, 'ctau': 1, 'name': 'sig_Mchi-73.5_dMchi-7.0_ct-1', 'sum_wgt': 1.0401379768154584e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 916.6790979, 'nFiles': 1, 'num_events': 304395, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:
#  [8130, 334, 498, 2859, 8099]{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-63p0_dMchi-6p0_ct-100/', 'Mchi': 63.0, 'dMchi': 6.0, 'ctau': 100, 'name': 'sig_Mchi-63.0_dMchi-6.0_ct-100', 'sum_wgt': 1.1268473826930858e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 16.0669205521, 'nFiles': 1, 'num_events': 312674, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [4281, 5525, 5680, 5306, 4412, 801, 8430, ... 7758, 6921, 6960, 3266, 4252, 5015]
# NJet [0,2]
# good_vtx definition v7{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-63p0_dMchi-6p0_ct-10/', 'Mchi': 63.0, 'dMchi': 6.0, 'ctau': 10, 'name': 'sig_Mchi-63.0_dMchi-6.0_ct-10', 'sum_wgt': 9.709176993055735e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 159.93377163899999, 'nFiles': 1, 'num_events': 269409, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
#
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [6709, 3365, 4911, 9447, 6312, 2882, 2985, ... 7863, 4273, 4736, 6695, 793, 7243]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-63p0_dMchi-6p0_ct-1/', 'Mchi': 63.0, 'dMchi': 6.0, 'ctau': 1, 'name': 'sig_Mchi-63.0_dMchi-6.0_ct-1', 'sum_wgt': 1.1015758900612127e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1524.37695913, 'nFiles': 1, 'num_events': 305820, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [2302, 1874, 31]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p5_dMchi-1p0_ct-100/', 'Mchi': 5.5, 'dMchi': 1.0, 'ctau': 100, 'name': 'sig_Mchi-5.5_dMchi-1.0_ct-100', 'sum_wgt': 9.954061169992201e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 31.639066700000004, 'nFiles': 1, 'num_events': 293617, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [3670, 2527, 5197, 1208, 9460, 5129, 4747, ... 210, 4589, 2375, 8108, 9948, 638]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p5_dMchi-1p0_ct-10/', 'Mchi': 5.5, 'dMchi': 1.0, 'ctau': 10, 'name': 'sig_Mchi-5.5_dMchi-1.0_ct-10', 'sum_wgt': 9.829372174863238e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 315.945803, 'nFiles': 1, 'num_events': 289888, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  []
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p5_dMchi-1p0_ct-1/', 'Mchi': 5.5, 'dMchi': 1.0, 'ctau': 1, 'name': 'sig_Mchi-5.5_dMchi-1.0_ct-1', 'sum_wgt': 9.982846677303314e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 3114.14413, 'nFiles': 1, 'num_events': 294222, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
#
# good_vtx definition v7Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [878, 5573, 8844, 4804, 8102, 3339, 9683, 6267, 410]
# NJet [0,2]
#
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p25_dMchi-0p5_ct-100/', 'Mchi': 5.25, 'dMchi': 0.5, 'ctau': 100, 'name': 'sig_Mchi-5.25_dMchi-0.5_ct-100', 'sum_wgt': 1.8084282373820315e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1005.7012780000001, 'nFiles': 1, 'num_events': 1464941, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [6893, 789, 6645, 306, 1202, 5288, 6044, ... 9646, 6465, 8251, 2984, 9404, 3833]
# NJet [0,2]{'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p25_dMchi-0p5_ct-10/', 'Mchi': 5.25, 'dMchi': 0.5, 'ctau': 10, 'name': 'sig_Mchi-5.25_dMchi-0.5_ct-10', 'sum_wgt': 5.451649371934764e-07, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 9654.60294, 'nFiles': 1, 'num_events': 441723, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
#
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [3132, 4077]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-5p25_dMchi-0p5_ct-1/', 'Mchi': 5.25, 'dMchi': 0.5, 'ctau': 1, 'name': 'sig_Mchi-5.25_dMchi-0.5_ct-1', 'sum_wgt': 2.97077264121981e-07, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 71121.5634, 'nFiles': 1, 'num_events': 240690, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [4623, 3062, 7360, 7557, 6502, 5349]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-55p0_dMchi-10p0_ct-100/', 'Mchi': 55.0, 'dMchi': 10.0, 'ctau': 100, 'name': 'sig_Mchi-55.0_dMchi-10.0_ct-100', 'sum_wgt': 0.0003454237012192607, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.973702779, 'nFiles': 1, 'num_events': 311639, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
#
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [8114, 907]
# Cos(collinear) [-1, -0.95] event #:  [6445, 1846, 4362]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-55p0_dMchi-10p0_ct-10/', 'Mchi': 55.0, 'dMchi': 10.0, 'ctau': 10, 'name': 'sig_Mchi-55.0_dMchi-10.0_ct-10', 'sum_wgt': 0.00012851697101723403, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 9.735678006, 'nFiles': 1, 'num_events': 115956, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-55p0_dMchi-10p0_ct-1/', 'Mchi': 55.0, 'dMchi': 10.0, 'ctau': 1, 'name': 'sig_Mchi-55.0_dMchi-10.0_ct-1', 'sum_wgt': 2.4928291168180294e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 97.18122089, 'nFiles': 1, 'num_events': 22500, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [4673, 5311, 247, 3085, 5222, 6493]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-52p5_dMchi-5p0_ct-100/', 'Mchi': 52.5, 'dMchi': 5.0, 'ctau': 100, 'name': 'sig_Mchi-52.5_dMchi-5.0_ct-100', 'sum_wgt': 2.780125396384392e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 31.152733342, 'nFiles': 1, 'num_events': 689487, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# NJet [0,2]
# good_vtx definition v7
# good_vtx definition v7
# Select True vertex
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:
# Cos(collinear) [-1, -0.95] event #:  [2196, 2817, 2196]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-52p5_dMchi-5p0_ct-10/', 'Mchi': 52.5, 'dMchi': 5.0, 'ctau': 10, 'name': 'sig_Mchi-52.5_dMchi-5.0_ct-10', 'sum_wgt': 1.676403553574346e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 309.67832616000004, 'nFiles': 1, 'num_events': 415843, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# Cos(collinear) [-1, -0.95] event #:  [1208, 742, 2882, 2443, 2385, 1788, 2367, 4279, 4002]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-52p5_dMchi-5p0_ct-1/', 'Mchi': 52.5, 'dMchi': 5.0, 'ctau': 1, 'name': 'sig_Mchi-52.5_dMchi-5.0_ct-1', 'sum_wgt': 1.46754164234153e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 2894.2410560999997, 'nFiles': 1, 'num_events': 363908, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-44p0_dMchi-8p0_ct-100/', 'Mchi': 44.0, 'dMchi': 8.0, 'ctau': 100, 'name': 'sig_Mchi-44.0_dMchi-8.0_ct-100', 'sum_wgt': 0.0010339958826079965, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 3.057662, 'nFiles': 1, 'num_events': 589401, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  []
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-44p0_dMchi-8p0_ct-10/', 'Mchi': 44.0, 'dMchi': 8.0, 'ctau': 10, 'name': 'sig_Mchi-44.0_dMchi-8.0_ct-10', 'sum_wgt': 0.0006436090916395187, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 30.562520199999998, 'nFiles': 1, 'num_events': 366975, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# Cos(collinear) [-1, -0.95] event #:  [8233, 1207]
# NJet [0,2]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-44p0_dMchi-8p0_ct-1/', 'Mchi': 44.0, 'dMchi': 8.0, 'ctau': 1, 'name': 'sig_Mchi-44.0_dMchi-8.0_ct-1', 'sum_wgt': 0.0005332844448275864, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 304.043685, 'nFiles': 1, 'num_events': 304001, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1401, 1514, 4441, 2461, 8748, 8697, 3373, ... 6111, 1583, 1321, 9512, 120, 4326]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-42p0_dMchi-4p0_ct-100/', 'Mchi': 42.0, 'dMchi': 4.0, 'ctau': 100, 'name': 'sig_Mchi-42.0_dMchi-4.0_ct-100', 'sum_wgt': 5.867567961104214e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 98.3570768, 'nFiles': 1, 'num_events': 918592, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [5609, 4829, 3463, 3165, 9737, 9618, 7882, ... 1764, 383, 1573, 8843, 6163, 7148]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-42p0_dMchi-4p0_ct-10/', 'Mchi': 42.0, 'dMchi': 4.0, 'ctau': 10, 'name': 'sig_Mchi-42.0_dMchi-4.0_ct-10', 'sum_wgt': 2.8500857297331095e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 969.089801, 'nFiles': 1, 'num_events': 446411, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1449, 6155, 5285, 6800, 8992, 2438, 8543, 9271]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-42p0_dMchi-4p0_ct-1/', 'Mchi': 42.0, 'dMchi': 4.0, 'ctau': 1, 'name': 'sig_Mchi-42.0_dMchi-4.0_ct-1', 'sum_wgt': 2.472328196745366e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 8504.86918, 'nFiles': 1, 'num_events': 387173, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1459, 3180, 4828, 4724, 1631]
# good_vtx definition v7
# Select True vertex
# NJet [0,2]
# Cos(collinear) [-1, -0.95] event #:  [7442, 7085, 998, 7417, 5723, 1468, 1528, ... 7174, 4476, 8388, 6939, 2246, 3206]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-33p0_dMchi-6p0_ct-100/', 'Mchi': 33.0, 'dMchi': 6.0, 'ctau': 100, 'name': 'sig_Mchi-33.0_dMchi-6.0_ct-100', 'sum_wgt': 0.17940662801265717, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1515.4870799999999, 'nFiles': 1, 'num_events': 389869, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1161, 156, 2653, 3338, 486, 5561, 3170, 7728, 990, 2849]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-33p0_dMchi-6p0_ct-10/', 'Mchi': 33.0, 'dMchi': 6.0, 'ctau': 10, 'name': 'sig_Mchi-33.0_dMchi-6.0_ct-10', 'sum_wgt': 0.18482398986816406, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 12752.7387, 'nFiles': 1, 'num_events': 401963, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-33p0_dMchi-6p0_ct-1/', 'Mchi': 33.0, 'dMchi': 6.0, 'ctau': 1, 'name': 'sig_Mchi-33.0_dMchi-6.0_ct-1', 'sum_wgt': 0.1846824586391449, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 37964.570999999996, 'nFiles': 1, 'num_events': 401252, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
#
# NJet [0,2]
# Cos(collinear) [-1, -0.95] event #:
# good_vtx definition v7
# Select True vertex
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-31p5_dMchi-3p0_ct-100/', 'Mchi': 31.5, 'dMchi': 3.0, 'ctau': 100, 'name': 'sig_Mchi-31.5_dMchi-3.0_ct-100', 'sum_wgt': 0.018431562930345535, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 28961.5332, 'nFiles': 1, 'num_events': 1101378, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# Cos(collinear) [-1, -0.95] event #:  [2813, 4007, 8627, 9618, 4107, 1339, 4925, ... 7190, 658, 436, 8101, 1161, 4843]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-31p5_dMchi-3p0_ct-10/', 'Mchi': 31.5, 'dMchi': 3.0, 'ctau': 10, 'name': 'sig_Mchi-31.5_dMchi-3.0_ct-10', 'sum_wgt': 0.008623819798231125, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 21568.034, 'nFiles': 1, 'num_events': 515420, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [2103, 1952, 2003, 2963, 2943, 534]
# Cos(collinear) [-1, -0.95] event #:  [6964, 7067, 6186, 950, 2115, 4443, 443, ... 9588, 4976, 2639, 2250, 2565, 2756, 326]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-22p0_dMchi-4p0_ct-100/', 'Mchi': 22.0, 'dMchi': 4.0, 'ctau': 100, 'name': 'sig_Mchi-22.0_dMchi-4.0_ct-100', 'sum_wgt': 0.00039172606193460524, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 9.516153899999999, 'nFiles': 1, 'num_events': 603880, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-31p5_dMchi-3p0_ct-1/', 'Mchi': 31.5, 'dMchi': 3.0, 'ctau': 1, 'name': 'sig_Mchi-31.5_dMchi-3.0_ct-1', 'sum_wgt': 0.007165809161961079, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 23040.233, 'nFiles': 1, 'num_events': 428148, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [2883, 5319]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-22p0_dMchi-4p0_ct-10/', 'Mchi': 22.0, 'dMchi': 4.0, 'ctau': 10, 'name': 'sig_Mchi-22.0_dMchi-4.0_ct-10', 'sum_wgt': 0.00033917155815288424, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 95.11161299999999, 'nFiles': 1, 'num_events': 522806, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
#
# good_vtx definition v7
# Select True vertex
# NJet [0,2]
# Cos(collinear) [-1, -0.95] event #:  [116, 341, 225, 8522, 2516, 3528, 1378, 2877, 2668, 4593, 944]
# good_vtx definition v7
# Select True vertex
# NJet [0,2]
# good_vtx definition v7Cos(collinear) [-1, -0.95] event #:
#  []
# Select True vertex
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-22p0_dMchi-4p0_ct-1/', 'Mchi': 22.0, 'dMchi': 4.0, 'ctau': 1, 'name': 'sig_Mchi-22.0_dMchi-4.0_ct-1', 'sum_wgt': 0.00027210605912841856, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 946.7888800000001, 'nFiles': 1, 'num_events': 419498, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# Cos(collinear) [-1, -0.95] event #:  [162, 3050, 2540, 4012, 2172, 4571, 2745, ... 803, 2594, 1693, 4034, 3646, 8041]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-21p0_dMchi-2p0_ct-100/', 'Mchi': 21.0, 'dMchi': 2.0, 'ctau': 100, 'name': 'sig_Mchi-21.0_dMchi-2.0_ct-100', 'sum_wgt': 1.816521216824185e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 303.99344, 'nFiles': 1, 'num_events': 769569, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-21p0_dMchi-2p0_ct-10/', 'Mchi': 21.0, 'dMchi': 2.0, 'ctau': 10, 'name': 'sig_Mchi-21.0_dMchi-2.0_ct-10', 'sum_wgt': 9.44840121519519e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 2994.01098, 'nFiles': 1, 'num_events': 400009, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [596, 2766, 2404, 3073]
# Cos(collinear) [-1, -0.95] event #:  [4500, 7348, 3072, 4525, 2030, 2374, 7252, ... 1797, 8765, 9605, 2121, 6481, 406]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-21p0_dMchi-2p0_ct-1/', 'Mchi': 21.0, 'dMchi': 2.0, 'ctau': 1, 'name': 'sig_Mchi-21.0_dMchi-2.0_ct-1', 'sum_wgt': 9.511019015917554e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 25833.374, 'nFiles': 1, 'num_events': 402997, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [3528, 2129, 1993, 903, 3072, 431]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-11p0_dMchi-2p0_ct-100/', 'Mchi': 11.0, 'dMchi': 2.0, 'ctau': 100, 'name': 'sig_Mchi-11.0_dMchi-2.0_ct-100', 'sum_wgt': 9.749970922712237e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 15.5520366, 'nFiles': 1, 'num_events': 732332, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-11p0_dMchi-2p0_ct-10/', 'Mchi': 11.0, 'dMchi': 2.0, 'ctau': 10, 'name': 'sig_Mchi-11.0_dMchi-2.0_ct-10', 'sum_wgt': 7.448990800185129e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 155.409249, 'nFiles': 1, 'num_events': 559380, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# Cos(collinear) [-1, -0.95] event #:  [4461, 3201, 630, 3206, 2399, 4734, 925, ... 5397, 4176, 4298, 3845, 3602, 7703, 572]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-11p0_dMchi-2p0_ct-1/', 'Mchi': 11.0, 'dMchi': 2.0, 'ctau': 1, 'name': 'sig_Mchi-11.0_dMchi-2.0_ct-1', 'sum_wgt': 5.9077003243146464e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 1543.0629600000002, 'nFiles': 1, 'num_events': 443760, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# NJet [0,2]
# Select True vertex
# good_vtx definition v7
# Select True vertexCos(collinear) [-1, -0.95] event #:  [2464, 4070, 6265, 1749, 3156, 3646, 4338, ... 9486, 1037, 1826, 6668, 2905, 1656]
# Cos(collinear) [-1, -0.95] event #:  [3204, 2969, 306, 2718]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-110p0_dMchi-20p0_ct-100/', 'Mchi': 110.0, 'dMchi': 20.0, 'ctau': 100, 'name': 'sig_Mchi-110.0_dMchi-20.0_ct-100', 'sum_wgt': 0.00021416587696876377, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.08935513095309999, 'nFiles': 1, 'num_events': 258432, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-110p0_dMchi-20p0_ct-10/', 'Mchi': 110.0, 'dMchi': 20.0, 'ctau': 10, 'name': 'sig_Mchi-110.0_dMchi-20.0_ct-10', 'sum_wgt': 0.00022194665507413447, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 0.893541909663, 'nFiles': 1, 'num_events': 267815, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [2662, 4021, 742, 1820]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-110p0_dMchi-20p0_ct-1/', 'Mchi': 110.0, 'dMchi': 20.0, 'ctau': 1, 'name': 'sig_Mchi-110.0_dMchi-20.0_ct-1', 'sum_wgt': 0.00021350891620386392, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 8.92400311055, 'nFiles': 1, 'num_events': 257674, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [8011, 464, 7629, 2372, 4345, 1288, 2731, ... 4598, 185, 5517, 8950, 5968, 3403]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-10p5_dMchi-1p0_ct-100/', 'Mchi': 10.5, 'dMchi': 1.0, 'ctau': 100, 'name': 'sig_Mchi-10.5_dMchi-1.0_ct-100', 'sum_wgt': 6.962325869608321e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 496.527114, 'nFiles': 2, 'num_events': 1437170, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [8771, 8165, 8596, 9828, 8859, 5812, 1054, ... 7182, 1049, 9043, 3033, 4694, 7128]
# NJet [0,2]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-10p5_dMchi-1p0_ct-10/', 'Mchi': 10.5, 'dMchi': 1.0, 'ctau': 10, 'name': 'sig_Mchi-10.5_dMchi-1.0_ct-10', 'sum_wgt': 3.116922471235739e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 4859.838919999999, 'nFiles': 1, 'num_events': 643295, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [93, 472, 2829]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-10p5_dMchi-1p0_ct-1/', 'Mchi': 10.5, 'dMchi': 1.0, 'ctau': 1, 'name': 'sig_Mchi-10.5_dMchi-1.0_ct-1', 'sum_wgt': 2.4860339635779383e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 40301.1609, 'nFiles': 1, 'num_events': 513160, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [6479, 2227, 8156, 4664, 8473, 3349, 3428, ... 3717, 1817, 7893, 8979, 9596, 3192]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-105p0_dMchi-10p0_ct-100/', 'Mchi': 105.0, 'dMchi': 10.0, 'ctau': 100, 'name': 'sig_Mchi-105.0_dMchi-10.0_ct-100', 'sum_wgt': 2.346780092921108e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 2.8498258236700003, 'nFiles': 1, 'num_events': 778905, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [3928, 6373, 7588, 1395, 205, 6235, 1596, ... 4676, 6000, 6553, 1934, 2357, 5223]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-105p0_dMchi-10p0_ct-10/', 'Mchi': 105.0, 'dMchi': 10.0, 'ctau': 10, 'name': 'sig_Mchi-105.0_dMchi-10.0_ct-10', 'sum_wgt': 1.9013201381312683e-05, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 28.438868393299998, 'nFiles': 1, 'num_events': 631085, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [279, 8544, 2475, 6069, 4291, 5004, 7166, ... 7829, 2100, 4486, 8183, 8115, 986]
# {'location': '/store/group/lpcmetx/iDMe//skimmed_ntuples/signal/signal_v9_miniAOD_2018_aEM_rdfSkim_MET200_noNJetCut/output_sig_Mchi-105p0_dMchi-10p0_ct-1/', 'Mchi': 105.0, 'dMchi': 10.0, 'ctau': 1, 'name': 'sig_Mchi-105.0_dMchi-10.0_ct-1', 'sum_wgt': 2.3678271645621862e-06, 'type': 'signal', 'year': 2018, 'alphaD': 'aEM', 'xsec': 277.338399693, 'nFiles': 1, 'num_events': 78615, 'blacklist': [], 'defineGoodVertices': <function defineGoodVertices at 0x7f4d7f3e7790>, 'selectBestVertex': <function selectBestVertex at 0x7f4d7f3e7820>}
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [9275, 5864, 2762, 1897, 6899, 934, 2507, ... 9242, 4911, 3190, 368, 2386, 964, 4164]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [1315, 4009, 6601, 9412, 5884, 1233, 3583, ... 1417, 173, 9074, 3205, 4411, 6693]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
#  [9029, 8157, 8955, 9443, 1825, 2965, 4910, ... 5442, 9334, 4903, 2537, 9210, 354]
# NJet [0,2]
# good_vtx definition v7
# Select True vertex
# Cos(collinear) [-1, -0.95] event #:  [3023, 2207, 1434, 6003, 1853, 2098, 4617, ... 9853, 3301, 6814, 6422, 9533, 1593]
