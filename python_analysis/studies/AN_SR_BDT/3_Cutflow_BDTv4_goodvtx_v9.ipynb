# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from coffea import util
from coffea.processor import accumulate
import os
import re
import pandas as pd
import hist
import matplotlib as mpl
import mplhep
import sys

sys.path.append("../../analysisTools/")
import plotTools as ptools
import utils

# %% [markdown]
# ## Import coffea files -- signal and background

# %%
prefix = './coffea/skimmed/'

#suffix = 'BDT_v1_goodVtx_v10'
#suffix = 'BDT_v4_goodVtx_v9_Tight_bjetMed'
suffix = 'BDT_v4_goodVtx_v9_Tight_bjetMed_TrueVertex'

# %%
# Signal
sig_histo = util.load(f'{prefix}/signal_{suffix}.coffea')[0]

# %%
# Background
bkg_histo = util.load(f'{prefix}/bkg_{suffix}.coffea')[0]

# %% [markdown]
# ## Signal

# %%
sig_samples = list(sig_histo['cutflow'].keys())
si = pd.DataFrame.from_dict({s:ptools.signalPoint(s) for s in sig_samples}, orient='index')

# %%
cutnames = utils.get_signal_list_of_cuts(sig_histo)
cutnames
# Out:
# ['Preselections',
#  'n(good vertex) > 0',
#  'Leading jet pT > 80 GeV',
#  'Leading jet |eta| < 2.4',
#  'dPhi(MET,leading jet) > 2.0',
#  'dPhi(MET,all jets) > 0.75',
#  'BDT']

# %%
# Efficiency
pd.options.display.float_format = '{:,.6f}'.format
eff_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow')

# %%
table = eff_cutflow
table.columns = cutnames

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_Efficiency'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_Efficiency.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_Efficiency.csv

# %%
# Weighted event count
pd.options.display.float_format = '{:,.4f}'.format
cts_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

# %%
table = cts_cutflow
table.columns = cutnames

# %%
# ctau = 1mm
ct = 1.0

points = (si["ctau"] == ct)

df = table.loc[list(si[points].name)]
df
# Out:
#                                        Preselections  n(good vertex) > 0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1         44.1691             29.5734
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       1,156.9315            716.8623
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       1,457.7156            884.9729
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1         74.7132             49.3345
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       1,964.2733          1,171.9332
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       2,725.2304          1,579.0888
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        1,620.1785            747.4597
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      33,765.0692         12,127.7993
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1        167.4818            113.2253
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       4,184.6540          2,391.5724
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1         403.5456            258.8580
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       9,916.8019          5,696.2562
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1      38,528.4000         24,522.9565
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1      20,174.8511         11,126.9966
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1         734.2812            445.1854
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1      17,929.3616          9,438.1695
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1         937.0399            527.3985
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1        34.0246             22.9323
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1      22,229.4245         10,333.4683
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       928.4857            584.6380
#
#                                        Leading jet pT > 80 GeV  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   29.5407
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   716.1004
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   883.6714
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   49.3094
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,171.2139
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,578.7905
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    747.4597
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                12,127.7993
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  113.2253
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,387.7622
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   258.4393
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,692.3059
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                24,500.2825
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                11,110.8939
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   445.0503
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 9,418.9596
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   527.1898
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  22.9053
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                10,319.3750
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 583.5817
#
#                                        Leading jet |eta| < 2.4  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                   28.5309
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                   691.4077
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                   853.9959
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                   47.5001
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                 1,131.2122
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                 1,522.4253
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                    718.9656
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                11,632.8190
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                  108.8301
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                 2,309.2443
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                   249.8828
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                 5,487.2554
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                23,634.1487
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                10,785.6165
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                   428.5733
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                 9,131.4853
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                   507.0019
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                  22.1282
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                 9,910.5872
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                 564.3731
#
#                                        dPhi(MET,leading jet) > 2.0  \
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                       28.5309
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                       691.4077
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                       853.9959
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                       47.4939
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                     1,131.2122
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                     1,522.4253
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                        718.9656
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                    11,632.8190
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                      108.8301
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                     2,309.2443
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                       249.8828
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                     5,487.2554
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                    23,634.1487
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                    10,785.6165
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                       428.5733
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                     9,131.4853
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                       507.0019
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                      22.1282
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                     9,910.5872
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                     564.3731
#
#                                        dPhi(MET,all jets) > 0.75         BDT
# sig_2018_Mchi-99p0_dMchi-18p0_ctau-1                     28.1607     13.4236
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1                     683.3386    408.4072
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1                     843.1193    522.6987
# sig_2018_Mchi-77p0_dMchi-14p0_ctau-1                     46.8828     27.4061
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1                   1,116.6125    740.7572
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1                   1,503.9374  1,041.9433
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1                      711.3617    525.0865
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1                  11,384.9230  6,789.1721
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-1                    107.5389     80.4046
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1                   2,274.0382  1,691.1461
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1                     246.4732    191.0035
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1                   5,439.9264  4,183.4648
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1                  23,299.8352 18,544.5121
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1                  10,701.8691  8,287.3447
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1                     423.8484    349.3034
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1                   9,028.0175  7,168.5086
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1                     502.4263    395.0636
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1                    21.8796      9.6205
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1                   9,802.6079  7,453.4825
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1                   555.2951    298.6269

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_EventCount_Weighted'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_EventCount_Weighted.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_EventCount_Weighted.csv

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# Raw count
pd.options.display.float_format = '{:,.4f}'.format
raw_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_nevts')

# %%
# Per ctau
for ct in [1, 10, 100]:
    points = (si["ctau"] == ct)
    
    df = table.loc[list(si[points].name)]

    outdir = './csv/Cutflow/Efficiency/'
    outname = f'SR_Signal_ctau-{int(ct)}_samples_Raw'
    
    df_to_save = df
    
    utils.save_df_to_csv(df_to_save, outdir, outname, isSignal=True)
# Out:
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-1_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-10_samples_Raw.csv
# Saved: ./csv/Cutflow/Efficiency//SR_Signal_ctau-100_samples_Raw.csv

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [5, 10, 20, 30, 40],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_SR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m5to40.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_100_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_1_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_10_m5to40.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_100_m5to40.png

# %%
df = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_sig_eff = {
    # Select signal points to display
    'm1s': [50, 70, 90, 100],
    'deltas': [0.1],
    'ctaus': [1],

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': './plots/cutflow/',
    'outName': ''
}

# Delta 0.1 1mm

for delta in [0.1, 0.2]:
    for ctau in [1, 10, 100]:
        plot_dict_sig_eff['deltas'] = [delta]
        plot_dict_sig_eff['ctaus'] = [ctau]
        
        plot_dict_sig_eff['title'] = rf"Cutflow: $\Delta$ = {delta}, c$\tau$ = {ctau}mm"
        plot_dict_sig_eff['outName'] = rf"Cutflow_SR_signal_delta_{str(delta).replace('.', 'p')}_ct_{ctau}_m50to100.png"
        
        ptools.plot_signal_efficiency(sig_histo, df, plot_dict_sig_eff)
# Out:
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p1_ct_100_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_1_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_10_m50to100.png
# ['Preselections', 'n(good vertex) > 0 && N(Jets) > 2', 'Leading jet pT > 80 GeV', 'Leading jet |eta| < 2.4', 'dPhi(MET,leading jet) > 2.0', 'dPhi(MET,all jets) > 0.75', 'BDT']
# Saved: ./plots/cutflow//Cutflow_SR_signal_delta_0p2_ct_100_m50to100.png

# %% [markdown]
# ## Signal purity

# %%
utils.get_signal_cutflow_dict(sig_histo, 'cutflow_vtx_matched')

# %% [markdown]
# ## Background

# %%
# efficiency
pd.options.display.float_format = '{:,.8f}'.format

bkg_eff_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow')
bkg_eff_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# Top            0.00039885          0.00001442               0.00001308
# DY             0.00018701          0.00001257               0.00001244
# WJets          0.00101318          0.00002788               0.00002733
# ZGamma         0.00032468          0.00001403               0.00001148
# ZJets          0.00242159          0.00004892               0.00004832
# QCD            0.00000249          0.00000001               0.00000001
# Multiboson     0.00065832          0.00004711               0.00003851
# Total          0.00001696          0.00000042               0.00000040
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# Top                      0.00001185                   0.00001166
# DY                       0.00001206                   0.00001180
# WJets                    0.00002605                   0.00002587
# ZGamma                   0.00001047                   0.00001008
# ZJets                    0.00004574                   0.00004559
# QCD                      0.00000001                   0.00000001
# Multiboson               0.00003619                   0.00003441
# Total                    0.00000038                   0.00000038
#
#             dPhi(MET,all jets) > 0.75        BDT
# Top                        0.00001053 0.00000006
# DY                         0.00001058 0.00000027
# WJets                      0.00002387 0.00000017
# ZGamma                     0.00001018 0.00000016
# ZJets                      0.00004258 0.00000058
# QCD                        0.00000000 0.00000000
# Multiboson                 0.00003271 0.00000008
# Total                      0.00000034 0.00000000

# %%
# Save as csv
outdir = f'./csv/{suffix}/Cutflow/Efficiency/'
outname = f'Background_Efficiency'

df_to_save = bkg_eff_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_v4_goodVtx_v9_Tight_bjetMed/Cutflow/Efficiency//Background_Efficiency.csv

# %%
# weighted event count
pd.options.display.float_format = '{:,.2f}'.format
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts', isLegacy = False)

bkg_cts_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# Top             26,174.93                            946.25
# DY               5,819.49                            391.25
# WJets          214,692.24                          5,907.87
# ZGamma           1,665.13                             71.94
# ZJets           63,745.58                          1,287.65
# QCD             53,432.27                            201.57
# Multiboson       4,588.16                            328.35
# Total          370,117.80                          9,134.89
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# Top                          858.46                   777.73
# DY                           387.08                   375.32
# WJets                      5,790.79                 5,518.97
# ZGamma                        58.88                    53.71
# ZJets                      1,272.02                 1,204.00
# QCD                          201.57                   171.26
# Multiboson                   268.41                   252.24
# Total                      8,837.21                 8,353.24
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75   BDT
# Top                              765.41                     690.89  3.87
# DY                               367.32                     329.19  8.34
# WJets                          5,481.92                   5,059.10 35.79
# ZGamma                            51.68                      52.19  0.83
# ZJets                          1,200.19                   1,120.99 15.30
# QCD                              157.33                      32.10  0.00
# Multiboson                       239.79                     228.01  0.58
# Total                          8,263.65                   7,512.47 64.72

# %%
# Save to csv
outdir = f'./csv/{suffix}/Cutflow/EventCount_Weighted/'
outname = f'Background_EventCount_Weighted'

df_to_save = bkg_cts_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_v4_goodVtx_v9_Tight_bjetMed/Cutflow/EventCount_Weighted//Background_EventCount_Weighted.csv

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df
# Out:
#             Preselections  n(good vertex) > 0  Leading jet pT > 80 GeV  \
# Top                703976               25285                    22627
# DY                 296131                9735                     9697
# WJets             1177020               16358                    16090
# ZGamma               6506                 304                      270
# ZJets              738994                8102                     8014
# QCD                 31490                  64                       64
# Multiboson          25187                1895                     1496
# Total             2979304               61743                    58258
#
#             Leading jet |eta| < 2.4  dPhi(MET,leading jet) > 2.0  \
# Top                           20476                        19816
# DY                             9580                         8728
# WJets                         15538                        15191
# ZGamma                          257                          236
# ZJets                          7689                         7593
# QCD                              63                           59
# Multiboson                     1412                         1291
# Total                         55015                        52914
#
#             dPhi(MET,all jets) > 0.75  BDT
# Top                             17814   77
# DY                               5486   92
# WJets                           12955   85
# ZGamma                            211    1
# ZJets                            6487   75
# QCD                                 4    0
# Multiboson                       1212    2
# Total                           44169  332

# %%
# raw event count
pd.options.display.float_format = '{:,.0f}'.format
bkg_cts_raw_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_nevts', isLegacy = False)

bkg_cts_raw_df.rename(columns={'n(good vertex) > 0': 'n(jet) > 2 && n(good vertex) > 0'})
# Out:
#             Preselections  n(jet) > 2 && n(good vertex) > 0  \
# Top                703976                             25285
# DY                 296131                              9735
# WJets             1177020                             16358
# ZGamma               6506                               304
# ZJets              738994                              8102
# QCD                 31490                                64
# Multiboson          25187                              1895
# Total             2979304                             61743
#
#             Leading jet pT > 80 GeV  Leading jet |eta| < 2.4  \
# Top                           22627                    20476
# DY                             9697                     9580
# WJets                         16090                    15538
# ZGamma                          270                      257
# ZJets                          8014                     7689
# QCD                              64                       63
# Multiboson                     1496                     1412
# Total                         58258                    55015
#
#             dPhi(MET,leading jet) > 2.0  dPhi(MET,all jets) > 0.75  BDT
# Top                               19816                      17814   77
# DY                                 8728                       5486   92
# WJets                             15191                      12955   85
# ZGamma                              236                        211    1
# ZJets                              7593                       6487   75
# QCD                                  59                          4    0
# Multiboson                         1291                       1212    2
# Total                             52914                      44169  332

# %%
outdir = f'./csv/{suffix}/Cutflow/EventCount_Raw/'
outname = f'Background_EventCount_Raw'

df_to_save = bkg_cts_raw_df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/BDT_v4_goodVtx_v9_Tight_bjetMed/Cutflow/EventCount_Raw//Background_EventCount_Raw.csv

# %%
nBkg = bkg_cts_df.loc['Total'][-1]

print(f'Total number of backgrounds (weighted) after the last SR cut: {nBkg:.2f}')
# Out:
# Total number of backgrounds (weighted) after the last SR cut: 64.72

# %%
pd.options.display.float_format = '{:,.2f}'.format

bkg_composition = pd.concat([pd.DataFrame(bkg_cts_df[bkg_cts_df.columns.values[-1]]).transpose(), pd.DataFrame(bkg_cts_raw_df[bkg_cts_df.columns.values[-1]]).transpose()], ignore_index=True)

bkg_composition = bkg_composition.rename(index={0: 'Weighted Counts', 1: 'Raw Counts'})
bkg_composition
# Out:
#                   Top    DY  WJets  ZGamma  ZJets  QCD  Multiboson  Total
# Weighted Counts  3.87  8.34  35.79    0.83  15.30 0.00        0.58  64.72
# Raw Counts      77.00 92.00  85.00    1.00  75.00 0.00        2.00 332.00

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/BDT_v4_goodVtx_v9_Tight_bjetMed/cutflow//Cutflow_background.png

# %%
df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')

fig, axes = plt.subplots()

plot_dict_bkg_eff = {
    # Select processes
    'processes': 'all', # Otherwise, give as a list; ['WJets', 'ZJets', 'Total']

    # Plot display styling
    'ylim': None, # None for default; otherwise [ymin, ymax]
    'doLog': True,
    
    'ylabel': 'Events', # None for default
    'title': rf"Cutflow", 

    # Plot saving
    'doSave': True,
    'outDir': f'./plots/{suffix}/cutflow/',
    'outName': f'Cutflow_background.png'
}

# For all processes
ptools.plot_bkg_efficiency(bkg_histo, df, plot_dict_bkg_eff)
# Out:
# Saved: ./plots/BDT_v4_goodVtx_v9_Tight_bjetMed/cutflow//Cutflow_background.png

# %% [markdown]
# ## S/B

# %%
bkg_cts_df = utils.get_bkg_cutflow_df(bkg_histo, 'cutflow_cts')
nBkg = bkg_cts_df.loc['Total'][-1]

nBkg
# Out:
# 64.71540961434737

# %%
cts_cutflow = utils.get_signal_cutflow_dict(sig_histo, 'cutflow_cts')
table = cts_cutflow

cutnames = utils.get_signal_list_of_cuts(sig_histo)
table.columns = cutnames

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
df = pd.DataFrame(table.loc[:, cutnames[-1]]) # last cut
df = utils.add_signal_info_to_df(df)
df
# Out:
#                                                BDT       m1  delta     ctau
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1     6,789.1721   5.0000 0.1000   1.0000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        525.0865   5.0000 0.2000   1.0000
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100       4.8881   5.0000 0.1000 100.0000
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10      323.0046   5.0000 0.1000  10.0000
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100        0.3098   5.0000 0.2000 100.0000
# ...                                            ...      ...    ...      ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10      1.0592 100.0000 0.2000  10.0000
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       9.6205 100.0000 0.2000   1.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     298.6269 100.0000 0.1000   1.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     0.9772 100.0000 0.1000 100.0000
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10     29.1293 100.0000 0.1000  10.0000
#
# [62 rows x 4 columns]

# %%
# Missing rows
#df[ (df['m1'] == 60) & (df['delta'] == 0.2) ]

df.loc[len(df.index)] = [0, 60, 0.2, 1]
df.loc[len(df.index)] = [0, 60, 0.2, 10]
df.loc[len(df.index)] = [0, 60, 0.2, 100]
df.loc[len(df.index)] = [0, 80, 0.2, 1] 

df = df.sort_values(by=['m1']) # sort by m1

# %%
df = df.rename(columns={df.columns[0]: 'Signal'})

df['Background'] = nBkg
df['S/sqrt(B)'] = df['Signal'] / np.sqrt(df['Background'])

df = df[['m1', 'delta', 'ctau', 'Signal', 'Background', 'S/sqrt(B)']]

df
# Out:
#                                               m1  delta     ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       5.0000 0.1000   1.0000 6,789.1721
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1        5.0000 0.2000   1.0000   525.0865
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100     5.0000 0.1000 100.0000     4.8881
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10      5.0000 0.1000  10.0000   323.0046
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100      5.0000 0.2000 100.0000     0.3098
# ...                                          ...    ...      ...        ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1   100.0000 0.2000   1.0000     9.6205
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1   100.0000 0.1000   1.0000   298.6269
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100 100.0000 0.1000 100.0000     0.9772
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10  100.0000 0.1000  10.0000    29.1293
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10  100.0000 0.2000  10.0000     1.0592
#
#                                          Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1         64.7154   843.9427
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1          64.7154    65.2720
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-100       64.7154     0.6076
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-10        64.7154    40.1518
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-100        64.7154     0.0385
# ...                                             ...        ...
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-1       64.7154     1.1959
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1       64.7154    37.1215
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-100     64.7154     0.1215
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-10      64.7154     3.6210
# sig_2018_Mchi-110p0_dMchi-20p0_ctau-10      64.7154     0.1317
#
# [66 rows x 6 columns]

# %%
outdir = './csv/SR_Yields/'
outname = f'SR_S_over_B'

df_to_save = df

utils.save_df_to_csv(df_to_save, outdir, outname)
# Out:
# Saved: ./csv/SR_Yields//SR_S_over_B.csv

# %%
ct = 1.0

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.1
delta = 0.1

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau     Signal  \
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1      5.0   0.1  1.0 6,789.1721
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1     10.0   0.1  1.0 7,453.4825
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1     20.0   0.1  1.0 7,168.5086
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1     30.0   0.1  1.0 8,287.3447
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1     40.0   0.1  1.0 4,183.4648
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1     50.0   0.1  1.0 1,691.1461
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1     60.0   0.1  1.0 1,041.9433
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1     70.0   0.1  1.0   740.7572
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1     80.0   0.1  1.0   522.6987
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1     90.0   0.1  1.0   408.4072
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1  100.0   0.1  1.0   298.6269
#
#                                        Background  S/sqrt(B)
# sig_2018_Mchi-5p25_dMchi-0p5_ctau-1       64.7154   843.9427
# sig_2018_Mchi-10p5_dMchi-1p0_ctau-1       64.7154   926.5212
# sig_2018_Mchi-21p0_dMchi-2p0_ctau-1       64.7154   891.0970
# sig_2018_Mchi-31p5_dMchi-3p0_ctau-1       64.7154 1,030.1763
# sig_2018_Mchi-42p0_dMchi-4p0_ctau-1       64.7154   520.0346
# sig_2018_Mchi-52p5_dMchi-5p0_ctau-1       64.7154   210.2216
# sig_2018_Mchi-63p0_dMchi-6p0_ctau-1       64.7154   129.5210
# sig_2018_Mchi-73p5_dMchi-7p0_ctau-1       64.7154    92.0814
# sig_2018_Mchi-84p0_dMchi-8p0_ctau-1       64.7154    64.9752
# sig_2018_Mchi-94p5_dMchi-9p0_ctau-1       64.7154    50.7679
# sig_2018_Mchi-105p0_dMchi-10p0_ctau-1     64.7154    37.1215

# %%
pd.options.display.float_format = '{:,.4f}'.format

# S/sqrt(B) in ctau = 1mm, delta = 0.2
delta = 0.2

df_to_show = df[ (df.ctau == ct) & (df.delta == delta) ]
df_to_show.loc[:, 'm1'] = df_to_show.loc[:, 'm1'].map('{:,.1f}'.format)
df_to_show.loc[:, 'delta'] = df_to_show.loc[:, 'delta'].map('{:,.1f}'.format)
df_to_show.loc[:, 'ctau'] = df_to_show.loc[:, 'ctau'].map('{:,.1f}'.format)

df_to_show
# Out:
#                                           m1 delta ctau      Signal  \
# sig_2018_Mchi-5p5_dMchi-1p0_ctau-1       5.0   0.2  1.0    525.0865
# sig_2018_Mchi-11p0_dMchi-2p0_ctau-1     10.0   0.2  1.0    395.0636
# sig_2018_Mchi-22p0_dMchi-4p0_ctau-1     20.0   0.2  1.0    349.3034
# sig_2018_Mchi-33p0_dMchi-6p0_ctau-1     30.0   0.2  1.0 18,544.5121
# sig_2018_Mchi-44p0_dMchi-8p0_ctau-1     40.0   0.2  1.0    191.0035
# sig_2018_Mchi-55p0_dMchi-10p0_ctau-